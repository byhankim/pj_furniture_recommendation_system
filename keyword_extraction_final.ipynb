# %% [markdown]
# # 도전 키워드 추출!
# - 무엇을 도전하나요?
#     - 각 리뷰 토큰화
#     - 각 상품별 리뷰를 총집합하여 최적의 키워드 n개 추출
# - 무슨 방식으로 하나요?
#     - CountVectorizer
#     - TF-IDF
#     - (라이브러리)KoNLPy
#     - (라이브러리)KRWordRank

# %% [markdown]
# ### 1. 각종 라이브러리 import!

# %%
# 파일시스템 관련
import os

# 데이터 처리 관련
import numpy as np
import pandas as pd

# 텍스트 전처리 관련
import re
import string
from konlpy.tag import Kkma
# stopwords도 알아서 구해볼것

# 데이터시각화 관련
import matplotlib.pyplot as plt
# %matplotlib inline

# sklearn
from sklearn import model_selection
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# __불용어 정리__

# %%
ko_stopwords_raw = """아
휴
아이구
아이쿠
아이고
어
나
우리
저희
따라
의해
을
를
에
의
가
으로
로
에게
뿐이다
의거하여
근거하여
입각하여
기준으로
예하면
예를 들면
예를 들자면
저
소인
소생
저희
지말고
하지마
하지마라
다른
물론
또한
그리고
비길수 없다
해서는 안된다
뿐만 아니라
만이 아니다
만은 아니다
막론하고
관계없이
그치지 않다
그러나
그런데
하지만
든간에
논하지 않다
따지지 않다
설사
비록
더라도
아니면
만 못하다
하는 편이 낫다
불문하고
향하여
향해서
향하다
쪽으로
틈타
이용하여
타다
오르다
제외하고
이 외에
이 밖에
하여야
비로소
한다면 몰라도
외에도
이곳
여기
부터
기점으로
따라서
할 생각이다
하려고하다
이리하여
그리하여
그렇게 함으로써
하지만
일때
할때
앞에서
중에서
보는데서
으로써
로써
까지
해야한다
일것이다
반드시
할줄알다
할수있다
할수있어
임에 틀림없다
한다면
등
등등
제
겨우
단지
다만
할뿐
딩동
댕그
대해서
대하여
대하면
훨씬
얼마나
얼마만큼
얼마큼
남짓
여
얼마간
약간
다소
좀
조금
다수
몇
얼마
지만
하물며
또한
그러나
그렇지만
하지만
이외에도
대해 말하자면
뿐이다
다음에
반대로
반대로 말하자면
이와 반대로
바꾸어서 말하면
바꾸어서 한다면
만약
그렇지않으면
까악
툭
딱
삐걱거리다
보드득
비걱거리다
꽈당
응당
해야한다
에 가서
각
각각
여러분
각종
각자
제각기
하도록하다
와
과
그러므로
그래서
고로
한 까닭에
하기 때문에
거니와
이지만
대하여
관하여
관한
과연
실로
아니나다를가
생각한대로
진짜로
한적이있다
하곤하였다
하
하하
허허
아하
거바
와
오
왜
어째서
무엇때문에
어찌
하겠는가
무슨
어디
어느곳
더군다나
하물며
더욱이는
어느때
언제
야
이봐
어이
여보시오
흐흐
흥
휴
헉헉
헐떡헐떡
영차
여차
어기여차
끙끙
아야
앗
아야
콸콸
졸졸
좍좍
뚝뚝
주룩주룩
솨
우르르
그래도
또
그리고
바꾸어말하면
바꾸어말하자면
혹은
혹시
답다
및
그에 따르는
때가 되어
즉
지든지
설령
가령
하더라도
할지라도
일지라도
지든지
몇
거의
하마터면
인젠
이젠
된바에야
된이상
만큼	어찌됏든
그위에
게다가
점에서 보아
비추어 보아
고려하면
하게될것이다
일것이다
비교적
좀
보다더
비하면
시키다
하게하다
할만하다
의해서
연이서
이어서
잇따라
뒤따라
뒤이어
결국
의지하여
기대여
통하여
자마자
더욱더
불구하고
얼마든지
마음대로
주저하지 않고
곧
즉시
바로
당장
하자마자
밖에 안된다
하면된다
그래
그렇지
요컨대
다시 말하자면
바꿔 말하면
즉
구체적으로
말하자면
시작하여
시초에
이상
허
헉
허걱
바와같이
해도좋다
해도된다
게다가
더구나
하물며
와르르
팍
퍽
펄렁
동안
이래
하고있었다
이었다
에서
로부터
까지
예하면
했어요
해요
함께
같이
더불어
마저
마저도
양자
모두
습니다
가까스로
하려고하다
즈음하여
다른
다른 방면으로
해봐요
습니까
했어요
말할것도 없고
무릎쓰고
개의치않고
하는것만 못하다
하는것이 낫다
매
매번
들
모
어느것
어느
로써
갖고말하자면
어디
어느쪽
어느것
어느해
어느 년도
라 해도
언젠가
어떤것
어느것
저기
저쪽
저것
그때
그럼
그러면
요만한걸
그래
그때
저것만큼
그저
이르기까지
할 줄 안다
할 힘이 있다
너
너희
당신
어찌
설마
차라리
할지언정
할지라도
할망정
할지언정
구토하다
게우다
토하다
메쓰겁다
옆사람
퉤
쳇
의거하여
근거하여
의해
따라
힘입어
그
다음
버금
두번째로
기타
첫번째로
나머지는
그중에서
견지에서
형식으로 쓰여
입장에서
위해서
단지
의해되다
하도록시키다
뿐만아니라
반대로
전후
전자
앞의것
잠시
잠깐
하면서
그렇지만
다음에
그러한즉
그런즉
남들
아무거나
어찌하든지
같다
비슷하다
예컨대
이럴정도로
어떻게
만약
만일
위에서 서술한바와같이
인 듯하다
하지 않는다면
만약에
무엇
무슨
어느
어떤
아래윗
조차
한데
그럼에도 불구하고
여전히
심지어
까지도
조차도
하지 않도록
않기 위하여
때
시각
무렵
시간
동안
어때
어떠한
하여금
네
예
우선
누구
누가 알겠는가
아무도
줄은모른다
줄은 몰랏다
하는 김에
겸사겸사
하는바
그런 까닭에
한 이유는
그러니
그러니까
때문에
그
너희
그들
너희들
타인
것
것들
너
위하여
공동으로
동시에
하기 위하여
어찌하여
무엇때문에
붕붕
윙윙
나
우리
엉엉
휘익
윙윙
오호
아하
어쨋든
만 못하다"""

# %%
ko_stopwords = list(ko_stopwords_raw.split('\n'))
ko_stopwords[:10]
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %% [markdown]
# ### 시작

# %%
df_raw = pd.read_excel("2차통합(리뷰수조정포함)_전체_리뷰데이터.xlsx")
df_raw.shape
# Out:
# (793223, 14)

# %% [raw]
# df = df_raw.sample(frac=0.1, random_state=42) # 10퍼센트만 가지고 진행
# df.shape

# %%
df = df_raw

# %%
# df = df.drop_duplicates() # 중복행 제거
# df = df.dropna()          # 결측치 제거
df.shape
# Out:
# (793223, 14)

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  '상품명',
#  '가격',
#  '총점',
#  '리뷰수',
#  '날짜',
#  '아이디',
#  '별점',
#  '내구성',
#  '가격.1',
#  '디자인',
#  '배송',
#  '좋아요',
#  '내용']

# %%
# 상품명, 아이디, 내용 제외한 컬럼 제거
df = df[['상품명', '내용']] # 선택한 column만 들고온다
print(df.shape)
df.head(2)
# Out:
# (793223, 2)
#                                   상품명  \
# 0  크리스마스 LED 테이퍼 초 블랙폿 테이블 센터피스 장식 소품
# 1  크리스마스 LED 테이퍼 초 블랙폿 테이블 센터피스 장식 소품
#
#                                                   내용
# 0  오브제 덕분에 지인들과 짧지만 좋은 시간을 가졌습니다:) 디테일도 마음에 들고 확실...
# 1  브라운을 시켰는데 레드가 왔구요..보니 빨간 열매 한알이 떨어져있네요 예쁘긴한데 내...

# %%
# column명 변경
df.columns = ['pname', 'review']

# rating 컬럼 숫자로 대체
# df['rating'] = df['rating'].apply(lambda x: x.split('점')[1].lstrip())

df.head(1)
# Out:
#                                 pname  \
# 0  크리스마스 LED 테이퍼 초 블랙폿 테이블 센터피스 장식 소품
#
#                                               review
# 0  오브제 덕분에 지인들과 짧지만 좋은 시간을 가졌습니다:) 디테일도 마음에 들고 확실...

# %% [markdown]
# ### 리뷰 텍스트 전처리

# %%
# 구두점 특수문자 제거
def text_preprocess(text):
    text = re.sub('\[.*!?\]', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text) # 구두점 제거
    text = re.sub('\n', '', text)
    return text

# %%
df['review'] = df['review'].apply(lambda x: text_preprocess(str(x)))
df.head(3)
# Out:
# <ipython-input-19-7ac77e141a2f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].apply(lambda x: text_preprocess(str(x)))
#                                 pname  \
# 0  크리스마스 LED 테이퍼 초 블랙폿 테이블 센터피스 장식 소품
# 1  크리스마스 LED 테이퍼 초 블랙폿 테이블 센터피스 장식 소품
# 2                     도일리 드림캐쳐(2size)
#
#                                               review
# 0  오브제 덕분에 지인들과 짧지만 좋은 시간을 가졌습니다 디테일도 마음에 들고 확실히 ...
# 1  브라운을 시켰는데 레드가 왔구요보니 빨간 열매 한알이 떨어져있네요 예쁘긴한데 내구성...
# 2     저는 속커튼사이에 두려고 구매했어요 생각했던 그대로여서 너무만족합니다 좋은꿈 꾸겠죠

# %% [markdown]
# # konlpy 자연어처리 라이브러리

# %% [markdown]
# ### Kkma, Okt 로 형태소 분해

# %%
kkma = Kkma()
kkma.morphs(u"""배송이 좀 늦네요 ㅠㅠ 하지만 택배포장은 굿입니당""")
# Out:
# ['배송', '이', '좀', '늦', '네요', 'ㅠㅠ', '하지만', '택배', '포장', '은', '굿', '이', 'ㅂ니다']

# %%
from konlpy.tag import Okt
okt = Okt()
okt.morphs(u"""배송이 좀 늦네요 ㅠㅠ 하지만 택배포장은 굿입니당""")
# Out:
# ['배송', '이', '좀', '늦네요', 'ㅠㅠ', '하지만', '택배', '포장', '은', '굿', '입니당']

# %% [markdown]
# __성능 => Okt가 더 낫다!__

# %%
# df['pname'].value_counts().index
df['pname'].value_counts()
# Out:
# 문체어 3colors                            222
# 네이쳐 원목스툴 12colors                      216
# 클린업 터치 휴지통 + 분리수거 비닐봉투 20L 20매입        208
# WH 화이트 원형테이블 800size                   206
# 줄무늬 글라스 유리병 2size                      204
#                                       ...
# 차단이 잘되는 비욘드 화이트 나비주름 쉬폰 먼지없는 항균 속커튼      1
# 다옴 1인 식기세트 6p                            1
# 크리스마스트리 중대형 풀세트 트리 모음                    1
# 심플 모던 깔끔한 화이트 린넨 가리개 커튼                  1
# 앵두전구 크리스마스 벽트리 장식 세트 100구/11m            1
# Name: pname, Length: 360, dtype: int64

# %% [markdown]
# ### reviews -> 한 상품에 대한 전체 리뷰를 리스트화

# %%
reviews = [r for r in df_todo['review']]
len(reviews)
# Out:
# 222

# %%
reviews[:5]
# Out:
# ['배송하루만에 왔네요 펼치면 되는 완제품이구 짐옮기거나 이사할때 짐덩이 안되구 좋아요 양반다리 할정도 크기는 아니지만 베란다에 두려고 일부러 작은사이즈 했는데 불편하지 않아요 체구 있는 신랑도 보기와 다르게 편하대요',
#  '편하게 쉴 수 의자이고 접이식이라서 공간 활용에 좋습니다',
#  '디자인 가격 사이즈 전부 마음에 들지만 뚠뚠이 신랑이 앉기에 약한 내구성과 두개를 구매했는데 한개만 배송 후 홈페이지에 두개 모두 배송 완료라고 표기해놓은 것 때문에 별 두개 뺐습니다 의자는 넘넘 마음에 들어요',
#  '딸 방에 놓으려고 샀는데 울 양이가 더 좋아하는거 같네요 골골거리고 안내려오네요',
#  '그리너리한 느낌 만땅으로 너무 잘어울립니다 감사합니다']

# %% [markdown]
# # CountVectorizer or TextRank + TF-IDF 사용

# %% [markdown]
# ### unigram

# %%
# 캐글발 코드
vec = CountVectorizer(stop_words=ko_stopwords).fit(reviews)
bag_of_words = vec.transform(reviews)
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x:x[1], reverse=True)

# %%
words_freq[:10]
# Out:
# [('좋아요', 55),
#  ('너무', 44),
#  ('생각보다', 43),
#  ('편하고', 38),
#  ('편해요', 28),
#  ('정말', 18),
#  ('ㅎㅎ', 17),
#  ('마음에', 14),
#  ('좋네요', 14),
#  ('샀는데', 13)]

# %% [markdown]
# ### bigram

# %%
vec2 = CountVectorizer(ngram_range=(2,2), stop_words=ko_stopwords).fit(reviews)
bag_of_words2 = vec2.transform(reviews)
sum_words2 = bag_of_words2.sum(axis=0)
words_freq2 = [(word, sum_words2[0, idx]) for word, idx in vec2.vocabulary_.items()]
words_freq2 = sorted(words_freq2, key = lambda x:x[1], reverse=True)
words_freq2[:10] # 상위 10개
# Out:
# [('편하고 좋아요', 10),
#  ('마음에 들어요', 7),
#  ('좋아요 좋아요', 6),
#  ('너무 편하고', 6),
#  ('쓰고 있어요', 6),
#  ('너무 편해서', 5),
#  ('생각보다 너무', 5),
#  ('둥근 디자인의', 4),
#  ('좋아요 짱짱짱좋아요', 4),
#  ('커서 좋았어요', 4)]

# %% [markdown]
# ## Okt 형태소 분석기로 각 리뷰 토큰화한다음 uni, bigram 만들기

# %%
text = reviews[0]
text
# Out:
# '배송하루만에 왔네요 펼치면 되는 완제품이구 짐옮기거나 이사할때 짐덩이 안되구 좋아요 양반다리 할정도 크기는 아니지만 베란다에 두려고 일부러 작은사이즈 했는데 불편하지 않아요 체구 있는 신랑도 보기와 다르게 편하대요'

# %%
text = okt.morphs(text)

# %%
print(text)
# Out:
# ['배송', '하루', '만에', '왔네요', '펼치면', '되는', '완제', '품이구', '짐', '옮기거나', '이사', '할', '때', '짐', '덩이', '안되구', '좋아요', '양반', '다리', '할', '정도', '크기', '는', '아니지만', '베란다', '에', '두', '려고', '일부러', '작은', '사이즈', '했는데', '불편하지', '않아요', '체구', '있는', '신랑', '도', '보기', '와', '다르게', '편하', '대요']

# %%
print(reviews[0].split())
# Out:
# ['배송하루만에', '왔네요', '펼치면', '되는', '완제품이구', '짐옮기거나', '이사할때', '짐덩이', '안되구', '좋아요', '양반다리', '할정도', '크기는', '아니지만', '베란다에', '두려고', '일부러', '작은사이즈', '했는데', '불편하지', '않아요', '체구', '있는', '신랑도', '보기와', '다르게', '편하대요']

# %%
print(okt.nouns(reviews[0])) # 명사만 빼기
# Out:
# ['배송', '하루', '완제', '짐', '이사', '때', '짐', '덩이', '양반', '다리', '정도', '크기', '베란다', '려고', '일부러', '사이즈', '체구', '신랑', '보기', '대요']

# %% [markdown]
# ## 9만여개 리뷰 상품별로 정리하여 리스트로 만들기

# %%
df = df_raw
df.shape
# Out:
# (93976, 14)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (92995, 14)

# %%
df = df.dropna()
df.shape
# Out:
# (92993, 14)

# %%
# df 3컬럼만 빼내기
print(df.columns.tolist())
df = df[['상품명', '아이디', '내용']]
df.shape

# %%
df.columns = ['pname', 'uid', 'review']
df.head(1)
# Out:
#                           pname   uid  \
# 0  디퓨저 리필액 200ml 1+1+1+1 + 캔들증정  톨레란쓰
#
#                                               review
# 0  딱..제가 좋아하는 빨래 향 ㅜㅜ 작은 방에 뒀더니 상쾌한 냄새나요.. 빨래 널어서...

# %%
# 상품명 별로 정렬하기
df = df.sort_values(by='pname')

# 상품개수 몇개인지 알아보기
# df['pname'].nunique() # unique value count
df['pname'].value_counts()
# Out:
# 메리미 이중레이스 암막커튼 3size 3colors                   1000
# 원목 사이드테이블 협탁 (강화유리선반)                          1000
# Romane 발매트 shape type 6종 택1                    1000
# 애슐리 전신거울 3colors                               1000
# 포송 양귀비 가지 조화_7color                            1000
#                                                ...
# 올리브 조화 나무 화분세트                                    1
# 디퓨저 섬유스틱 화이트                                      1
# 행운 4K UHD LED TV 65인치 HW55KUGEL (스탠드 방문설치)        1
# 극강의 편안함 무중력 우주방석 / 강아지방석 (프리미엄_겨울용) 3colors       1
# 달빛식기 전용 유리볼 L (단품)                                1
# Name: pname, Length: 412, dtype: int64

# %%
# text_preprocess()함수로 리뷰내용에서 구두점 등등 제외하기
df['review'] = df['review'].apply(lambda x: text_preprocess(x))
df.head(10)
# Out:
#                                        pname        uid  \
# 14463  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)        서원범
# 14345  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)     mive1y
# 14344  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)  ㅇㅇ1238648
# 14343  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)     pungel
# 14342  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)       듀듀ㄷ두
# 14341  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)       유댕덩덩
# 14340  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)       찡여사_
# 14339  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)       김총명5
# 14338  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)     냐하아ㅏㅏㅏ
# 14337  (1+1) 솔리드 방한 암막커튼 핀형/아일렛형 (작은창/긴창/대형)  gustn9045
#
#                                                   review
# 14463                         암막도 엄청좋고 배송도 빠르고 색도 너무 이뻐요
# 14345  커튼봉이 늦게와서 커튼을 늦게달았는데 저는 너무이쁘고 맘에들거든요근데엄마가 무슨장례...
# 14344                        생각한 그대로이고 주름만 스팀으로 펴면 될거같아요
# 14343             깔끔하고 전체적으로 집이 넓어 보이네요 완전 화이트 원했는데 딱이에요
# 14342  색도 딱이고 두께도 좋아요 저는 암막 목적보다 우풍 막으려고 산거라 살짝 빛은 비치...
# 14341                   화면과 같은 색상이며 빛 차단도 잘 되는것 같아 만족합니다
# 14340  딸아이방에 달아주려 구매하였습니다 넘 핑크핑크하지않고 인디핑크색이라 더 맘에 들어요...
# 14339     좀짧습니다 227 보시면되고 저희집은 층고가 240 은되야해서 좀 짧네요 참고하세요
# 14338  디자인이나 색감 가격 너무 맘에 드는데 반듯한 네모 커튼이 아니라 울퉁불퉁하고 마감...
# 14337                  그냥 그럭저럭 쓸만해요  길이가 쫌만 길었음 좋았을거 같아요

# %%
# 412 개의 상품별 row구조로 변환
df_rev = pd.DataFrame(df['pname'].value_counts())
df_rev.reset_index(level=0, inplace=True) # pname이 index로 가서 index를 column으로 변환시켜줌
df_rev.columns = ['pname', 'count']
df_rev.head(10)
# Out:
#                                        pname  count
# 0                       선데이 러그 7size 4colors  33619
# 1                    순수원목 선반장 4colors (가로2단)  29225
# 2                        오로라 단스탠드(전구 증정 이벤트)  20335
# 3                           애슐리 전신거울 3colors  14545
# 4  집순이 슬리브 옥스포드 삼각 등쿠션 (솜포함, 2size / 6color)  14491
# 5                      소프트 모던 러그/카페트 4colors  14169
# 6                            순수 원목 선반 신발장 2단  11407
# 7           헤링본 사이잘룩 라탄 러그 카페트 4colors 4size   9523
# 8                        BRUG 스탠드 행거 3colors   8957
# 9      가벽인테리어 스트라이프 파티션 4size 5colors(리뷰이벤트)   6457

# %%
df_rev.shape
# Out:
# (3650, 2)

# %%
print(df_rev[:2])
# Out:
#                      pname  count
# 0     선데이 러그 7size 4colors  33619
# 1  순수원목 선반장 4colors (가로2단)  29225

# %%
first_prod = '메리미 이중레이스 암막커튼 3size 3colors'

# pname이 first_prod인 리뷰들을 리스트에 모으기
df_first = df[df['pname']==first_prod]
df_first['review'].tolist()
# Out:
# ['햇빛 암막 100프로 되구요이쁜건 덤이에여 진짜 강추완전강추 이 가격에 이런디자인에 이런 암막기능이면 얼른사야해요집분위기도 완전 호텔방처럼 너무이뻐요👍🏻👍🏻제발 사세요그리고 세로길이는 233cm라고해서 길겟다햇는데 저희집 227cm 밑에가아니고 윗부분이 길어서 다행히 끌리지않고 딱맞는데 잘 보고 구매하셔야할거같아요',
#  '커튼을 잘근 잘근 밟아 왔네요 도저히 드러워서 빨기도 싫고 확인좀 하고 보내지 어떻게 관리하길래 슬리퍼 자국 선명하고 더럽더럽 저런때는 빨아도안지워짐 반품 교환 구찬은데빨리 다시 보내주세요 짜증짜증',
#  '우리집 고영희가 좋아해요 그럼 다 된거에요 이만한 가성비 오지는 제품이 없습니다 판매자님 많이 팔아 부자되시고 건강하십시오',
#  '만족해요 샤라라 하네요 근데 천 질이 그렇게 좋지는 않아요',
#  '환해보이고 싶으면 화이트 추천 입니다',
#  '이걸 도대체 어떻게 설명 해야하는지후배송 받자마자 너무 싼마이가 확어떻게 묶어봐도 싸보여서그 값 한다 생각하다가도 보면 화날정도ㅠㅠ그래서 커튼집 가서 새로 삿지뭐에요 속 천은 폴리천이어서 구김도 바스락바스락 겉 망사는 이걸 어떻게 표현해야되지부드러운 망사가 아닌아너무별로임오늘의집 어플 없애고싶을 정도에요ㅠㅠ 진짜 긍정왕인데ㅠㅠㅠㅠㅠ빨리 새로 산 커튼 왔으면 좋겠어요여러분 사진에 속지말자구여 방금 새로 찍은건데도 그 느낌이 안잡힙니당',
#  '커튼 진짜 이뻐요 진심 웨딩드레스처럼 촤르르 떨어져요',
#  '색도 예쁘고 러블리하고 좋아용 설치도 쉽고 고리형이여서 가려야하나 걱정했는데 커튼이예뻐서 고리도 별로 가릴필요없네요 작은창 용으로도 있으면 구매했을텐데 아쉬워요 ㅠㅠ',
#  '저렴한가격과 이쁜디자인과 빠른배송 너무 마음에드네요 번창하세요',
#  '화이트톤의 암막커튼이라 고민많이했는데 이중으로 레이스도 있어서 인테리어와 사생활보호및 햇빛차단까지 완벽하니 전혀 후회없고 만족합니다 ㅎㅎ',
#  '아이가 무조건이뿐거 고집해서 좀많이망설였어요 아이가좋아하니 나두 좋네요',
#  '우선 제가 설치한곳은 베란다쪽이구요 가로길이 200인데 저는 좀 더 큰평수로 이사갈 계획이라 사이즈를 360으로 구매했어요 당장 살고있는 집은 평수가 작은 원룸이다보니 가로길이 200cm에 사이즈 360짜리 커튼은 한쪽만쳐도 되겠더라구요 저처럼 평수작은 원룸사시는분들 가로길이 200정도 되시는분들 360사면 한쪽만 펼치고삽니다 저는 큰평수로 갈계획이라 상관없지만 암튼 참고하세용 아 그리고 세로길이는ㅠㅠ바닥에 끌려요ㅠㅠ 제가 천장에 못박고 설치한게 아니라 안뚫어고리 사서 연결한거라ㅜㅜ 재질면에서는 최고에요 암막 잘되구요 색감도 예쁘고 레이스가 어우러지니 더 조화로운거같아요 굿굿굿bbb',
#  '집안분위기가너무이뻐요 커튼으로인테이러했어요 감사합니다',
#  '커튼을 처음달아보는거라서 이것저것 많이 고민했어요 이제품을 보고 이거구나 싶어서 고민없이 선택했습니다 그이유는 첫째 가성비에요 가격이 하얀색커튼바탕에 그위에 레이슨데 과하지않고 차르르해서 정말 맘에 들더라구요 정말 다른사람 말대로 웨딩드레스 같아요 ㅋㅋ 집 거실에 하얀색으로 해놓으니 환해지고 깨끗해보여서 정말 강추해요 제가 원한 화이트 입고가 느려서 기다리다가 주문했는데 하루만에 배송와서 정말 깜짝놀랐어요 그만큼 배송이 빠릅니다 이제품은 제친구한테도 추천했어요',
#  '역시 리뷰대로 예쁘네용 최고에용 근데 좀 길어요 ㅠ',
#  '암막커튼인데도 하나도 안답답해보이고 너무예뻐요',
#  '넘나 예뻐요ㅠㅠ 진짜 촤르르 샤랄라ㅠㅠ 설치하기도 쉽고 분위기도 대박입니다',
#  '이게 8만원이라니 대박 진짜 가성비갑개예쁨',
#  '베이지 살까 화이트 살까 엄청 고민했는데 결론은 화이트 사세요 분위기 첵오입니다ㅠㅠ흰색벽지면 화이트 사세요 방 벽지랑 톤이 같아서 그런지 더 화사해보여요 길이도 딱 맞고 맘에 아주 들어요',
#  '가격대비 진짜 최고인거 같아요 진짜 설치하고 보니까 너무 맘에 듭니다',
#  '색감은 은은합니다 조명에 따라 다르네요 베이지계열 좋아해 나름 만족하지만 구김이 조금 아쉽네요',
#  '이 가격에는 살수 없는 상품이에요 너무 얇지도 않고 두껍지도 않고 암막이라고 해서 너무 깜깜하지도 않고 근데 검수가 좀 안됐는지 누가 밟은것 마냥 검은색 때 탄부분이 있어서 별하나 뺐습니다',
#  '드레스룸에 찬기 차단 및 창문 가릴려고 삿는데 드레스룸이 정말 너무 예뻐졋어요',
#  '너무 맘에들어서 감탄만 나와요 또 구매할게용',
#  '처음 배송받았을때는 냄새가 너무심했는데 하루지나니까 점점 괜찮아졌어요 그리고 가까이서 만져 봤을때는 저렴한 느낌이 없지않아 있는데 전체적으로 보면 너무이쁘고 가성비 좋아요 햇빛 비추면 샤랄라한게 맘에 들어요😄😄',
#  '어머니 방 커튼 바꿨어요이쁘고 보온효과도 있구요 만족하셔서 저도 기뻐요',
#  '너무너무 만족스러워요 빛도 적당히 차단되고 방분위기도 예뻐진것같아요',
#  '너무 이쁘네요 일단 배송이 너무 빨라서 좋았구요 후기처럼 화이트가 집 분위기를 너무 밝고 고급스럽게 만들어 주는거같아요🤍옆에 행거 설치했더니 쇼룸같다고 하네요',
#  '제 잘못입니다ㅜㅜ 264라고 해서 264가 두장인줄 알고 주문했는데 132가 두장 총 264라는ㅜㅜ 그래서 딸 방으로 보냈어요ㅜㅜ 가격대비 별로입니다',
#  '거실 분위기 바꿔보려고 크림베이지로 꾸며봤어요 뭐괜찮네요',
#  '사실 사이즈 두번째거 사고팠는데 품절이기도했고 집이 작아서 맞겠지싶어 작은거라도 주문했는데 설치하고나니 가로길이가 짧더라구용 ㅇㅅㅇ흑흑 환기시키려고 창문열기위해 의도한거라며 자기위안즁입니다ㅋㅋㅋ 그래도 너어무 이뻐요 ㅠㅠ 집 분위기가 바껴버렸어요 진짜 구매하길 잘한듯ㅠㅠ 통유리 오피스텔사는분들은 두번째사이즈 구매하시길',
#  '사진이랑 너무 다릅니다 싼티가 너무납니다 그리고 이물질도 검은색으로 묻어있었고 귀찮고 이왕단거 대충 쓰고 다른것으로 교체하려고 합니다',
#  '너무 좋아요♡ 커튼하나에 분위기 싹 바꼈어요 이사와서 제일 잘 산 물건중 하나네요ㅋㅋ 근데 실밥이 넘 많아요ㅠㅠ 마감처리가 아쉽네용 커튼 끈 다는것도 없어서ㅠㅠ 커튼끈은 서랍으로',
#  '배달을 이런식으로 실망입니다',
#  '화이트를 구매한 사람들이 훨씬 많고 리뷰가 많이 올라와 있지만 화이트는 너무 부담스러워 망설이고 고민하다가 배이비핑크로 구매했는데 너무 만족합니다 핑크를 원래 좋아하는 사람은 아닌데 이 베이비핑크는 약간 톤도 다운되어 있고 은은한 핑크라 마음에 들어요 햇빛이 비치는 낮에 찍은 사진인데 암막정도는 저 정도로 나옵니다 완전 깜깜 암막은 아니지만 저는 개인적으로 만족해요',
#  '이뻐여 인테리어 효과도있구 맘에듭니다',
#  '집분위기가 공주공주하네요 ㅎㅎㅎ조아요',
#  '최고네요  무조건 사심 후회없는 상품이에요',
#  '집이 화사해지고 너무 이뻐요😍😍 커튼 묶어놓으니 더 이쁜거 같네요',
#  '상품평이많은건 다 이유가 있더라구요 무조건 대박입니다 낮에도 너무좋아요 햇빛찬단되면서 집안은 밝고 너무좀아요',
#  '안방커튼으로 너무 이쁘네ㅣ요 분위기있어요',
#  '크기를잘못해서 다시주문했어요 화이트 깔끔하니이쁘네요 조금길어서 끌려서아쉬워요',
#  '만족합니다 최고큰거샀더니 중간사도될뻔했어요만족합니다',
#  '확장한 거실이라 베란다에서 들어오는 바람을 막을려고 샀는데 바람도 잘 막아주고 거실 분위기도 아늑하게 만들어줘요 제일 큰 싸이즈 했는데 25평 거실에 딱 맞네요',
#  '3년된 커튼을 해치우고 계속 고르다가 알게됐음 이가격에 아주 훌륭해요 아주깔끔하게 잘어울리네요 길이가 좀 길어서 끌리지만 뭐 그정도쯤이야 짧은것보단 낫죠 ㅎㅎ 반대편 창도 할까해요',
#  '커튼봉이 좀 허술한것 빼고는 이쁩니다 마음에 들어요',
#  '암막커튼이라 빛 차단도 잘 되고요 바람도 막아죠서 따뜻하네요 괜찮아요',
#  '암막커튼과 레이스가 같이 붙어있어서 따로 쓸수 없는 부분이 아쉽지만 예쁘게 잘쓸수있을것 같아요',
#  '너무 이뻐요 주위에선 흰색이라 관리할수 있겠냐고 하지만 진심 너무이쁘고 집도 밝고 따뜻해보여요',
#  '구김도 많지 않게 와서 일 덜었습니다 100프로 암막보다 약간 빛이 비치는게 더 마음에 들어서 구매했는데 정말 마음에 들어요 이중이라 확실히 포근한 느낌이 더 들어요 커튼 두개 달기는 애매한데 분위기 연출하고 싶은 분이라면 적극 추천드립니다 완전 만족하구요 커튼 볼때마다 기분이 좋습니다',
#  '생각보다 집이랑 잘 어울립니다 잘산거같아요',
#  '저희집엔 좀 길긴 하지만 끝부분까지 막을수 있어 좋아요 완벽한 암막은 안되고 좀 밝아요',
#  '하얗고 예뻐요  암막커튼도 빛이 잘 가려지고 좋습니다',
#  '안방에 걸었는데 화사해서 집콕생활이 즐거워 졌어요',
#  '999프로의 암막이라고 해서 기대많이했는데 위에눈 조금 뜨니 어쩔 수 없지만 창문쪽도 아무래도 밝은톤이라 어쩔 수 없이 완벽히 차단은 어렵군요 ㅠㅠ 하지만 은은히 따뜻한 느낌을 받는듯 합니다 어제 저녁에 도착하여 바로 달고 너무 아늑해진 방에 놀라며 연신 대박 너무이쁘다를 외쳤으나 아침에 일어나서 보이는 저 희미한 가로줄이 거슬리는 건 어쩔 수 없겠지요ㅠㅠ 안에 암막층이 나뉘어져서 저리보이는것일지 일일이 저 큰 커튼을 다 암막체크해보며 할 순 없겠지만 자꾸만 눈이가는 저 가로선 개인적으로 상당히 거슬려 만족감이 점점 떨어지는 느낌이지만 집 구조상 신랑이 아주 어렵게 달아줘서 다시 떼어 반품하기 어려울듯 하여 아쉬운 평을 남깁니다 남기면서도 눈이가는 가로선 다좋은데저 가로선 ㅠ',
#  '햇빛을 잘 가려주고 레이스 이중이라 예쁨니다 화이트랑 고민하다가 베이지 샀는데 이것도 분위기 있네요',
#  '리뷰 잘 안쓰는데 너무 예뻐서 작성합니다화이트로 사라는 리뷰 보고 고민 없이 구매했는데 너무 마음에 듭니다 번창하세요',
#  '안방 커튼으로 굿이네요 화이트로 하길 잘 한것 같아요 밤에 빛 차단률90 정도 되는것 같아요 배송도 빠르네요 강력추천합니다♡',
#  '와 너무 예뻐요 전 사실 좀 얼렁뚱땅이라 하자 이런거 별로 신경쓰지 않는데 흘깃 봤을때 하자나 얼룩 하나도 없었고 그냥 끝장납니다 방 창문이 너무 별로라서 아예 벽 한면을 커튼으로 가려버릴 생각에 산 건데 달자마자 방이 확 밝아지면서 그냥 스튜디오 분위기 뿜뿜 최고입니다 할인 들어가서 완전 좋은 가격에 좋은 커튼 득템했네요 번창하세요',
#  '예뻐요 ㅎㅎ 흰색은 딱 흰색치고 암막이 잘 되는 편 정도이고 완전 차광은 당연히 아니에요',
#  '깨끗하고 좋아요 방이 환해져서 딸이 좋아해용',
#  '최고최고예용 전세집들어가면서 이쁘게 꾸미고싶었는데 커튼이 제일 큰 몫하는거같아요 체리몰딩에 오래된건물이라 막막했는데 아주 완벽하게 가려주네요 ㅎㅎ맘에듭니다',
#  '다 좋은데 구김이 너무 심해서 ㅠㅠㅠ 다림질 하는게 힘들어써염 ㅋㅋ',
#  '암막도 잘 되고 화이트라 집 분위기가 화사해져요넘 맘에 들어요',
#  '실물이 더 예뻐요 아늑한 느낌이 듭니다 가격도 착하고 질도 좋고 암막 잘됩니다 많이 파세요',
#  '집이 좁아서 그런지 레이스가 과해보였어요 ㅠ 기대 많이 했는데 마음엔 안 들더라고요ㅜ 베이지색이라서 그런가 화이트면 달랐을지도 몰라요 그래도 암막이랑 가성비갑이네용',
#  '흰색살까 베이지살까 엄청 고민하다가 베이지 선택 집이랑 찰떡으로 잘 맞아요 근데 커텐 너무너무 이뿌긴 한데 짧아서 슬프네요 ㅜㅜ 바람막이겸 암막겸 산거였는데 바람이 솔솔 들어와요ㅠㅠ',
#  '다른건 괘찮은데 길이가 집은 230인데 233이라 생각했던 것보다 바닥에 더 끌리네요ㅜ',
#  '사진을 못 찍었는데 이쁘네요 막상 개봉했을때는 순간 잘못 선택했나 싶었는데 막상 설치하고 보니 예쁘네요 만족합니다',
#  '커튼 진짜 고민 많이하고 비교 많이해봤습니다 겉커튼 속커튼 다 하려니 비용이 후덜덜하더라구요 이 커튼은 디자인도 나쁘지 않아보이고 한 커튼으로 이중 커튼 효과를 볼 수 있고 가격이 13로 줄어서 샀습니다 받기 전에 잘못 선택한 건 아닐까 ㅠㅠ 색깔도 고민 마니 했는데 베이지가 너무 누렇지는 않을까 했는데 달고 나니 괜찮네요  인테리어 예산이 넉넉했으면 더 좋은 것 샀겠지만 가성비 너무 괜찮은 선택이었던 것 같습니다',
#  '가성비좋고 예쁜커튼이에요 이중이라 보온성 좋을것 같고요',
#  '적당히 은은하게 빛 차단과 지루하지 않게 2중이라 레이스 커튼을 하고 싶었던 만족감도 어느정도 채워줘요 아쉬운건 무게추가 없어서 양쪽 시접쪽이 좀 당겨 올라가서 자주 잡아 당겨요',
#  '너무 이뻐요 봉타입하나에 커튼을 이중으로 사용할 수 있다는게 정말 좋은 아이디어같아요 가격대비 재질도 무난히 괜찮습니다 흰색이라 완전 암막은 되지 않는데 저는 구매 할때부터 빛이 조금은 비쳤으면 했기 때문에 아주 마음에 듭니다',
#  '가격대비 좋아요 안방에 달랐어요 해가 많이들어 은은하니좋넹ᆢㄷ',
#  '넘예버요가성비 갑이에요 저희집 커텐은 다 까르데코인데 다 맘에쏙들어요 ♥',
#  '두께감 있음 저렴해보이지 않음 디자인 가격 모두 만족',
#  '360짜리했더니 길이만 살짝긴데 길어서 더 예쁜거같아요 폭은 맞춘것처럼 딱맞네요 집이 어두운편이라 화이트했더니 화사해졌어요 암막도 확실히되구요 이중망사커튼이 너무 러블리해서 볼수록 예뻐요 암막커튼도 이렇게 예쁠수있구나싶네요 감사합니다',
#  '답답한걸 싫어해서 커튼 없이 계속 살았는데 오늘의 집에서 우연히 이 커튼을 발견하고 고민하다 주문했어요 창밖으로 밖을 보는게 속이 시윈하다 생각했는데 커튼을 쳐놓으니 아늑하고 집이 더 밝아진 느낌이예요 아이들도 좋아해요',
#  '두번째 쓰는 커텐이예요 거실에 먼저 사용하고 안방에 이번 설치했어요 암막 기능은 최고입니다',
#  '배송도 엄청 빠르고 분위기 갑입니다 커텐 하나 바꾼거 뿐인데 너무 예뻐여',
#  '침대헤드쪽 찬반람이 확실히 없어졌네요 블링한게 깨끗한 흰색이설치하니 이쁘네요',
#  '커튼사는 김에 함께 구매했는데 봉은 모던하우스가 더싸네요 ㅎㅎ',
#  '샤랄라 한게 맘에 들어요 커튼하나로 분위기가 달라졋어요',
#  '가성비 최고에여 커튼하나로도 집분위기가 달라지네여 이가격에 이 디자인에 딱이에요 안방에 걸었는데 사이즈도 딱맞아요 러블리해보여요 ',
#  '음암막까진햇빛비칠때그냥햇빛이살짝막아주는정도흰색이라서그러는거같네요암막부분은조금아쉽습니다',
#  '길이 잘 보고 구매하세요 결국 못 박았습니다',
#  '이음새가 보이긴 하지만 이 가격에 훌륭해요 다림질만 좀 해놓으면 넘 이쁠거 같아요',
#  '생활 암막 정도 이며 레이스가 붙어잇어서 너무 이쁘고 길이도 제작주문도 아닌데 딱 맞고 너무 이뻐요 ㅠㅠㅠㅠ❤️❤️👍👍👍👍역시 커튼은 여기꺼가 채고에욤😋😋',
#  '배송 진짜 빠르고 커텐 너무 이뻐요 딱 제가원하던 느낌입니당 ㅎㅎ',
#  '너무 분위기있고 멋스러워요 분위기가 확 다르네요배송두 무지 만족하고 추천합니다',
#  '맘에쏙들어요 빛도많이가려지고 좋아요',
#  '너무 이뻐요 사이즈도 잘봤어요 강추합니다',
#  '방에 걸어 놓으니 분위기도 다르고 예뻐요 가격대비 만족입니다',
#  '진짜이뻐요 근데비싸요 ㅠㅠ 이쁘고튼튼한편',
#  '예쁘고 좋아용 맘에 쏙 드네요 ㅎㅎㅎ',
#  '거실엔 레이스커튼이랑같이달았는데 서향이라 햇빛을딱 기분좋게 가려줘요 안방은 더큰싸이즈로바꾸었는데 길이는 조금짧은감이있으나 오히려더먼지끌리지않아 좋네요 가격은조금비싼것같은데 뭐맞춤에비하면싸니까만족해요',
#  '두껍고 너무 이쁩니다 ㅎㅎ 가성비좋음',
#  '저렴한가격에 잘 샀어요 방안이 환해진 느낌이에요',
#  '이것도 정말 잘샀음 추천합니다',
#  '전에 핑크였는데 화이트로바꾸니 더욱 화사하네요 마음에 듭니다 근데 끈이 틀어져 있어 잘 다려도 해결될런지 커텐은 예뻐요',
#  '가성비 갑 인정이요 너무 이뻐요',
#  '너무예쁘네요 배송도 빠르고요 암막이중커튼이라 혼자달긴 쪼꼼 힘들긴했는데 이번겨울 따시게 날수있겠어요',
#  '와이프가 너무 원해서 샀는데 실제 설치까지 하니 방벙뛰네요 이쁘다고 ㅎㅎ',
#  '천장이 조금 낮아서 바닥에 끌리지만 너무 만족합니다̆̈ 원단도 부드럽고 암막률도 나쁘지 않아요 다만 화이트라 빛투과율이 높은 편이라 안쪽에 소창용 암막커튼을 겹쳐 달았답니다̆̈ 낮에도 어두워서 굉장히 맘에 듭니다₍₍  ๑॔˃̶◡\u200a˂̶๑॓◞♡',
#  '너무 예뻐서 집에 분위기 살리는데 한몫하고 있어요 거실이랑 안방꺼 두 개 구매했어요 거실은 하얀색 안방은 핑크색인데 넘 예쁘고 레이스도 좋아요👍',
#  '커튼덕분에 거실이 너무 예뻐졌어요 감사합니다',
#  '배송도빠르고가격도저렴하고좋아요일단두가지버전으로쓸수릿어서조음',
#  '너무 예뻐요 바람도 잘 막아주고 공주방 된 기분이에요',
#  '기장감이 좀길어서 세련된 느낌은 앖는데요분위기는 한결 안정감이 있어서 좋아요',
#  '진짜 실물이 훨씬 더 예쁘네요 너무너무 맘에 들어요 배송도 빨랐어요',
#  '너무 마음에 들어요 색깔도 길이도 딱 맞아요 풍성해보이기도 하고요 가성비도 짱이구요 감사합니다♡',
#  '사진보다 실물이 훠어얼 이쁨 아주 고급짐 맘에 쏙',
#  '너무이뻐요 싸게 잘삿습니당 두께도 두툼하고 울코스로 돌리니 변형도 없어용',
#  '샤랄라 분위기있고 넘 이뻐요 다소 길이가 길어 바닥에 끌리지만 그마저도 이뻐보이네요 근데 오늘보니 세일을 더 하네요 저렴한 가격에 득템했다 좋아라했는데 속상해요ㅠㅠ',
#  '속 커튼이 약간 모기장느낌이라 생각과는 달랐어요 그리고 밝은색이라 암막이 거의 안되는데 너무 햇빛 안 쏟아지는 선에서 밝아지는거라 암막 잘 되는거보다 나은가같아요 밤보다 낮에 빛들어올때가 더 예쁘네요',
#  '이전에 집에 사고 너무 맘에 들어서 선물용으로 한번더 주문햇는데 지인이 맘이 든다고 난리네요 너무 이뻐요',
#  '완전 마음에 듭니다 ㅋㅋㅋ길이가 조금 길어서 아쉽지만 ㅠㅠ',
#  '고급스럽고 예뻐요 설치도 쉬웠어요 배송도 다소 빠릅니다',
#  '커튼 진짜 이쁜데용 너무 이버여 아늑한 느낌도 들고 따뜻해지는 기분까지  다만 밑에가 좀 짧은데 강아지 키워서 더 낫겟다 싶어요',
#  '깔끔하고 하늘하늘하고 아늑해서 너무좋아요',
#  '좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ',
#  '가로 265 세로230 사이즈로 10자 구입했는데 딱맞네요',
#  '암막기능도있고 가볍고 가격도 착하고 너무 좋아요 무엇보다 봉이라는게 가장 맘에들어요',
#  '지금까지 산커튼중에 제일 예쁨',
#  '저렴한 가격에 잘산것같어요 방안이 한결 화사해지고 예쁩니다',
#  '아이가 좋아하네요 괜찮아요좋아요 만족해요',
#  '길이가 조금 길긴한데 깔끔하고 괜찮아요 가성비 좋구요',
#  '너무 예뻐서 지인한테도 추천했어요',
#  '가성비 최고입니다 암막기능도 베이지인데도 괜찮습니다',
#  '안방 분위기에 잘맞아요 단독주택이라 길이는 좀 짧은듯 한데 그래도 어색하지않고 잘 어울리네요',
#  '좋아요 아주 잘 사용하고 있숨달 감사합니댱',
#  '길어서 좋아요 봉이 두께가 있어서 얇은 커튼봉 고리 에는 안들어가요',
#  '예뻐요 거실에는 안어울려서 부모닝방에 설치했는데 부모님방이 확 사네요',
#  '가성비가 좋아요 하늘하늘 예뻐요 길이가많이 긴 점 참고하세요',
#  '커튼 깨끗하게 잘 받았습니다 생각보다 많이 무겁지는 않아서 좋아요 집에 창문으로 바람이 많이 들어와서 설치했는데 역시 화이트로 하니까 환해보이고 깔끔해보여서 만족합니다',
#  '사이즈 안맞을까봐 걱정했는데 다 설치하니깐 예쁘네용 거실 창문에 특대형으로 하니깐 맞아요화이트 커텐때문에 거실 분위가가 환해졌어요',
#  '주문하고 2일 만에 받았어요 생각보다 박스 규격이 커서 놀랬지만🤣 빠른 배송에 너무 만족스럽네요 아직 세탁망이 안 와서 제대로 된 사진은 없지만 세탁 후 거실이 어떻게 변할지 벌써부터 기대되네요😏😏',
#  '생각보다 길어서 바닥에 좀 끌리네요ㅜㅜ',
#  '아직이사전이라서 설치는 못하구 박스만 뜯어서 봤어요 펼쳐보지않아도 리뷰가 장담해주리라 믿고 있습니다 새하얀 커튼 거실에 달면 화사할 것 같아요',
#  '저는 사실 리뷰도보고 이쁘다 하시는분들 대부분이라 구매는 햇는데 사진들이 너무 이뻐 보였네요 그래두 만족합니당',
#  '예뻐요ㅜㅠㅜ 공주님 방 같애졌어요 존예 가격도 싸고 다들 사세용',
#  '빠른 배송 깔끔 가격대비 가성비 갑 너무 만족해요',
#  '적당히 암막되서 넘 좋아요 이쁘고 싼티안남',
#  '안방커텐으로 정말 좋아요 분위기있고 그냥 암막보다 훨씬 인테리어에 좋습니다 해도 적당히 은은하게 들어오구 우선 그냥 너무 예뻐요 ㅋㅋ',
#  '후기보고 살까말까 고민 많이 했지만 좋은후기들이 더 많아서 구매했어요ㅎㅎ 커튼봉이 아직 안와서 설치를 못했지만 이쁘게 달아서 나중에 더 좋은후기 남길게요',
#  '리뷰에 사진이 다 그닥안이뻐보였는데 생각보다 튀지않고 이쁘네요 고양이도 좋아해요',
#  '커튼도 방 분위기 바꾸는데 최고인 것 같아요 샤랄라 합니다',
#  '완전한 암막은 아니지만 가격대비 만족하구요 레이스 끝부분 박음질이 촘촘해서인지 양쪽 다 울어 반품하려다 설치후 알아서 걍 씁니다',
#  '배송도 하루만에 와서 좋았고 커튼도 예쁜데 부족해요ㅠㅠ 사이즈 재고 샀는데 무거워서 더 사지는 못하겠지만 그래도 전체적으로 만족해요',
#  '좀 뭔가아쉬움 기장도 잘못재서 짧아요',
#  '처음엔 너무 하얀색이라서 조금 후회했음 뭔가 집에 커텐만 붕떠있는 느낌ㅜㅜ 그런데 아침에 빛을받은 커텐의 모습이 너무예쁨 잘쓸게요',
#  '가격이랑 커튼 설치하는거는 정말 간편합니다 근데 밑위 길이가 230m 인데 30cm정도 끌려서 그게 좀 너무 아쉽네여 자르면 끝처리가 이상해 질까봐 이도저도 못해여 밑위길이만 잘 맞으면 너무 이쁠거 같아여 디자인 보고 샀는데 레이스가 쭈글거라는거 빼고는 맘에 듭니다 기대했던것보다는 사알짝 아쉬움이 조금 큽니다 ㅠㅠ',
#  '530짜리는 브라켓이 1개 더 필요할 것 같아요 무거우니까 중간부분이 대가 쳐져요',
#  '밝은색상이라 암막은 덜한것같지만 예쁘네요',
#  '풍성한게 좋아서 2장 구매했고 4쪽이 왔습니다 화이트이고 원단도 두꺼운편은 아니라 암막과 방한은 거의 안된다고 보시면 될꺼같아요 포장왔을때 있던 구김도 잘 안펴져서 구김도 많은 편이고 레이스도 약간 두꺼운 망사부직포 스탈이라 주름도 예쁘게 접히지도 않아요 뭐 그럼에도 불구하고 이중레이스라 일반 솔리드보다는 디자인 나쁘진 않습니다',
#  '배송은 빨리 왔고 색상은 생각했던것 보다는 약간 무거운 핑크 느낌이예요 그래도 차분한 분위기를 연출해주어 좋네요',
#  '상품평이 좋아서 기대 많이 하고 샀는데 기대이상입니다 암막이 장난 없습니다',
#  '아직 설치는 안했는데 언넝 달아 보고 싶어요',
#  '너무 예뻐요 생각보다 암막 기능은 크진않은데 감안하고 화이트 구매한거여서 만족합니다',
#  '완전이쁘요ㅎ 저렴한가격에 잘구매한것같으요',
#  '디자인은 샤랄라하고 이쁜데 암막커튼이 암막이 안돼요 아침에 해가뜨면 환해져요 그냥 예쁜커튼으로 생각하면 될듯',
#  '조금 구김이 있지만 이정도면 괜찮아요 암막도 잘되고',
#  '새로 이사를해서 분위 전환삼아 샤랄라커튼이촤아 가격대비만족합니다',
#  '이사하면 쓰려고 모셔뒀다가 이제야 설치 했어요 수령하고 너무 하얀거 아닌가 교환을 망설였는데 많은 후기들 보면서 일단 달아보자 했어요ㅎ 확실히 넓어보이고 화사하니 좋네요 두겹이라 여러가지 연출도 가능하고 이렇게 해두니 해도 잘 들고 사생활보호도 되고 넘 좋네요',
#  '여자 혼자 설치 가능 의자밟고 올라가서 했네요 길이가 좀 길었어용 전 땅에 끌리는거 싫어해서 수선맡겼네요 드릴만있으면 혼자서도 설치 가능해용ㅇ 화이트로 샀는데 거실 분위기 확 살고 암막까지되니 넘좋아요 너무이뽀여 배송도 빨랐음 최고💛',
#  '무난한거 같습니다 가성비 제품이에요',
#  '생각했던 면은 아니지만 흰색인데 암막도 잘되고 공간느이 넓어보야요',
#  '커튼봉이 생각보다 약해보이긴한데 조립하긴 편했어요 커튼이 구겨져서 와서 주름져서 좀 밉긴한데 마음에는들어요',
#  '기대안했는데 안막이 은근 잘되더러구여 그래서 좋운고겉아요',
#  '암막효과 최고 디자인도 촤르르 고급스러워요',
#  '거실 크기에 딱 맞네요상품 구성이 마음에 듭니다배송도 빨라요ㅎㅎ',
#  '암막은 비교적 잘 되는데 속커튼 재질이 좀더 부드러웠으면 하는 아쉬움이 있네요',
#  '암마커튼이랑 레이스 커튼 두가지를 원했는데 진짜 생각했던 그대로를 한꺼번에 만족시켜줬어요 흰색은 암막이 아무래도 아쉬울거 같아서 베이지 선택했는데 아주 만족합니다',
#  '정말 커튼하나로 분위기 완전 살아요 ㅎㅎㅎ 레이스 묶을 때 풀때 느낌달라서 다양하게 연출할 수 있고 화이트 깔끔하고 고급스럽네요 레이어드 된거 따로안사도 되고 이정도면 가격도 착하다고 생각합니당 ㅎㅎ 거실 창이 가로 3미터 60정도 되서 530사이즈 샀습니당 참고하시길',
#  '커튼하나로집이화사해지네요 소재는암막이라서그런지약간아쉽긴한데 디자인이너무마음에들어서 괜찮아요ㅋ',
#  '배송도빠르고 완전예뽀요 맘에들어요 ㅎㅎ 커텐봉고리듀 이미 뚫어진상태로와서 너무편하게설치햇어요',
#  '이뻐요 안방도 해가너무잘들어와서 더할라구요',
#  '택배온거 풀어봤을때는 아 괜히 샀구나 싶었는데 설치하고 보니 예쁘네요 가격대비 만족스러워요 아직 창문 하나 더 남았는데 핑크로 하나 더 사야겠어요',
#  '기대이하에요 구매가격보다더싸보여요ㅜㅜ',
#  '진짜 넘 예뻐요ㅠㅠㅜㅜ길이도 딱 맞고 아주 나이스입니당',
#  '적절한 암막 너무 좋아요 색도 마음에들고 디자인도 이뻐용',
#  '조아여 졸라 고급스럽고 ㅠㅠㅠ 아름다워여',
#  '제 자취방에는 조금 길어서 밑에 잘라야 할 것 같지만 예뻐요',
#  '배송받고 색깔이 첨엔 맘에 안들었는데 막상 설치하고보니 넘 맘에 드네요완전 분위기 깡패네요오늘 낮 12시에 찍었습니다햇볕이 좋은집이라서 암막기능이 어느정도 되는것같아요',
#  '고급스럽고 디자인 심플해서 좋아요 너무 어둡지도 않고 포근해보여요',
#  '가격도 착하고 배송도 빨라요굿',
#  '칼블럭이없이 배송되네요 피스도짧아서 힘을잘못받아서 결국다이소가서 구입후설치했습니다 나머지는 너무좋네요',
#  '너무이쁜데브라켓 길이를 생각못했네요조금끌리지만 딸방에 걸었는데 너무 만족 해요',
#  '암막커튼이랑 함께있어 빛차단도 적당하고 좋아요',
#  '왜 예쁘다는 댓글이 많을까요 내눈이 이상한가 레이스는 뻣뻣한 모기장같고 설치해보니 한복속치마같아서 아이들이 소복같다고 놀려요 걸어서 어떤지 보려다가 먼지가 묻고 약간 긁히는 바람에 반품도 못하고 당첨ㅜㅜㅜㅜㅜㅜㅜ 그나마 후사고리로 정리해놓으니 볼만은 합니다만 걍 맞출걸하는 후회가 드네요',
#  '배송도 빠르고 가격도 좋고 아주 예뻐요 ㅎㅎ',
#  '햇빛 비추면 이정도 되네요 만족합니다',
#  '끝부분이 좀 어색한거 같아요 흰색인데 암막잘됩니다',
#  '처음엔 좀 약해보였는데 설치해보니 안정감있어요 너무 이쁘네요',
#  '커튼 너무이뻐용 잘산거같아용 너무마음에 들어요',
#  '화이트 샀어요 예쁘고 우아합니다 맘에 쏙 들어요',
#  '베이지랑 화이트중에 엄청 고민하다가 베이지 선택했어요 아늑하고 따듯한느낌이 좋으면 베이지강추입니당',
#  '이사하면서 커튼이 필요해서 구매했어요 화이트 커튼은 처음 써보는데 때가 탈거같긴하지만 너무 이뻐서 만족합니다',
#  '여러상품 둘러보다 후기 꼼꼼히 살펴보고 구매했는데 정말 만족스러워요이 가격에 이런 디자인이라닝ㅠ❤️나중에 커텐 살일이 있으면 재구매할게용',
#  '거실에 딱이에용 넘 깨끗하면서 세련되보여용',
#  '다른곳에서 사고 너무실망해서 반품하고 다시 찾다가 원하던 커튼을 찾은거 같아서 바로 주문했어요 여유있게 했다고 했지만 더 크게 잡고 주문했으면 좋았을거같지만  그래도 충분히 맘에 들어여',
#  '사진찍으면 이뿌게 잘나와요 원래 어두운 암막커튼 이용했는데 커튼 바꾼 후로는 밝아서 정말 일찍 눈이 떠져요 암막도되고 레이스도있어서 일석이조에요 하얀방을 만들고싶었는데 만족합니다',
#  '흰색 커튼이 거실 넓어보이게하는 효과도 있고 넘 좋아용 다만 재질이 쉬폰이 아니라 생각보다 까끌까끌한 모시같은 재질이라 가까이서 보면 주름 티가 좀 잘나네요ㅠ 잘 안묶어둬요',
#  '역시 커튼은 화이트♡ 이뻐서 미친것같음',
#  '저렴한 가격에 예쁜 커튼 득템했네요 세로 길이가 짧을까 걱정이었는데 맞아 너무 좋으네요',
#  '베이비핑크 아니고 인디핑크 입니다 볕 들어오면 베이비핑크일 것 같지만요 설치 쉽구요 암막인데 무겁지도 않구요 샤가 너무 이쁘네요 ㅎㅎ 세일할때 언능 사세요ㅎㅎ',
#  '혼자서도 쉽게 설치했어요 예쁘게 잘쓸께요',
#  '앞쪽이 화이트 뒷쪽이 크림베이지에요 어둡게 하고 촬영해서 느낌이 안사는데 암막도 잘되고 분위기도 따뜻해졌어요',
#  '사진하고 똑같이 너무 예뻐요 흰색이라 암막은 완벽하지 않지만 감안하고 산거고 분위기 있고 한번에 설치 가능해서 일석이조에요',
#  '깔끔함을 원해서 구매했어요 진짜 깔끔 길이가 좀더 길었으면 약간의 아쉬움이 있네요',
#  '커튼 레이스 같은 얇은 천이 안쪽으로 들어와야 되는데 바깥으로 가게 달았는데 귀찮아서 안바꾸고있어요 이게 더 이쁜거같기도하구요 흰색커튼이라 완전 암막은 안되는데 되게 은은하게 햇볕 들어오는게 더 좋더라구요 디자인도 너무너무 예뻐서 창 크고 높은 층 사시면 꼭 사세요 바깥뷰하고 너무 잘 어울려서 좋아요',
#  '분위기 갑 설치도 쉽고 냄새도 안나서 좋았어요 배송도 빠르고 다 좋아요 ',
#  '설치도쉽고 이뻐요 깔끔하네요 베이지보다흰색이이뻐요',
#  '색감이너무이쁘고 좋아요 진짜 이뻐요',
#  '정말예뻐요 햇빛도 은은하게 들어오고 너무 어두운 암막은싫었는데 딱 원하던거라 정말 맘에들어요',
#  '이거 커텐 진짜 너무이쁩니다ㅠ 암막도되고 레이스도 있구 배송도빠르거 제일맘에들어요',
#  '너무 좋아요 암막커튼으로 원래 그레이색 했었는데 너무 칙칙한 느낌이라 바꾸고 싶어도 주말에 늦게 일어나고싶은 마음등등으로 암막커튼만 취급했었는데 아니 화이트로 암막이 가능할줄은 몰랐어요 게다가 이렇게 이중으로 넘 샤랄라 하고 넓어보이고 고급스러워 보여요 ㅠㅠ 여기서 산것중에 진짜 손꼽히게 맘에들어요 다는것도 넘 쉽게 달았네요 무게는 좀 있어서 힘들었지만요 진짜 넘 예뻐요 ㅠㅠㅠ 판매자님 번창하세요',
#  '아늑해보이고 넓어보여요 맘에 듭니당 추천요',
#  '이뻐요 근데 저희집에는 조금 긴느낌ㅠㅠ 수선하기엔 배보다 배꼽이 더 큰격이라 그냥 쓰려구요',
#  '고급저보여요 역시 후기보고 사길 잘했습니다 배송도 빨라용',
#  '화이트 계열이지만 암막 기능이 있어서 좋아요 저렴하게 잘 샀습니다',
#  '거실에 달았어요 처음엔 달고나서 별로인가 싶었는데 볼수록 마음에 드네요 저희집 천장 높이에는 긴 편이라 살짝 하단이 접힙니다 구매하실때 높이도 파악하고 구매하시면 더 좋을 것 같네요',
#  '살짝 주름져서 오긴했지만 걸어두니 깔끔하고 예쁘긴합니당',
#  '화이트라 드레스같고 정말 예뻐요 34평형 거실인데 사이즈 정말 딱이구요 너무 맘에 들어요',
#  '설치도 쉽고 넘 만족해요암막이라 좋와요',
#  '커튼 무게가 잇어서 봉다실때 잘못하면 봉 휘니 조심하셔야합니다 가성비는 좋습니다 쉬폰이 좀 아쉽네요',
#  '리뷰가 많은 이유가 있네요 베이지색상으로 했는데 집 분위기랑 아주 찰떡입니다 길이감도 너무 이쁘게 떨어져요 창문 살짝 열어두고 살랑살랑하는거 보면 기분 너무 좋아요 어디하나 흡이 없습니다',
#  '거실에 하고 이번에 안방에 했어요 분위기 있고 아늑해서 방안에서 나가기 싫을정도 입니다',
#  '창문이 아니라 주방 가리려고 샀는데 이뻐요 진짜',
#  '2중 커튼이라 흰색인데도 불구하고 빛 차단 잘 돼요 무엇보다 예쁩니다',
#  '와우 고민말고 사세여 도톰해서 바람도 막아주고 ㅎ ㅎ 커텐집은 비싸서 엄두도 못냇는데 완죤 만족해요 사세요 520싸이즈 햇어여 거실',
#  '반대로 달은거 같기도 하고ㅋㅋㅋㅋ집이 환해지긴해여',
#  '배송도 빨랐구요 촤르륵 떨어지는게 진짜 이뻐요😍 방 분위기가 커튼 하나로 달라져요ㅠㅠ최고 근데 암막커튼인데 흰색이라 그런가 암막 기능은 좀 떨어져요ㅠㅠ 그래도 밖에서 보이고 이런건 없어요 추천합니다',
#  '상품이 흰색이다보니 밤에는 살짝 불빛이 비치지만 늦은 시간부터는 괜찮습니다 예쁘고 넘 좋아요 저희는 모든 커튼을 이것으로 통일시켰답니다 4세트를 구매했네요',
#  '커튼으로 인해 집안이 화사하고 예쁩니다',
#  '일단 화이트는 정말 하얘요ㅋㅋㅋ 누렇게 된 부분도 있어요',
#  '배송 엄청 빠릅니다 저 처럼 빨리 막 바꾸고 싶은 사람들 한테는 너무나 즐거운 일이죠ㅎ 커텐 예쁩니다 설명 필요없이 그냥 사세요ㅋ 후회 안합니다 화이트는 암막 효과 기대하지마세요 저는 처음부터 이쁜것만 생각했기 때문에 넘 만족합니다 가운데 레이스는 이케아에서 주문 한겁니다',
#  '배송도 빠르고 예뻐요 암막커튼이라 더 좋아요',
#  '이뿌게 묶고싶은데 어려워요  ㅋㅋㅋㅋ',
#  '완전한 암막커튼은 아니에요 햇살들어오는걸 더 선호하는 타입이라 만족하고 있어요',
#  '오 진짜 이뻐요 이 가격에 이 퀄리티에 촤르르 너무 이쁘네요',
#  '커튼을 달고나니 방이 다 훤하네요 커튼봉이 좀 약한거 빼곤 만족합니다',
#  '한층 아늑해진 방 분위기에 너무 만족 합니다 🥰',
#  '배송도 빨랐고 물건도 너무 좋아요 암막덕분에 요즘 푹자고있어요 추천합니다',
#  '예쁘네요오랫만에 커텐을 달았더니 가족들이 호텔같다며 좋아해요문틈 바람도 막아줘서 요즘날씨에 달길 잘한거같아요가격대비 퀄리티 좋아요 배송도 엄청 빨라서 깜놀강추해요',
#  '길이도 컬러도 적합 완전암막 아니어도 70는 채광 기려주고석유냄새 살짝 나지만 금방 날아갈 것 같음 만족',
#  '딱 제가 원하던 이중 커튼이에요 암막도 원하고 레이스도 원했는데 가성비 좋아요 설치하기도 편하고 너무 예쁩니다',
#  '깨끗하고 예쁘네요 많이 실용적이에요 잘산듯',
#  '작은방창에 길게 달았는데 분위기 있고 좋네요',
#  '배송도 빨리 왔고 너무너무 예뻐여 ㅠㅠ 베이지색이라 아무래도 암막기능은 조오금 떨어지지만 그래도 넘넘 만족입니다  실오라기 같은게 조금 떨어지긴 하지만 거슬릴 정도는 아니에용 예쁜 상품 감사합니다 ',
#  '설치해보니 이쁘네요 그런데 커튼을 치고 접을때 고리형식이 아니라 좀 불편하단생각이드네요 레일이었음 더 편하지 않았을까 하네요 디자인은 이뻐요',
#  '안방 창문이 가로 180인데 딱 두배해서 360사이즈 하니까 주름도 이쁘게 지고 좋아요 암막은 엄청 어둡게 되지는 않는데 빛은 다 차단해줘서 잠 잘때도 푹 잘것같아요ㅎㅎ',
#  '구매 예정이신분들 참고 하실것이 생각보다 모기장 느낌이고 연결부분 사진과 같습니다 ㅎㅎ',
#  '이중인데도 다른 커텐가격하고 비슷하게 구입했어요 암막기능도 좋고 색상도 예쁩니당 ㅁ',
#  '작은방에 달아뒀는데 이정도 가격에 암막이면 괜찮은거같아요 가로 길이가 살짝 짧은거같아서 아쉬워요  꽉차는 암막을 원하신다면 여유롭게 주문하시는것도 나쁘지않을거같아요 ',
#  '작은집에 답답 분위기라도 연출해볼까 구입하였고 밤과낮 일이바뀌는바람에 암막이필요했어요 확실하게 어둠을주어 피로를 풀어줍니다',
#  '우리집 370인데 530으로 시킴 아주적절함 생각보다 큰데 안뚫어고리 부족해서 그대로 둿다가 한동안 방치해서 달았더니 쭈글해짐 쭈글해지는거 펴느라힘들었지만 나름 괜찮음 한부분이 계속 쭈글어져있는부분존재함',
#  '다는것도 편하고 너무 이뻐요 색깔도 고급스럽습니다',
#  '거실 바닥이 타일이라 처음엔 커튼만 둥둥 뜬 느낌이었는데 너무 잘 어울리고 화사합니다 햇핓차단 적당하니 좋구요 가격 착하고 길이가 좀 길어요',
#  '이번에 산 것 중에 제일 마음에 들어요 ㅠㅠ 가격대비 넘넘 좋네요 암막도 잘되고 그냥 넘 좋네요 예뻐야 ㅠㅠ',
#  '커튼이 보면 볼수록 예뻐용 암막효과도 좋은 것 같고요',
#  '사람들이 찬양한거에 비해서 퀄리티가 그렇게 좋은건 아님 싼맛에 하는거죠 배송상태는 안좋았구요 박스 다망가지고 안에는 한겹비닐로만 포장된 커튼이 덩그러니 있었음 참고요',
#  '아주 맘에 듭니다 꼭 사세요 살까말까 하는 시간에 사세요',
#  '이쁘긴한데 주름이 많아여 펴야 되는데 귀찮아서 방지 중 ㅎㅎ',
#  '진짜 방도 환해지는 것 같고 너무 예뻐요ㅠㅠ',
#  '계속 품절이어서 겨우겨우 득템했네요 역시나 예뻐요 낮에 찍을라고 했는데 불빛받아 예쁘네요 밤에도 번창하세요',
#  '고급지고 예뻐서 너무 마음에 들어요👍',
#  '커튼 무난히 쓰고있습니다 만족하고있어여',
#  '방 분위기가 완전 포근해졌어요 층고가 높아서 젤 큰거를 했지만 바닥이 저렇게 보이는거 빼곤 대만족입니다 ㅋㅋㅋㅋ',
#  '화이트라살짝걱정했는데너무이뻐요💕 암막은좋은데거실이라서 적당한거찾고있었는데완전딱이네요',
#  '밖이 보이지는 않지만 햇빛은 비춰요👍 답답해보일까봐 걱정했는데 답답해보이진않아요 단점은 무겁다는점 여자 두명에서 설치했는데 진짜 무거웠어요',
#  '너무 맘에 들어요♡♡♡ 샤랄라한 느낌이에용',
#  '커튼하나 다니까 신혼분위기 확나네요 ㅎㅎ 생각보다 무게가 있어서 고생했지만 달고나니까 뿌듯해요',
#  '너무이쁘고 암막도어느정도되네요',
#  '고민하다 샀는데 가격대비 좋아요 깔끔하네요',
#  '웨딩드레스같아요 창이 너무 밝아 새벽부터 눈이 일찍뜨이기 일상이었는데 흰색이어도 기분좋은 햇빛차단을 해주네요따뜻한 아침을 맞이하네요',
#  '집이 너므 화사해졋어요 ㅠㅠ 담에재구매각이에요',
#  '이뻐요 너무 좋아요 층고가 낮아서 그런지 조금 끌리지만 나중에 이사하게될경우를 생각해서 자르기가 아깝네요ㅠ 근데 차르르 떨어지는 느낌에 암막도 되고 좋아요',
#  '너무 예뻐요 거실 커튼 바꿔달아봤어요 화사하네요',
#  '디자인이 너무 예뻐서 재입고 기다리다가 바로 주문했어요 기대한만큼 너무 예뻐요 사이즈도 딱이에용',
#  '커튼봉이 같이 안오는줄 모르고 고생했네어ㅜㅜ 다들 잘보고사세요',
#  '가격대비 완전 만족입니다 암막도 잘되고 짱이네요',
#  '생각보다 어두워요 그래도어두운게더나은거같아요 저희집에비하면 쫌짧으네요 그래도 예쁘고 달아놓으니 분위기가살아요 배송도빨랏구요',
#  '진짜 너무 예뻐요 당장사세요 한가지 단점은 커튼 분리가 안되는것 하지만 전 너무 만족해요 ㅠㅠ 고민은 품절만 불러올뿐',
#  '사진 그대로 깔끔하고 너무 이뻐요',
#  '커튼 비싼거 살 이유가 없어요완전 맞춤이네요너무 예뻐요 구매 강력하게 추천합니다',
#  '새벽 햇살나올쯤 조명없이 보정없이 찍어봤습니다 흰색이지만 암막이중커튼이라 밤에도 무리없이 보호해주더라구요 고민많았던 제품인데 실제 사고보니 젤 이쁘다는 말을 자주듣게해준 제품이라 만족입니다 인데리어 같은거 할줄모르지만 이거 하나로 집이 3배커진느낌이예요',
#  '다른 후기처럼 엄청 예쁘진 않고 살짝 싼티나긴하는데 안방에 달거라 잘 가려지는거 원했는데 그런점에선 맘에들어요 ㅎㅎ',
#  '우선 총알배송에 너무 감사하구요 화이트 너무 이뻐요 러블리하면서 안막도 되고 커튼 생각보다 엄칭 무거워요 ㅠㅠ',
#  '은은하게 집에 분위기 연출을 해줘서 좋아용 한참 고민하다 샀는데 후회없는 지출이었어용 이쁜 집게핀도 같이 팔았으면 좋겠어요',
#  '집이 한층 분위기 있어지고 예뻐요',
#  '기대이상입니다 커튼이쁜건 가겨이 좀 있던데이 커튼은 가격대비 훌륭해요👍방이 살랑살랑해졌어요',
#  '예뻐요 제가 급하게 다느라고 저렇게 못나게 고정하고 대충 사진찍었는데 마음에듭니당ㅎㅎ',
#  '사이즈 딱 색상좋고 차르르 떨어지네요 맘에 들어요 퇴근하자마자 개봉하여 설치 하니 예뻐요',
#  '엄청 이쁘고 길이를 넉넉히 사는게 나은것 같아요 커튼 하나로 방 분위기가 엄청 달라져요 완전 사시길 강추합니다 배송도 2일 밖에 안 걸렸어요',
#  '가격대비 만족해요 레이스 2증커튼 주름으로 풍성해 보이고 446창에 530 작지않네요 원단이 고급지진 않지만 가격대비 괜찮아요 다른사이트 화이츠 품절이라 기다리다 최저가 오늘의집에서 구매했네요 베이지랑 고민 좀 했는데화이트가 깨끗해 보이긴해요',
#  '집이 엄청 화사해졌어요 ㅎㅎㅎ 너무이쁩니다',
#  '주말에 주문 화욜 받았어요 상품평들이 좋아서 믿고 구입했는데 역시  너무너무 이뻐요저녁이라 빛 정도는 확인할 수 없어서 어서 아침이 오길 기다려봅니다 거실이 거의 미터정도인덕 530하니 살짝 주름지고 딱 이쁜거 같아요',
#  '침실 분위기를 은은하게 해주네요 그러면서 암막 기능도 있다니 좋구요 신랑이 어떻게 흰색이 암막이냐고 근데 직접 설치해보더니 이쁘다고 하네요 ㅎㅎ 센스쟁이 됐어요',
#  '화이트라 암막이 완벽하진 않지만 예쁩니다',
#  '두개째 구매했어요 엄마방에 사드렸는데 예뻐보여서 제방에도 달았어요화이트암막이다 보니 완전 어둡게 암막이 되지는 않지만 은은한 암막이라 더 맘에 들고 암막 위로 쉬폰 커튼이 분위기 있어 보이고 예쁘네요 항상 빠른배송도 좋네요 ㅎㅎ',
#  '예뻐요 깔끔해서 화이트의 매력에 빠집니다 봉이 좀약해서 약간 휘어지는것 빼고는굿 입니다감사해요',
#  '여자혼자서도 잘 설치할수있어요 좋습니다',
#  '소파와 색감이 찰떡이에요  분위기 넘 좋네요 암막역할도 넘 좋고 너무 잘 산거같아요 배송도 빠르고 만족해요',
#  '진짜 너무너무 만족하고 예쁩니다 이 가격에 이런 퀄리티라니 감동이네요',
#  '기존에잇던커튼이랑 갖이매치시키니까 더예쁘네요 맘에들어요 강츄합니당',
#  '생각보다 배송빠르게 왔고 암막이라 빛도 잘 차단해줘요',
#  '봉 튼튼하고 좋아요ㅋㅋㅋㅋ잘 버텨주길',
#  '정말 너무 이뻐요 덕분에 집이 너무 화사해졌어요',
#  '원단이 암막커텐 이라서 약간의 구김은 있네요 방이 좁아서 화이트구매했는데 금액 대비 괜찬고 만족합니다',
#  '디자인이 너무 이쁩니다 흰색이라 암막은 솔직히 기대 많이 안했는데 생각보다 기능이 좋습니다 ㅎㅎ',
#  '암막이 잘되길바래서 흰색보다 베이지색 암막 더될거같아서 선택했는데 완전 꿀잠 가능해요 완전 만족하고 이쁩니다',
#  '신혼집 커텐 찾다가 디자인도 이쁘고 가격도 착한듯해서 구매 ㅎㅎ 배송와서 설치해보니 아주 맘에 드네요 끈을 이쁘게 못묶었지만 되게 이뻐요ㅎㅎ 집도 화사해지구 단 묶고나서 구김이 많이지지만 이건 다른 커텐도 똑같을것같아용',
#  '전에꺼 실패하고 구입한건디 너무 맘에들어요 ㅠㅠ',
#  '배송도 빠르게왔고 커튼 진짜 부드러워요 마감처리도 좋아요 조금 무거운데 레이스까지̆̎ 달린거 치면 정말 좋아요',
#  '너무 튼튼하고 예뻐요 저렴하게 주문잘했어용',
#  '인디핑크랑 베이비핑크랑 고민했는데  베이비핑크도 괜찮네용 더 방이 화사해보여서요  ㅎㅎ',
#  '안방에는 포근한느낌으로 베이지색상했는데 예뻐요 ',
#  '가격도 착하고 디자인도 너무 예뻐요 암막커튼 질감도 너무 맘에 듭니다 커튼박스부터 달아서 그런지 커튼 아래가 약간 짧은데 그래도 괜찮아요 너무 예뻐요',
#  '배송도 빠르고 가격도 저렴하고 달아보니 너무 예쁘기도 한데요 레이스 부분 박음질 불량이 좀 있어요 실이 잡아당겨지며 우글우글해진부분이 많아서 다른부분은 제가 살살 당기며 폈는데 천이 연결되는 부분은 오버록되어있는 부분이라 잡아당겨 펼수가 없네요 ㅠ 이미 커튼 설치한 다음에 발견해서 교환하기도 그렇고 또 주름이 있어서 자세히 안보면 크게 티가 안나서 그냥 쓰려구요 그래도 전반적으로 만족합니다 집이 화사해졌어요',
#  '하얗고 샤랄라하고 너무 예쁘네요ㅎㅎㅎ',
#  '너무이뻐요 근데 연결하는게 좀 약해서 끼우다가 몇번 빠졌어요 그거빼고는 만족합니다',
#  '며칠을 한참 기다렸어요 사이즈때문에 ㅜㅜ 근데 보람있어요 생각했던 그대로고 너무 이뻐요ㅠㅠ',
#  '너무 이뽀요 너무 하옇고 이뽀서 때탈까 조금 조심스럽긴 하지만 잘 쓰겠습니다',
#  '화이트엄청깔끔해요 안방에 설치했는데넘넘예쁘네요',
#  '타블렛 아래쪽 제봉선 박음질 일부 부분이 터져있는데 교환하기 귀찮아서 그냥 사용합니다 암막효과는 좋네요',
#  '이가격에 이렇게 고급스러운 커튼이 있다는게 너무 놀라워요ㅠㅠ 달고나서 집 분위기가 완전 바껴서 너무 감동이에요 넉넉하게 하려고 530으로 샀는데 하나로도 충분해서 하나는 다른 문에 달려고 합니다 너무 조아여',
#  '조금 더 준만큼 값어치 있게 좋네요 ㅎ',
#  '솔직하게 사진보단 덜했어요 주문하려고 했는데 품절이라서 조금 기다렸는데 입고되자마자 바로 배송해주시긴 해서 좋았어요 가격대비 괜찮아요',
#  '예뻐요 흰색이라 암막이 많이 되는건 아니지만 그래도 적당히 됩니다 ㅎㅎ  배송도 빨랐어요 ',
#  '사진은 약간 베이지빛나는 흰색인줄 알았는데 회색기가 도는 흰색이네여 그리고 사진 보기보다 하늘하늘한 느낌이 없어요ㅠㅠㅠㅠ',
#  '배송이 빠르긴했는데 상자는 여기저기 뜯어져서 왔더라구요 그래도 빠진것없이 다 잘왔어요 커튼은 예쁘구 설치도 어렵지 않았는데 봉이 엄청 내구성 있어보이진않네요 스팀다림질 한번 해주면 더 예쁠것같아요',
#  '이사오면서 주문한건데 사이즈 완전 찰떡 넘나 이뻐요',
#  '이중레이스 안방 침실용으로 달았습니다 이쁘네요 화사하고 기존 암막커튼은 한 낮에도 쳐놓으면 밤인지 낮인지 몰라서 낮잠자기 좋은 요요 커튼은 암막의 효과보단 인테리어용 으로 좋아요 밝고 화사한 샤랄라느낌으로 분위기 바꿔봤어요 침구랑 잘 어울립니다',
#  '진작 살껄 ㅠㅠㅠ 넘 예뻐요 ㅠㅠㅠ 샤랄라',
#  '기존에 있던 커튼은 암막이 하나도 안되어서 사봤는데 너무 예쁘고 웨딩드레스처럼 샤랄라한게 대만족이에요 아쉬운건 세로길이가 치수로 재면 딱 맞아야 하는데 아일렛 부분이 높아서 그런지 딸랑하네요 ㅠㅠ 그래도 길어서 머리카락 엉켜붙는것보다는 낫겠거니 하고 그대로 달았어요',
#  '커튼 진짜 특가로 잘샀어요고급지고 집도 넓어보이고 너무 이뻐요',
#  '너무너무너무만족해요진짜 생각한것보다 다 너무예뻐요 ㅠㅠㅠ 이제 안방이랑 작은방 다용도실것도 주문하려구요 완전대만족 추천합니다 이 가격에 이 커튼 못사요',
#  '예쁘네요 그런데 대가 좀 약한거 같아요',
#  '사진이 어두워서그런데 색이쁘고 분홍색ㄷ샀는데 그것도이뻣어요근데 여름이라그런지 좀두꺼워서 아직은 커텐을 쳐놓고 살아욘 ㅎㅎㅎㅎ',
#  '넘무 예뻐요 진짜 가성비 짱인 것 같아용',
#  '십년만에 남이 준 커튼에서 새로 샀네요 하얀색이 너무 이쁘고 저희 거실 창이 아주 넓은데도 충분히 커버가 되네요 딸들이 너무 이쁘다고 앞에서 틱톡찍어요 가격 생각하면 너무 싸게 잘 샀다고 여겨지네요',
#  '넘 예뻐요 흰색이라 때가 탈까 조심스럽지만 예뻐서 감안하고 사용하려구요 암막이 100프로 되진 않지만 살짝 비치는 정도인데 이정도면 만족해요',
#  '동생이 구입한 커텐이랑 사이즈만 다르게 주문했습니당 워낙 예쁘고 적당한 암막이라 좋아서 저도 샀어요 동생은 같은 창문 사이즈에 더 큰 사이즈를 샀지만 저는 264사이즈로도 주름이 충분해서 샀습니다 실사이즈 두배정도면 충분하게 예쁜 주름인것 같아요 완전 어두운 암막 원하시는 분보다 어느정도 햇빛을 막아주고 여리한 느낌 원하는 분들한테는 완전 추천입니닫 그리고 조립 너무 쉬워요',
#  '아직 달아보진않았지만 노란빛없는 흰색이네요',
#  '예뻐요 암막도 잘되고 레이스 있어서 더 예쁨것 같네요',
#  '생각보다 좀 약한데 깔끔하고 설치가 쉬워서 좋어요 커튼은 사이즈미스라 교환 요청하고 기다리는중이에요',
#  '배송 설치 적당한 가격에 맘에 들어요',
#  '실제보단 사진이 좀 더 예쁜 것 같아요 레이스부분이 약간 모기장같은 느낌이 들어요 실밥 정리 안 된 부분도 있구요',
#  '겉에 달린 망사같은게 조금 저렴해보여요ㅜㅜ 차라리 베이지말고 화이트가 나을듯합니다',
#  '집이랑 침대랑 잘어울려요 예뻐요 추천',
#  'ㅜㅜ커튼3개째실패했는데 이번꺼는대박성공♡♡ 가성비진짜좋아요 뒤에확실히가려집니다 창이이쁜집이었음 얇은커튼만으로도이쁠텐데 옛날집이라그냥가려버려쓰여ㅋㅋㅋ 담달에하나더사려구요',
#  '저희집 거실 세로가 230 이어서 딱 좋을줄알았는데 막상와서보니 반뼘정도 짧아서 기존 커튼 거는식으로 걸어서 기장은 맞췄는데 커튼자체 커튼고리 구멍이 살짝보여 쫌 아쉽네요 한가지 아쉬운점이 있다면 망사원단 커튼끝과 중간 이음선끝 밖음질이 망사를 당겨서 밖음질 하셨는지 울어서 그 분분이 쫌 아쉬워요 참고로 1층이어서 밤에 집안이 보이면 어쩌나 했는데 하나도 안보이고 좋아요 전체적인 분위기 변화는 성공적입니다 밝아져서 기분이 좋아요',
#  '레이스가 따로 분리되어 있지 않아서 계속 암막과 함께 써야하는게 아쉽네요 판단미스였던거 같아요 함께온 나사가 약해서 한번 떨어졌고 집에 있는 공구로 다시 작업해서 달았어요 컬러감은 예쁘고 암막은 햇살을 잘 막아줘요',
#  '배송도 빠르고 색상도 질감도 진짜 딱 원하던 스탈이에요ㅠㅠ  촤르르르르 강추👍🏻👍🏻',
#  '빛도 잘 차단되고 이뻐요 잘 구매했어요',
#  '하얀색을 할까하다 베이지로 했는데 휠 이쁘네요 집에있는 가구와 잘 맞춰서 산 것 같아요',
#  '너무 맘에 들어요 암막커튼인데 레이스 달려있어서 신혼방 침실에 딱이네요 빛차단은 100프로는 안되지만 화이트라 감안하고 샀습니다 그렇다고 불편할 정도는 아니고 80프로 이상 되는것 같아요 배송도 빠르고 가성비 좋습니다',
#  '가격대비 완전 만족입니다 뻣뻣하지 않고 부드럽고 구김도 잘 안가요',
#  '음 이중인것도알고 암막인것도 알았는데 망사인줄은 또 신경을 못쓰고 붙어있다는것도 몰랐고ㅎㅎ 무조건 이쁘고 가격이 착해서 샀는데 하늘하늘 느낌이 없다는게 아쉬워요 그래서 나비커튼을 베란다에 해야하나봐요ㅎㅎ 530두개인데 작긴작아요 거실이 4000이 넘어서요 그것도 뭐 감수해야죠 그래도 웨딩드레스느낌은 진짜 나네요ㅎㅎ',
#  '깔끔하고 무난합니다 순백색이라 웨딩드레스분위기',
#  '크으 너무 예뻐서 만족스러워요ㅠㅠㅠ 방 분위기가 달라졌어요',
#  '커튼봉 진짜 별로요 여기서 말고 다른곳에서 사세요 튼튼하긴 한데 천장에서 너무 떨어지게 걸 수밖에 없어서 지저분해보여요',
#  '커튼 하단에 신발에 밟힌 자국이 있어서 아쉽네요 검수나 포장때 신경써주시면 좋겠어요 암막 생각하고 사면 안됩니다 커튼이 없다면 눈부셔서 깨겠지만 커튼이 있어도 밝아서 깨요 디자인은 예쁘고 낮에 굳이 안걷어도 된다는 장점이 있네요',
#  '남편이 하얀색 싫다고 설치 전까지 입길이가 일메다 나왔었는데 설치하고 사진 보내주니 잡지에 나오는 집같다며 퇴근하고 와서는 발렌타인 한 잔 했어요 커튼봉 자체가 견고하진 않지만 커튼봉을 양쪽 균형맞춰 브라켓에 끼운 후에는 커튼달기로서 문제 없이 튼튼함 사진처럼 반나절 묶고 있다가 밤에 풀어 펼쳤는데 이렇게 해도 저렇게 해도 예쁨 커튼이 무게감이 있어 고급스러워 보임 포쉐린 타일 공사로 지면 높이가 높아져 커튼이 끌리는 건 세탁 시 수선집에 맡겨야겄음',
#  '너무 하애서 걱정했는데 분위기 살고 좋아요',
#  '샤랄랄라해서 이뻐요 배송도 진짜 빠르구여 화이트라 그런지 완전히 빛을 차단해주지는 못하지만 이쁘니까 추천합니다',
#  '쉬폰커튼을 사고싶었는데 쉬폰커튼은 암막이 너무 안될거같아서 찾아보다가 이 커튼을 보게되었는데 쉬폰커튼이랑 암막커튼 두개를 같이 달고싶었던 저에게 딱 안성맞춤인 커튼이였어요 그래서 품절이 풀리길 기다렸다가 샀는데 사이즈를 잘못알고 원래 시켜야되는 사이즈의 2배나 큰걸 시켰지만 그렇게 커보이지않고 예뻐서 다행이에요 화이트 완전 강추입니당 방 분위기가 엄청 밝아보이고 인스타갬성이 아주 뿜뿜해여 너무 예뻐요 다들 사세요',
#  '배송도 빠르고 설치도 쉬워요 결정적으로 너무 예쁩니다',
#  '이중커튼이 너무 하고싶은데 커튼 레일이 아니라 고민하던중 찾은거예요 생각보다 더 예쁘고 흰색이지만 암막도 잘되요 살짝 길어서 밑에가 끌리지만 그것마저도 이뻐요 ㅎㅎ',
#  '아일렛인데 쉬폰 느낌 찾기가 힘들었어요 암막 뒤에 이쁘게 두겹으로 되어있어서 너무 예뻐요',
#  '불키면 더 이쁜데 암막 어느정도 되는지 궁금하실 분들이 계실것같아서 흰색 너무 좋아요샤랄라하구 진짜 이뻐요 위에 고리형식이 아니라서 안이쁠까봐 걱정햇는데 샤방해가지구 눈도 잘 안가구 진짜 마음에 드는데 키가 딸려서 압축봉으로 역도함',
#  '멋스럽네요정리하느라 이제서안 달았어요',
#  '암막이 효과가 크네요 생각보다 좋아요 ㅎㅎ',
#  '너무예뻐요 큰방 커튼도 여기서 샀는데 레이스짱예쁘고 거실커튼도 사이즈나 디자인이나 만족입니다 흰색이라 완벽암막은 아니지만 거실이라 느낌이 딱 좋아요 4시쯤 찍은 사진입니다',
#  '거실이 ㄱ자로 창문이 있어서 큰거 작은거 구입해서 다 달았어요 샤랄라하니 이뻐요',
#  '예뻐용 근데 커튼 고리 위로 천 부분이 길어서 벽에 닿아서 구겨짐 ㅠ 안그래도 흰색이라 때탈까봐 걱정인데 움직일때마다 커튼 달려있는 부분 천장 닦는 기분 그리고 레이스가 좀 구겨져서 와요',
#  '커튼 정말 천도 좋고 예쁘고 200퍼센트 만족입니다 아빠도 커튼 잘 샀다고 칭찬해주셨어요',
#  '좋아요 안방하고 거실 다이커튼이에여 암막인데 회색빛안돌고 최고에요',
#  '예뻐요예뻐용예뻐요오오진짜예쁘요₩',
#  '화이트로 하니 집이 화사해보이고 좋아요',
#  '사진처럼 실물도 이뻐요 다만 뒷면이 좀 더 얇은 원단일줄 알았는데 완전 암막커튼용이에요 ㅋㅋ 겨울에는 방한용이되서 좋을꺼같은데 여름엔 좀 덥겠어요 ㅠㅜ 상품 좋아요 튼튼하고',
#  '정말 깨끗해요 단지 구겨짐이 있어 전 스팀다리미로 다렸더니 구김이 그나마 사라졌네요 깔끔해요',
#  '분위기가 너무 이뻐요 다만 밝은 색이라 완벽한 암막은 포기해야합니다 ㅜㅜ',
#  '사실 길이를 착각해서 다시 주문했는데 매우 친절하게 응대해줘서 감사했습니다 우리집고양이도 마음에 들었는지 커튼에다 쉬를 해서 오자마자 깨끗이 빨래하고 사용했습니다',
#  '색이 예쁘고 귀엽네요 잘 잘 사용하세요 네',
#  '100프오 암막말구 빛이 은은하게 들어오는 커튼을 원했는데 딱 좋아요 정말 이뻐요',
#  '커텐 이거산게 신의한수에요넘나리 예쁨',
#  '커튼을 처음 사보는지라 정말 오랜 고민 끝에 사서 생각과 다를까봐 걱정도 많았는데 마음에 들어요 겨울이든 여름이든 어울릴 수 있을 것 같고 컬러랑 디자인도 좋아요 올해부턴 대충 살기로 해서 특별히 냄새도 안나길래 돌돌이로 먼지 제거 했고 때가 두세군데 묻어있던 점 마감 거슬리는 것들 있었지만 대충 닦고 정리하니 눈에 띄진 않아요 그냥 걸었더니 역시 구겨짐이 거슬려서 스팀으로 대충 다렸네요 목요일 밤 주문했고 금요일 발송 토요일 수령했습니다 참고로 벽 가로220세로230 정도입니다 커튼봉은 별도로 구매했고 여기서 파는 브라켓보다 짧아서인지 바닥에 끌리지 않고 딱 떨어지는 길이에요',
#  '햇빛이 잘드는곳인데 화사하게 빛들어와서 좋네요 ㅎㅎ재구매 의사 있습니다',
#  '진짜 잘샀어요 친규들이 집들이 와서도 커텐 사고 싶었던거라몀서 사야겟다고 하더라구요 러블리하니 예뻐요',
#  '걸었을 때 너무나도 예쁜 커텐입니다 특히 사진이 예쁘게 나오는 거 같아요 원래 커텐 택배로 사면 처음에 주름때문에 안 예뻐보이는데 이거는 레이스가 있어서 처음부터 너무 예쁘네요 커텐은 내구성이 좋아보이는데 커텐봉이 조금 약해보였어요',
#  '퀄리티 아주좋아요♡ 집안 분위기가 화사해지고 겨울에 방한 효과도 있네용',
#  '차르르 심플하고 예쁩니다 암막 커튼 기능도 괜찮구요 압축봉이 버티기 살짝 무거운 것 같긴한데 맘에 들어요',
#  '디자인도 이쁘고 배송도 빨랐어요ㅎㅎ 잘쓸게여',
#  '집안분위기가 커튼하나로 확 바꼈어영 전엔 다크그레이톤이였어서 좀 어두워서 분위기도 바꿀겸해서 찾다가 원하던 디자인에 커튼찾아서 넘 좋았어영 가격도 디자인도 다 맘에 들어영 추천합니당 ',
#  '존나이쁨요어어어어어아아아ㅏ아아어오오오ㅗ옹',
#  '안방 아침햇살입니다 너무 예뻐요',
#  '도어대신 파티션으로 사용하는데 은은한 크림색과 잘 어울려요',
#  '커튼 하나로 분위기 완전 바꼈어요 이뻐요',
#  '이케아 커튼을 샀는데 갈색 몰딩이 그대로 비춰서 아쉬워서 다시 구매했는데 너어어어무 좋습니다 진짜 만족도 100프로에요 화이트인데 암막도 잘됩니다',
#  '너무너무 예뻐서 난리입니다 암막커텐이 이렇게 예뻐도 되냐고 ㅎㅎ 대만족입니다',
#  '전 은은한 빛이 좋아 선택했는데 완벽한 암막이 아니라 분위기는 한껏 더 살아나는거 같아 좋네요 우풍도 많았는데 많이 차단해줘서 한층 더 따뜻해요',
#  '인터넷화면에서는 너무너무 예뻣는데ㅜㅜ 달고보니 싼티가 너무 난다며그냥 가격대비 자알 쓸께요 막 도저히 싼티나서 못쓰겠어환불할래 이정돈 아니에요 ㅋㅋㅋ',
#  '베이지 색상 선택했는데 색상도 이쁘고 설치도 쉬워요암막 기능도 좋고요가성비 좋습니당',
#  '레이스가 붙어잇어서 두 개 설치할 수고는 줄어든단게 최고 장점입니다',
#  '울 딸방 햇빛이 해질때까지 들어 오는 방이라 이 암막커튼이 딱인것 같아 주문 했는데 배송도 빠르고 설치 방법도 숴웠어 정말 맘 에 들고 울 딸이 드레스 같다고 좋아 하네요 방이 은은 하니 딱 좋아요 원하던 커튼 이에요',
#  '가격비해 맘에 듭니다 울양이가 숨바꼭질 할공간이 생겨 신나해요',
#  '커텐과 길이가 잘 맞아요 쉽게 잘 설치했어요',
#  '커튼봉 커튼 모두 가장 큰사이즈로 했어요  18평20평 정도의 거실이구요  커튼길이가 살짝 길어서 조금 아쉽지만 전체적으로 디자인이 넘 이뻐요  속커튼과 레이스커튼 모두 소재가 톡톡해서 고급져요 싼티안나요 ㅎㅎㅎㅎ 화이트하길 잘한거같아요 관리는 좀 빡씨겟지만 넘 맘에들어요오',
#  '정말 너무너무 예뻐요 너무 하얘서 병원 느낌 나면 어쩌나 했는데 조금 오바해서 호텔느낌나요 ㅠㅠ 방이 워낙 작고 어수선 했는데 커튼 하나로 화사해졌어요 암막에 레이스가 겹쳐있는 디자인이라 사랑스럽고 암막 특유의 탁한 느낌이 없어요 제방엔 360 사이즈가 딱인데 방이 큰 분들은 더 폭이 넓은걸로 추천드려요 새 냄새는 좀 나는데 시간이 해결해 줄거라 믿습니다 배송도 총알이에요 금요일 아침에 결제하고 토요일에 받았어요 bbb',
#  '창가에서 자려니 춥고 정남향이라 햇빛이 많이 들어와서 주문했어요 방풍효과 암막기능 디자인 모두 완벽입니다 감사합니다',
#  '거실이 화사하게 변했네요 이중이라 그런지 내부에서는 화사한 느낌이 들고 외부에서는 확실히 내부가 않보이네요',
#  '말이필여없어요ㅡ너무이쁩니다♡빛차단도 잘되요',
#  '가격 대비 이쁘고 좋아요 천도 두껍고 암막 효과도 좋네요',
#  '품절풀리기 기다려서 산 보람이 있어요 화이트 역시예뻐요 창이 큰편이라 일반커튼이었으면 좀 없어보였을 사이즈인데 망사가 덧대져있어서 풍성해보이는 효과가있네요 두껍고 탄탄해요 한달을 커튼고민하고 가성비랑 디자인 엄청따졌는데 완전 잘샀어요',
#  '이전보다 집안이 환해진 느낌이예요 화이트커텐사고싶었는데 너무만족합니다 가격대비 완전굿이네요',
#  '너무 잘쓰고있어요 ㅎㅎ 감사합니다',
#  '넘 예뽀요 생각보다 고급스럽고요 화이트 커튼 덕분에 방이 환해졌어요 단 밑에가 조금 더 길었으면 좋았을텐데 아쉽지만 그래도 이뻐서 그냥 쓰려해요 만족합니다',
#  '사이즈 원단 배송 다 좋습니다 분위기 로맨틱하게 만들어 주는 듯',
#  '커튼 크림베이지 색 예뻐요 안방에 하면 따뜻한 분위기가 살아나네요 빛 차단도 꽤 잘돼요',
#  '방 분위기가 화사해졌어요 이뻐요 만족합니다',
#  '너무 이뿌고 좋은데 흰샛 커튼인데 여기저기 지저분하게 뭍어 있는게 많네요 ',
#  '카튼 하나로 방이 따뜻하고 아늑해졌어요 넘이쁨',
#  '보는 그대로 너무 예뻐요 디자인 보자마자 이거다 싶어 바로 구매했습니다 쉬폰느낌으로 호텔 느낌도 나면서 단열과 암막도 필요해서 이중으로 커튼을 달아야하나 고민했는데 마침 딱 이 디자인 만나서 바로 달았어요 커튼 봉이랑도 너무 잘 어울리고 저희집 길이랑도 딱이라 진짜 맞춤으로 제작한 거 같아요 화이트라 때 안타게만 잘 관리하면 더할나위 없이 좋을 제품 같아요 프로방스한 느낌을 살리고 호텔 느낌도 원하시면 딱입니다 배송도 빨랐어요',
#  '오자마자 세탁하고 바로설치했어요 너무이쁘네요잘산거같아요',
#  '가볍고 산뜻해요 하늘하늘 예쁘네요 ',
#  '저는 뒤에 행거 옷 가리는 용도로 구입했는데 진짜 넘넘 마음에 쏙 들어요 정신 없던 방이 아주 조금은 정리됬습니당',
#  '커튼 다니까 집 분위기가 달라져요 넘 예쁘고 만족합니다',
#  '커튼이 너무 예뻐요 ㅠㅠㅠ완전 취저❣ 딱 적당한 안막이랄까 안막은 한 6070프로정도는 되는거같아요 디자인도 길이도 딱이예요  배송도 빠르고 손님들이 올때마다 커튼 예쁘다고 잘샀다고 어디서 샀냐고 물어보더라구요  너무 맘에들어요🙆\u200d♀️❤ 추천합니다👍',
#  '새로이사간집 거실에 걸었는데 길이도 딱이고 너무 예뻐요ㅠㅠ',
#  '전세집 브라운 색상에 칙칙한 블라인드를 떼버리니 속이 다 후련 덕분에 집에 화사해졌어요 몇몇 후기에 못이 짧아서 설치하는데 힘들다 해서 걱정했는데 저는 튼튼하게 쉽게 설치했어요 만족합니다D',
#  '빛 은은하게 들어오면 너무 예쁘네요 화이트 인테리어에 잘 어울리는 디자인입니다',
#  '화이트라 완전 깜깜은 아니지만 블링블링하고 분위기 살아서 흔한 암막커튼처럼 딱딱한 이미지가 아니예요 이뻐여',
#  '호불호 리뷰보며 고민도 했지만 과감히 선택해 봤는데 집안이 환해지고 밝아졌어요 생각이상으로 좋아서 안방커텐도 여기에서 구입할려 해요 배송도 최대한 케텐이 구겨지지 않도록 왔어요 번창하세요',
#  '좋아요 예쁘네요 적당해요 분위기 좋아요',
#  '빠른 배송 좋았어요 근데 단점이라면 배송 왔을 때 박스 상태가 조금 좋지 않았었어요',
#  '완전암막은아니지만ㅇㅣ뻐요',
#  '이거꼭사세요너무이쁨니다진짜최고고고고',
#  '고급스럽고 깨끗합니다 아주마음에듭니다',
#  '제가 원하던 디자인이라 맘에들어요',
#  '안방에 달았는데 화사하고 공주풍이예요',
#  '안방 작은방에 달았어요 이쁘고 맘에 들어요 암막 효과도 뛰어나요',
#  '물품은 자세히 보면 싼티 그러나 멀리서 보면 괜찮음 예쁘기는 하나 무엇보다 상단 커텐에 무언가에 긁혀서 30센티 정도의 올이 나간 물품이 옴   생각같아서는 반품에 환불이지만 긔찮아서 그냥 쓰는 정도 장사 그렇게 하지 마세요 45만원하는 커텐인테 검수도 안하고 보낸 거라면 더더욱 실망입니다 여기서는 앞으로 절대 구매 안합니다',
#  '커튼을 하니 집이 훨씬 넓어 보여요',
#  '너무이뽀요 완전이뻐서좋아요 가격이좀저렴했음좋겠어요',
#  '가격대비 만족하는데 바느질 좀더 신경써주세요',
#  '좋아요😆ㅎㅎ 봉은 약해보이긴 한데 그래도 튼튼해요',
#  '잘잗았습니다 예뻐여 색감도 그렇고 제 방과 아주 잘 어울립니다',
#  '배송하난 진짜 빠르네요아직 달아보진 않았지만 괜찮은거 같아요',
#  '진짜 최고에요 오랫동안 고민하지 말껄 그랬어요',
#  '길이감이 좀 길지만 샤랄라 예뻐요 빛이 은은하게 들어와서 완전 암막보다 좋네요',
#  '화이트색상이라 관리를 잘해줄려구요 ㅠㅠ 집이 화사해져서 너무 좋아요',
#  '좋아요 생각보다 많이 무겁지 않아요',
#  '정말 정말 예뻐요가성비최고에요 레이스가 한겹 있는게 더 예쁘고 아늑한느낌이 배가 되네요허전했던 공간에 이 커텐을 다니 정말 달 라보여요♡♡',
#  '생각보다 고급진 느낌은 없지만 괜춘해요',
#  '거실에 커튼 달았는데 사람들이 이쁘다고 어디서 샀냐고 물어 보네요 ㅋ 추운 날씨에 방한도 잘 되는거 같고 좋아요',
#  '배송도 빠르고 생각했던대로 예뻐요',
#  '배송 빨라요 다음날 바로 왔어요 색도 생각했던 느낌대로고 좋아요',
#  '디자인 너무마음에들었구요 가격도좋았어욥 배송도진짜빨랐구욥 빨ㄹㅣ달고싶은마음에바로달기했는데ㅜ 얼룩이좀많이묻어왔더라구요하얀색이라티가확나구ㅜ 교환신청하고싶었지만빨리달고싶었구귀찮았어요 그얼룩만아니었어도아쉬웠지만이뻐서마음에들어요',
#  '배달원료 썼는데 물건이 없어요 어떠ㅎ게 하세요',
#  '너무 예쁘고 좋아요 잘 샀어요  따스해보여요',
#  '이가격에 이퀄 괜찮네요 길이를 잘못재서 ㅜㅜ 봉길이가 불안불안하네요',
#  '조악한 품질응대 다신 여기물품쳐다도 안봅니다',
#  '커튼이뻐요 베이지라서암막이잘안될줄알았는데 암막도나름잘되고만족합니다',
#  '동생방에 있는거 너무 이뻐서 똑같은거 구매했어요 화이특컬러인데도 햇빛차단 잘되고 깔끔하고 이뻐요',
#  '중문이 낡기도 하고 체리색이라 자꾸 눈에 거슬려 커텐으로 가려볼까 하고 구매했는데 집도 더 넓어 보이고 레이스 때문에 한층 더 예뻐보이네요 케텐만으로도 집분위기가 달라지다니 너무 좋아요',
#  '배송 진짜 빨랐어요 시킨 다음 날 와서 놀랐어요 ㅋㅋ 그리고 커튼 너무 예쁩니다 레이스가 싸구려 같다고 많이 ㅎ ㅏ샤서 기대를 전혀 안 했는데 그래서 그런지 전 괜찮았어요 ㅎㅎ 묶으면 더 예쁠 것 같아서 설렙니다',
#  '결재후 다음날 바로도착했고 설치도쉽고 예뻐요',
#  '진짜 이쁜데 암막에 레이스까지 있으니 무겁고 튼튼해요 그래서 역으로 5평짜리 작은 집엔 뭔가 어울리지 않는거 같습니다 작은 방을 약간 좁아보이게 하고 답답해보이게 하는 느낌 하지만 예쁘긴 진짜 예쁩니다ㅠㅠ 나중에 넓은집 살게되면 꼭 이런 커텐 달고 살거 싶은 느낌',
#  '너무너무 이뻐요 잘쓰겠습니다ㅎㅎㅎㅎ',
#  '화이트 인테리어에 너무 잘 어울려요 순백드레스화이트입니다 추가로 구매한 봉이 약한듯하지만 사용에는 문제없을것 같습니다',
#  '봉이 너무얇고 봉걸이는 플라스틱으로 되어있어서 부러질것같아요ㅠ 가운데 봉도 고정하는게 없고ㅠ 튼튼해보이지않아서 조심조심 사용해야할것같아요 흰색으로 구매했는데ㅠ 별루안이뻐요ㅠ 차라리 색있는걸로 할걸그랬나바요ㅠ',
#  '예쁘고 차르르 하니 좋네요 커튼봉이어서 아일렛으료 선택했어요',
#  '화이트색상 깨끗하고 이중 레이스라 더 풍성해보이고 이뻐요',
#  '산것중에 젤로 맘에드는 커텐이여요 존예임',
#  '생각보다 더 크고 예뻐요 무엇보다 예뻐요 최고',
#  '차르르 떨어지는게 너무예뻐요 침실 분위기가 확삽니다 ',
#  '예뻐요 정말 예뻐서 만족합니다 그런데 저희 창에 아주 조금 짧아서 아쉬워요 ㅠㅠ',
#  '나쁘지 않게 잘 쓰고 있습니다 가격대비 좋아요',
#  '배송도 이틀만에 엄청 빨리왓구요 디자인도 샤랄라하니 이뻐요 ㅎㄹ 설치하는것도 별로 안어려웠습니당',
#  '길이가 길어서 치렁치렁 정신이 없고 지저분해서 수선할까 하다가 눈을 수술해 그냥 쓰고있는데 왠지 울집이랑 안맞는듯 하고 겉도는 느낌이랄까 환상을 가지고 주문했던 꿈이 깨진셈',
#  '230이라 밑이 좀 뜰거 알고샀습니당 너무 예뻐요 빨리 달고싶어서 일단 걸었는데 약간 냄새가 나긴합니다 세탁한번 하고 써야할듯 해요 디자인은 좋습니다',
#  '예쁜데 박음질이 위 사진처럼 되어 있어요 그리고 제 생각보단 암막이 덜 되는것 같아요 앞에 말씀드린 점 빼고는 이 제품이 전체적으로 괜찮은 것 같아요',
#  '사진 그대로구 예뻐요 😆 저희 집에 길이도 딱 맞아서 수선 없이 바로 설치했습니당',
#  '품절이라 오래기다렸지만 배송도 빠르고 너무 예뻐요',
#  '완전암막은 아니에요 분위기있고 예뻐요 고급져요',
#  '너무 예뻐요 침실 분위기도 좋고 아침에 일어났을때도 기분 좋아요',
#  '햇빛 암막 100프로 되구요이쁜건 덤이에여 진짜 강추완전강추 이 가격에 이런디자인에 이런 암막기능이면 얼른사야해요집분위기도 완전 호텔방처럼 너무이뻐요👍🏻👍🏻제발 사세요그리고 세로길이는 233cm라고해서 길겟다햇는데 저희집 227cm 밑에가아니고 윗부분이 길어서 다행히 끌리지않고 딱맞는데 잘 보고 구매하셔야할거같아요',
#  '우리집 고영희가 좋아해요 그럼 다 된거에요 이만한 가성비 오지는 제품이 없습니다 판매자님 많이 팔아 부자되시고 건강하십시오',
#  '커튼 진짜 이뻐요 진심 웨딩드레스처럼 촤르르 떨어져요',
#  '색도 예쁘고 러블리하고 좋아용 설치도 쉽고 고리형이여서 가려야하나 걱정했는데 커튼이예뻐서 고리도 별로 가릴필요없네요 작은창 용으로도 있으면 구매했을텐데 아쉬워요 ㅠㅠ',
#  '아이가 무조건이뿐거 고집해서 좀많이망설였어요 아이가좋아하니 나두 좋네요',
#  '만족해요 샤라라 하네요 근데 천 질이 그렇게 좋지는 않아요',
#  '환해보이고 싶으면 화이트 추천 입니다',
#  '저렴한가격과 이쁜디자인과 빠른배송 너무 마음에드네요 번창하세요',
#  '화이트톤의 암막커튼이라 고민많이했는데 이중으로 레이스도 있어서 인테리어와 사생활보호및 햇빛차단까지 완벽하니 전혀 후회없고 만족합니다 ㅎㅎ',
#  '집안분위기가너무이뻐요 커튼으로인테이러했어요 감사합니다',
#  '넘나 예뻐요ㅠㅠ 진짜 촤르르 샤랄라ㅠㅠ 설치하기도 쉽고 분위기도 대박입니다',
#  '베이지 살까 화이트 살까 엄청 고민했는데 결론은 화이트 사세요 분위기 첵오입니다ㅠㅠ흰색벽지면 화이트 사세요 방 벽지랑 톤이 같아서 그런지 더 화사해보여요 길이도 딱 맞고 맘에 아주 들어요',
#  '이게 8만원이라니 대박 진짜 가성비갑개예쁨',
#  '커튼을 처음달아보는거라서 이것저것 많이 고민했어요 이제품을 보고 이거구나 싶어서 고민없이 선택했습니다 그이유는 첫째 가성비에요 가격이 하얀색커튼바탕에 그위에 레이슨데 과하지않고 차르르해서 정말 맘에 들더라구요 정말 다른사람 말대로 웨딩드레스 같아요 ㅋㅋ 집 거실에 하얀색으로 해놓으니 환해지고 깨끗해보여서 정말 강추해요 제가 원한 화이트 입고가 느려서 기다리다가 주문했는데 하루만에 배송와서 정말 깜짝놀랐어요 그만큼 배송이 빠릅니다 이제품은 제친구한테도 추천했어요',
#  '우선 제가 설치한곳은 베란다쪽이구요 가로길이 200인데 저는 좀 더 큰평수로 이사갈 계획이라 사이즈를 360으로 구매했어요 당장 살고있는 집은 평수가 작은 원룸이다보니 가로길이 200cm에 사이즈 360짜리 커튼은 한쪽만쳐도 되겠더라구요 저처럼 평수작은 원룸사시는분들 가로길이 200정도 되시는분들 360사면 한쪽만 펼치고삽니다 저는 큰평수로 갈계획이라 상관없지만 암튼 참고하세용 아 그리고 세로길이는ㅠㅠ바닥에 끌려요ㅠㅠ 제가 천장에 못박고 설치한게 아니라 안뚫어고리 사서 연결한거라ㅜㅜ 재질면에서는 최고에요 암막 잘되구요 색감도 예쁘고 레이스가 어우러지니 더 조화로운거같아요 굿굿굿bbb',
#  '역시 리뷰대로 예쁘네용 최고에용 근데 좀 길어요 ㅠ',
#  '암막커튼인데도 하나도 안답답해보이고 너무예뻐요',
#  '가격대비 진짜 최고인거 같아요 진짜 설치하고 보니까 너무 맘에 듭니다',
#  '길어서 좋아요 봉이 두께가 있어서 얇은 커튼봉 고리 에는 안들어가요',
#  '가격대비 완전 만족입니다 뻣뻣하지 않고 부드럽고 구김도 잘 안가요',
#  '창가에서 자려니 춥고 정남향이라 햇빛이 많이 들어와서 주문했어요 방풍효과 암막기능 디자인 모두 완벽입니다 감사합니다',
#  '햇빛을 잘 가려주고 레이스 이중이라 예쁨니다 화이트랑 고민하다가 베이지 샀는데 이것도 분위기 있네요',
#  '저렴한 가격에 잘산것같어요 방안이 한결 화사해지고 예쁩니다',
#  '주문하고 2일 만에 받았어요 생각보다 박스 규격이 커서 놀랬지만🤣 빠른 배송에 너무 만족스럽네요 아직 세탁망이 안 와서 제대로 된 사진은 없지만 세탁 후 거실이 어떻게 변할지 벌써부터 기대되네요😏😏',
#  '예뻐요ㅜㅠㅜ 공주님 방 같애졌어요 존예 가격도 싸고 다들 사세용',
#  '리뷰에 사진이 다 그닥안이뻐보였는데 생각보다 튀지않고 이쁘네요 고양이도 좋아해요',
#  '하얀색을 할까하다 베이지로 했는데 휠 이쁘네요 집에있는 가구와 잘 맞춰서 산 것 같아요',
#  '깔끔하고 무난합니다 순백색이라 웨딩드레스분위기',
#  '너무 하애서 걱정했는데 분위기 살고 좋아요',
#  '사실 길이를 착각해서 다시 주문했는데 매우 친절하게 응대해줘서 감사했습니다 우리집고양이도 마음에 들었는지 커튼에다 쉬를 해서 오자마자 깨끗이 빨래하고 사용했습니다',
#  '너무 잘쓰고있어요 ㅎㅎ 감사합니다',
#  '예뻐요 ㅎㅎ 흰색은 딱 흰색치고 암막이 잘 되는 편 정도이고 완전 차광은 당연히 아니에요',
#  '넘예버요가성비 갑이에요 저희집 커텐은 다 까르데코인데 다 맘에쏙들어요 ♥',
#  '가로 265 세로230 사이즈로 10자 구입했는데 딱맞네요',
#  '지금까지 산커튼중에 제일 예쁨',
#  '다른곳에서 사고 너무실망해서 반품하고 다시 찾다가 원하던 커튼을 찾은거 같아서 바로 주문했어요 여유있게 했다고 했지만 더 크게 잡고 주문했으면 좋았을거같지만  그래도 충분히 맘에 들어여',
#  '딱 제가 원하던 이중 커튼이에요 암막도 원하고 레이스도 원했는데 가성비 좋아요 설치하기도 편하고 너무 예쁩니다',
#  '커튼봉이 같이 안오는줄 모르고 고생했네어ㅜㅜ 다들 잘보고사세요',
#  '주말에 주문 화욜 받았어요 상품평들이 좋아서 믿고 구입했는데 역시  너무너무 이뻐요저녁이라 빛 정도는 확인할 수 없어서 어서 아침이 오길 기다려봅니다 거실이 거의 미터정도인덕 530하니 살짝 주름지고 딱 이쁜거 같아요',
#  '여자혼자서도 잘 설치할수있어요 좋습니다',
#  '기존에 있던 커튼은 암막이 하나도 안되어서 사봤는데 너무 예쁘고 웨딩드레스처럼 샤랄라한게 대만족이에요 아쉬운건 세로길이가 치수로 재면 딱 맞아야 하는데 아일렛 부분이 높아서 그런지 딸랑하네요 ㅠㅠ 그래도 길어서 머리카락 엉켜붙는것보다는 낫겠거니 하고 그대로 달았어요',
#  '넘 예뻐요 흰색이라 때가 탈까 조심스럽지만 예뻐서 감안하고 사용하려구요 암막이 100프로 되진 않지만 살짝 비치는 정도인데 이정도면 만족해요',
#  '저희집 거실 세로가 230 이어서 딱 좋을줄알았는데 막상와서보니 반뼘정도 짧아서 기존 커튼 거는식으로 걸어서 기장은 맞췄는데 커튼자체 커튼고리 구멍이 살짝보여 쫌 아쉽네요 한가지 아쉬운점이 있다면 망사원단 커튼끝과 중간 이음선끝 밖음질이 망사를 당겨서 밖음질 하셨는지 울어서 그 분분이 쫌 아쉬워요 참고로 1층이어서 밤에 집안이 보이면 어쩌나 했는데 하나도 안보이고 좋아요 전체적인 분위기 변화는 성공적입니다 밝아져서 기분이 좋아요',
#  '배송도 빠르고 색상도 질감도 진짜 딱 원하던 스탈이에요ㅠㅠ  촤르르르르 강추👍🏻👍🏻',
#  '빛도 잘 차단되고 이뻐요 잘 구매했어요',
#  '처음 배송받았을때는 냄새가 너무심했는데 하루지나니까 점점 괜찮아졌어요 그리고 가까이서 만져 봤을때는 저렴한 느낌이 없지않아 있는데 전체적으로 보면 너무이쁘고 가성비 좋아요 햇빛 비추면 샤랄라한게 맘에 들어요😄😄',
#  '사실 사이즈 두번째거 사고팠는데 품절이기도했고 집이 작아서 맞겠지싶어 작은거라도 주문했는데 설치하고나니 가로길이가 짧더라구용 ㅇㅅㅇ흑흑 환기시키려고 창문열기위해 의도한거라며 자기위안즁입니다ㅋㅋㅋ 그래도 너어무 이뻐요 ㅠㅠ 집 분위기가 바껴버렸어요 진짜 구매하길 잘한듯ㅠㅠ 통유리 오피스텔사는분들은 두번째사이즈 구매하시길',
#  '상품평이많은건 다 이유가 있더라구요 무조건 대박입니다 낮에도 너무좋아요 햇빛찬단되면서 집안은 밝고 너무좀아요',
#  '안방커튼으로 너무 이쁘네ㅣ요 분위기있어요',
#  '만족합니다 최고큰거샀더니 중간사도될뻔했어요만족합니다',
#  '저희집엔 좀 길긴 하지만 끝부분까지 막을수 있어 좋아요 완벽한 암막은 안되고 좀 밝아요',
#  '리뷰 잘 안쓰는데 너무 예뻐서 작성합니다화이트로 사라는 리뷰 보고 고민 없이 구매했는데 너무 마음에 듭니다 번창하세요',
#  '와 너무 예뻐요 전 사실 좀 얼렁뚱땅이라 하자 이런거 별로 신경쓰지 않는데 흘깃 봤을때 하자나 얼룩 하나도 없었고 그냥 끝장납니다 방 창문이 너무 별로라서 아예 벽 한면을 커튼으로 가려버릴 생각에 산 건데 달자마자 방이 확 밝아지면서 그냥 스튜디오 분위기 뿜뿜 최고입니다 할인 들어가서 완전 좋은 가격에 좋은 커튼 득템했네요 번창하세요',
#  '깨끗하고 좋아요 방이 환해져서 딸이 좋아해용',
#  '암막도 잘 되고 화이트라 집 분위기가 화사해져요넘 맘에 들어요',
#  '실물이 더 예뻐요 아늑한 느낌이 듭니다 가격도 착하고 질도 좋고 암막 잘됩니다 많이 파세요',
#  '흰색살까 베이지살까 엄청 고민하다가 베이지 선택 집이랑 찰떡으로 잘 맞아요 근데 커텐 너무너무 이뿌긴 한데 짧아서 슬프네요 ㅜㅜ 바람막이겸 암막겸 산거였는데 바람이 솔솔 들어와요ㅠㅠ',
#  '너무 이뻐요 봉타입하나에 커튼을 이중으로 사용할 수 있다는게 정말 좋은 아이디어같아요 가격대비 재질도 무난히 괜찮습니다 흰색이라 완전 암막은 되지 않는데 저는 구매 할때부터 빛이 조금은 비쳤으면 했기 때문에 아주 마음에 듭니다',
#  '두께감 있음 저렴해보이지 않음 디자인 가격 모두 만족',
#  '가성비 최고에여 커튼하나로도 집분위기가 달라지네여 이가격에 이 디자인에 딱이에요 안방에 걸었는데 사이즈도 딱맞아요 러블리해보여요 ',
#  '배송 진짜 빠르고 커텐 너무 이뻐요 딱 제가원하던 느낌입니당 ㅎㅎ',
#  '너무 분위기있고 멋스러워요 분위기가 확 다르네요배송두 무지 만족하고 추천합니다',
#  '예쁘고 좋아용 맘에 쏙 드네요 ㅎㅎㅎ',
#  '사진보다 실물이 훠어얼 이쁨 아주 고급짐 맘에 쏙',
#  '완전 마음에 듭니다 ㅋㅋㅋ길이가 조금 길어서 아쉽지만 ㅠㅠ',
#  '고급스럽고 예뻐요 설치도 쉬웠어요 배송도 다소 빠릅니다',
#  '커튼 진짜 이쁜데용 너무 이버여 아늑한 느낌도 들고 따뜻해지는 기분까지  다만 밑에가 좀 짧은데 강아지 키워서 더 낫겟다 싶어요',
#  '깔끔하고 하늘하늘하고 아늑해서 너무좋아요',
#  '좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ좋아용ㅎ',
#  '아이가 좋아하네요 괜찮아요좋아요 만족해요',
#  '너무 예뻐서 지인한테도 추천했어요',
#  '가성비 최고입니다 암막기능도 베이지인데도 괜찮습니다',
#  '좋아요 아주 잘 사용하고 있숨달 감사합니댱',
#  '빠른 배송 깔끔 가격대비 가성비 갑 너무 만족해요',
#  '적당히 암막되서 넘 좋아요 이쁘고 싼티안남',
#  '안방커텐으로 정말 좋아요 분위기있고 그냥 암막보다 훨씬 인테리어에 좋습니다 해도 적당히 은은하게 들어오구 우선 그냥 너무 예뻐요 ㅋㅋ',
#  '후기보고 살까말까 고민 많이 했지만 좋은후기들이 더 많아서 구매했어요ㅎㅎ 커튼봉이 아직 안와서 설치를 못했지만 이쁘게 달아서 나중에 더 좋은후기 남길게요',
#  '커튼도 방 분위기 바꾸는데 최고인 것 같아요 샤랄라 합니다',
#  '처음엔 너무 하얀색이라서 조금 후회했음 뭔가 집에 커텐만 붕떠있는 느낌ㅜㅜ 그런데 아침에 빛을받은 커텐의 모습이 너무예쁨 잘쓸게요',
#  '베이지랑 화이트중에 엄청 고민하다가 베이지 선택했어요 아늑하고 따듯한느낌이 좋으면 베이지강추입니당',
#  '거실에 딱이에용 넘 깨끗하면서 세련되보여용',
#  '역시 커튼은 화이트♡ 이뻐서 미친것같음',
#  '오 진짜 이뻐요 이 가격에 이 퀄리티에 촤르르 너무 이쁘네요',
#  '안방 창문이 가로 180인데 딱 두배해서 360사이즈 하니까 주름도 이쁘게 지고 좋아요 암막은 엄청 어둡게 되지는 않는데 빛은 다 차단해줘서 잠 잘때도 푹 잘것같아요ㅎㅎ',
#  '암막이 잘되길바래서 흰색보다 베이지색 암막 더될거같아서 선택했는데 완전 꿀잠 가능해요 완전 만족하고 이쁩니다',
#  '이사오면서 주문한건데 사이즈 완전 찰떡 넘나 이뻐요',
#  '너무 맘에 들어요 암막커튼인데 레이스 달려있어서 신혼방 침실에 딱이네요 빛차단은 100프로는 안되지만 화이트라 감안하고 샀습니다 그렇다고 불편할 정도는 아니고 80프로 이상 되는것 같아요 배송도 빠르고 가성비 좋습니다',
#  '크으 너무 예뻐서 만족스러워요ㅠㅠㅠ 방 분위기가 달라졌어요',
#  '쉬폰커튼을 사고싶었는데 쉬폰커튼은 암막이 너무 안될거같아서 찾아보다가 이 커튼을 보게되었는데 쉬폰커튼이랑 암막커튼 두개를 같이 달고싶었던 저에게 딱 안성맞춤인 커튼이였어요 그래서 품절이 풀리길 기다렸다가 샀는데 사이즈를 잘못알고 원래 시켜야되는 사이즈의 2배나 큰걸 시켰지만 그렇게 커보이지않고 예뻐서 다행이에요 화이트 완전 강추입니당 방 분위기가 엄청 밝아보이고 인스타갬성이 아주 뿜뿜해여 너무 예뻐요 다들 사세요',
#  '화이트로 하니 집이 화사해보이고 좋아요',
#  '진짜 잘샀어요 친규들이 집들이 와서도 커텐 사고 싶었던거라몀서 사야겟다고 하더라구요 러블리하니 예뻐요',
#  '이케아 커튼을 샀는데 갈색 몰딩이 그대로 비춰서 아쉬워서 다시 구매했는데 너어어어무 좋습니다 진짜 만족도 100프로에요 화이트인데 암막도 잘됩니다',
#  '베이지 색상 선택했는데 색상도 이쁘고 설치도 쉬워요암막 기능도 좋고요가성비 좋습니당',
#  '가볍고 산뜻해요 하늘하늘 예쁘네요 ',
#  '커튼 다니까 집 분위기가 달라져요 넘 예쁘고 만족합니다',
#  '화이트라 완전 깜깜은 아니지만 블링블링하고 분위기 살아서 흔한 암막커튼처럼 딱딱한 이미지가 아니예요 이뻐여',
#  '드레스룸에 찬기 차단 및 창문 가릴려고 삿는데 드레스룸이 정말 너무 예뻐졋어요',
#  '어머니 방 커튼 바꿨어요이쁘고 보온효과도 있구요 만족하셔서 저도 기뻐요',
#  '화이트를 구매한 사람들이 훨씬 많고 리뷰가 많이 올라와 있지만 화이트는 너무 부담스러워 망설이고 고민하다가 배이비핑크로 구매했는데 너무 만족합니다 핑크를 원래 좋아하는 사람은 아닌데 이 베이비핑크는 약간 톤도 다운되어 있고 은은한 핑크라 마음에 들어요 햇빛이 비치는 낮에 찍은 사진인데 암막정도는 저 정도로 나옵니다 완전 깜깜 암막은 아니지만 저는 개인적으로 만족해요',
#  '이뻐여 인테리어 효과도있구 맘에듭니다',
#  '크기를잘못해서 다시주문했어요 화이트 깔끔하니이쁘네요 조금길어서 끌려서아쉬워요',
#  '빠른 배송 좋았어요 근데 단점이라면 배송 왔을 때 박스 상태가 조금 좋지 않았었어요',
#  '완전암막은아니지만ㅇㅣ뻐요',
#  '암막커튼과 레이스가 같이 붙어있어서 따로 쓸수 없는 부분이 아쉽지만 예쁘게 잘쓸수있을것 같아요',
#  '너무 이뻐요 주위에선 흰색이라 관리할수 있겠냐고 하지만 진심 너무이쁘고 집도 밝고 따뜻해보여요',
#  '안방에 달았는데 화사하고 공주풍이예요',
#  '안방 작은방에 달았어요 이쁘고 맘에 들어요 암막 효과도 뛰어나요',
#  '안방에 걸었는데 화사해서 집콕생활이 즐거워 졌어요',
#  '커튼을 하니 집이 훨씬 넓어 보여요',
#  '안방 커튼으로 굿이네요 화이트로 하길 잘 한것 같아요 밤에 빛 차단률90 정도 되는것 같아요 배송도 빠르네요 강력추천합니다♡',
#  '360짜리했더니 길이만 살짝긴데 길어서 더 예쁜거같아요 폭은 맞춘것처럼 딱맞네요 집이 어두운편이라 화이트했더니 화사해졌어요 암막도 확실히되구요 이중망사커튼이 너무 러블리해서 볼수록 예뻐요 암막커튼도 이렇게 예쁠수있구나싶네요 감사합니다',
#  '배송도 엄청 빠르고 분위기 갑입니다 커텐 하나 바꾼거 뿐인데 너무 예뻐여',
#  '샤랄라 한게 맘에 들어요 커튼하나로 분위기가 달라졋어요',
#  '길이 잘 보고 구매하세요 결국 못 박았습니다',
#  '좋아요😆ㅎㅎ 봉은 약해보이긴 한데 그래도 튼튼해요',
#  '잘잗았습니다 예뻐여 색감도 그렇고 제 방과 아주 잘 어울립니다',
#  '생활 암막 정도 이며 레이스가 붙어잇어서 너무 이쁘고 길이도 제작주문도 아닌데 딱 맞고 너무 이뻐요 ㅠㅠㅠㅠ❤️❤️👍👍👍👍역시 커튼은 여기꺼가 채고에욤😋😋',
#  '진짜 최고에요 오랫동안 고민하지 말껄 그랬어요',
#  '길이감이 좀 길지만 샤랄라 예뻐요 빛이 은은하게 들어와서 완전 암막보다 좋네요',
#  '너무 이뻐요 사이즈도 잘봤어요 강추합니다',
#  '정말 정말 예뻐요가성비최고에요 레이스가 한겹 있는게 더 예쁘고 아늑한느낌이 배가 되네요허전했던 공간에 이 커텐을 다니 정말 달 라보여요♡♡',
#  '두껍고 너무 이쁩니다 ㅎㅎ 가성비좋음',
#  '가성비 갑 인정이요 너무 이뻐요',
#  '와이프가 너무 원해서 샀는데 실제 설치까지 하니 방벙뛰네요 이쁘다고 ㅎㅎ',
#  '너무 예뻐서 집에 분위기 살리는데 한몫하고 있어요 거실이랑 안방꺼 두 개 구매했어요 거실은 하얀색 안방은 핑크색인데 넘 예쁘고 레이스도 좋아요👍',
#  '커튼덕분에 거실이 너무 예뻐졌어요 감사합니다',
#  '배송도빠르고가격도저렴하고좋아요일단두가지버전으로쓸수릿어서조음',
#  '기장감이 좀길어서 세련된 느낌은 앖는데요분위기는 한결 안정감이 있어서 좋아요',
#  '너무 마음에 들어요 색깔도 길이도 딱 맞아요 풍성해보이기도 하고요 가성비도 짱이구요 감사합니다♡',
#  '너무이뻐요 싸게 잘삿습니당 두께도 두툼하고 울코스로 돌리니 변형도 없어용',
#  '이전에 집에 사고 너무 맘에 들어서 선물용으로 한번더 주문햇는데 지인이 맘이 든다고 난리네요 너무 이뻐요',
#  '배송도 빠르고 생각했던대로 예뻐요',
#  '완전이쁘요ㅎ 저렴한가격에 잘구매한것같으요',
#  '이사하면 쓰려고 모셔뒀다가 이제야 설치 했어요 수령하고 너무 하얀거 아닌가 교환을 망설였는데 많은 후기들 보면서 일단 달아보자 했어요ㅎ 확실히 넓어보이고 화사하니 좋네요 두겹이라 여러가지 연출도 가능하고 이렇게 해두니 해도 잘 들고 사생활보호도 되고 넘 좋네요',
#  '배송도빠르고 완전예뽀요 맘에들어요 ㅎㅎ 커텐봉고리듀 이미 뚫어진상태로와서 너무편하게설치햇어요',
#  '이뻐요 안방도 해가너무잘들어와서 더할라구요',
#  '택배온거 풀어봤을때는 아 괜히 샀구나 싶었는데 설치하고 보니 예쁘네요 가격대비 만족스러워요 아직 창문 하나 더 남았는데 핑크로 하나 더 사야겠어요',
#  '진짜 넘 예뻐요ㅠㅠㅜㅜ길이도 딱 맞고 아주 나이스입니당',
#  '조아여 졸라 고급스럽고 ㅠㅠㅠ 아름다워여',
#  '가격도 착하고 배송도 빨라요굿',
#  '너무이쁜데브라켓 길이를 생각못했네요조금끌리지만 딸방에 걸었는데 너무 만족 해요',
#  '암막커튼이랑 함께있어 빛차단도 적당하고 좋아요',
#  '배송도 빠르고 가격도 좋고 아주 예뻐요 ㅎㅎ',
#  '햇빛 비추면 이정도 되네요 만족합니다',
#  '처음엔 좀 약해보였는데 설치해보니 안정감있어요 너무 이쁘네요',
#  '커튼 너무이뻐용 잘산거같아용 너무마음에 들어요',
#  '화이트 샀어요 예쁘고 우아합니다 맘에 쏙 들어요',
#  '이사하면서 커튼이 필요해서 구매했어요 화이트 커튼은 처음 써보는데 때가 탈거같긴하지만 너무 이뻐서 만족합니다',
#  '저렴한 가격에 예쁜 커튼 득템했네요 세로 길이가 짧을까 걱정이었는데 맞아 너무 좋으네요',
#  '베이비핑크 아니고 인디핑크 입니다 볕 들어오면 베이비핑크일 것 같지만요 설치 쉽구요 암막인데 무겁지도 않구요 샤가 너무 이쁘네요 ㅎㅎ 세일할때 언능 사세요ㅎㅎ',
#  '혼자서도 쉽게 설치했어요 예쁘게 잘쓸께요',
#  '앞쪽이 화이트 뒷쪽이 크림베이지에요 어둡게 하고 촬영해서 느낌이 안사는데 암막도 잘되고 분위기도 따뜻해졌어요',
#  '분위기 갑 설치도 쉽고 냄새도 안나서 좋았어요 배송도 빠르고 다 좋아요 ',
#  '설치도쉽고 이뻐요 깔끔하네요 베이지보다흰색이이뻐요',
#  '정말예뻐요 햇빛도 은은하게 들어오고 너무 어두운 암막은싫었는데 딱 원하던거라 정말 맘에들어요',
#  '이거 커텐 진짜 너무이쁩니다ㅠ 암막도되고 레이스도 있구 배송도빠르거 제일맘에들어요',
#  '너무 좋아요 암막커튼으로 원래 그레이색 했었는데 너무 칙칙한 느낌이라 바꾸고 싶어도 주말에 늦게 일어나고싶은 마음등등으로 암막커튼만 취급했었는데 아니 화이트로 암막이 가능할줄은 몰랐어요 게다가 이렇게 이중으로 넘 샤랄라 하고 넓어보이고 고급스러워 보여요 ㅠㅠ 여기서 산것중에 진짜 손꼽히게 맘에들어요 다는것도 넘 쉽게 달았네요 무게는 좀 있어서 힘들었지만요 진짜 넘 예뻐요 ㅠㅠㅠ 판매자님 번창하세요',
#  '너무 예쁘고 좋아요 잘 샀어요  따스해보여요',
#  '이뻐요 근데 저희집에는 조금 긴느낌ㅠㅠ 수선하기엔 배보다 배꼽이 더 큰격이라 그냥 쓰려구요',
#  '고급저보여요 역시 후기보고 사길 잘했습니다 배송도 빨라용',
#  '화이트 계열이지만 암막 기능이 있어서 좋아요 저렴하게 잘 샀습니다',
#  '설치도 쉽고 넘 만족해요암막이라 좋와요',
#  '리뷰가 많은 이유가 있네요 베이지색상으로 했는데 집 분위기랑 아주 찰떡입니다 길이감도 너무 이쁘게 떨어져요 창문 살짝 열어두고 살랑살랑하는거 보면 기분 너무 좋아요 어디하나 흡이 없습니다',
#  '거실에 하고 이번에 안방에 했어요 분위기 있고 아늑해서 방안에서 나가기 싫을정도 입니다',
#  '창문이 아니라 주방 가리려고 샀는데 이뻐요 진짜',
#  '2중 커튼이라 흰색인데도 불구하고 빛 차단 잘 돼요 무엇보다 예쁩니다',
#  '와우 고민말고 사세여 도톰해서 바람도 막아주고 ㅎ ㅎ 커텐집은 비싸서 엄두도 못냇는데 완죤 만족해요 사세요 520싸이즈 햇어여 거실',
#  '이가격에 이퀄 괜찮네요 길이를 잘못재서 ㅜㅜ 봉길이가 불안불안하네요',
#  '일단 화이트는 정말 하얘요ㅋㅋㅋ 누렇게 된 부분도 있어요',
#  '배송 엄청 빠릅니다 저 처럼 빨리 막 바꾸고 싶은 사람들 한테는 너무나 즐거운 일이죠ㅎ 커텐 예쁩니다 설명 필요없이 그냥 사세요ㅋ 후회 안합니다 화이트는 암막 효과 기대하지마세요 저는 처음부터 이쁜것만 생각했기 때문에 넘 만족합니다 가운데 레이스는 이케아에서 주문 한겁니다',
#  '한층 아늑해진 방 분위기에 너무 만족 합니다 🥰',
#  '배송도 빨랐고 물건도 너무 좋아요 암막덕분에 요즘 푹자고있어요 추천합니다',
#  '예쁘네요오랫만에 커텐을 달았더니 가족들이 호텔같다며 좋아해요문틈 바람도 막아줘서 요즘날씨에 달길 잘한거같아요가격대비 퀄리티 좋아요 배송도 엄청 빨라서 깜놀강추해요',
#  '길이도 컬러도 적합 완전암막 아니어도 70는 채광 기려주고석유냄새 살짝 나지만 금방 날아갈 것 같음 만족',
#  '깨끗하고 예쁘네요 많이 실용적이에요 잘산듯',
#  '이중인데도 다른 커텐가격하고 비슷하게 구입했어요 암막기능도 좋고 색상도 예쁩니당 ㅁ',
#  '우리집 370인데 530으로 시킴 아주적절함 생각보다 큰데 안뚫어고리 부족해서 그대로 둿다가 한동안 방치해서 달았더니 쭈글해짐 쭈글해지는거 펴느라힘들었지만 나름 괜찮음 한부분이 계속 쭈글어져있는부분존재함',
#  '이번에 산 것 중에 제일 마음에 들어요 ㅠㅠ 가격대비 넘넘 좋네요 암막도 잘되고 그냥 넘 좋네요 예뻐야 ㅠㅠ',
#  '커튼이 보면 볼수록 예뻐용 암막효과도 좋은 것 같고요',
#  '아주 맘에 듭니다 꼭 사세요 살까말까 하는 시간에 사세요',
#  '너무너무 예뻐요 햇빛 차단에 디자인까지 모두 만족입니다',
#  '진짜 방도 환해지는 것 같고 너무 예뻐요ㅠㅠ',
#  '계속 품절이어서 겨우겨우 득템했네요 역시나 예뻐요 낮에 찍을라고 했는데 불빛받아 예쁘네요 밤에도 번창하세요',
#  '고급지고 예뻐서 너무 마음에 들어요👍',
#  '암막도 잘되고 흰색레이스와 있어서 투박한 느낌없이 방분위기에 잘어울려요 배송도 빠른편이고 가성비가 좋은제품이라 부모님방에도 해드렸어요',
#  '커튼 무난히 쓰고있습니다 만족하고있어여',
#  '방 분위기가 완전 포근해졌어요 층고가 높아서 젤 큰거를 했지만 바닥이 저렇게 보이는거 빼곤 대만족입니다 ㅋㅋㅋㅋ',
#  '화이트라살짝걱정했는데너무이뻐요💕 암막은좋은데거실이라서 적당한거찾고있었는데완전딱이네요',
#  '커튼하나 다니까 신혼분위기 확나네요 ㅎㅎ 생각보다 무게가 있어서 고생했지만 달고나니까 뿌듯해요',
#  '너무이쁘고 암막도어느정도되네요',
#  '이뻐요 너무 좋아요 층고가 낮아서 그런지 조금 끌리지만 나중에 이사하게될경우를 생각해서 자르기가 아깝네요ㅠ 근데 차르르 떨어지는 느낌에 암막도 되고 좋아요',
#  '너무 예뻐요 거실 커튼 바꿔달아봤어요 화사하네요',
#  '디자인이 너무 예뻐서 재입고 기다리다가 바로 주문했어요 기대한만큼 너무 예뻐요 사이즈도 딱이에용',
#  '진짜 너무 예뻐요 당장사세요 한가지 단점은 커튼 분리가 안되는것 하지만 전 너무 만족해요 ㅠㅠ 고민은 품절만 불러올뿐',
#  '사진 그대로 깔끔하고 너무 이뻐요',
#  '커튼 비싼거 살 이유가 없어요완전 맞춤이네요너무 예뻐요 구매 강력하게 추천합니다',
#  '새벽 햇살나올쯤 조명없이 보정없이 찍어봤습니다 흰색이지만 암막이중커튼이라 밤에도 무리없이 보호해주더라구요 고민많았던 제품인데 실제 사고보니 젤 이쁘다는 말을 자주듣게해준 제품이라 만족입니다 인데리어 같은거 할줄모르지만 이거 하나로 집이 3배커진느낌이예요',
#  '집이 한층 분위기 있어지고 예뻐요',
#  '기대이상입니다 커튼이쁜건 가겨이 좀 있던데이 커튼은 가격대비 훌륭해요👍방이 살랑살랑해졌어요',
#  '사이즈 딱 색상좋고 차르르 떨어지네요 맘에 들어요 퇴근하자마자 개봉하여 설치 하니 예뻐요',
#  '집이 엄청 화사해졌어요 ㅎㅎㅎ 너무이쁩니다',
#  '두개째 구매했어요 엄마방에 사드렸는데 예뻐보여서 제방에도 달았어요화이트암막이다 보니 완전 어둡게 암막이 되지는 않지만 은은한 암막이라 더 맘에 들고 암막 위로 쉬폰 커튼이 분위기 있어 보이고 예쁘네요 항상 빠른배송도 좋네요 ㅎㅎ',
#  '예뻐요 깔끔해서 화이트의 매력에 빠집니다 봉이 좀약해서 약간 휘어지는것 빼고는굿 입니다감사해요',
#  '소파와 색감이 찰떡이에요  분위기 넘 좋네요 암막역할도 넘 좋고 너무 잘 산거같아요 배송도 빠르고 만족해요',
#  '진짜 너무너무 만족하고 예쁩니다 이 가격에 이런 퀄리티라니 감동이네요',
#  '기존에잇던커튼이랑 갖이매치시키니까 더예쁘네요 맘에들어요 강츄합니당',
#  '생각보다 배송빠르게 왔고 암막이라 빛도 잘 차단해줘요',
#  '봉 튼튼하고 좋아요ㅋㅋㅋㅋ잘 버텨주길',
#  '정말 너무 이뻐요 덕분에 집이 너무 화사해졌어요',
#  '디자인이 너무 이쁩니다 흰색이라 암막은 솔직히 기대 많이 안했는데 생각보다 기능이 좋습니다 ㅎㅎ',
#  '전에꺼 실패하고 구입한건디 너무 맘에들어요 ㅠㅠ',
#  '배송도 빠르게왔고 커튼 진짜 부드러워요 마감처리도 좋아요 조금 무거운데 레이스까지̆̎ 달린거 치면 정말 좋아요',
#  '인디핑크랑 베이비핑크랑 고민했는데  베이비핑크도 괜찮네용 더 방이 화사해보여서요  ㅎㅎ',
#  '가격도 착하고 디자인도 너무 예뻐요 암막커튼 질감도 너무 맘에 듭니다 커튼박스부터 달아서 그런지 커튼 아래가 약간 짧은데 그래도 괜찮아요 너무 예뻐요',
#  '하얗고 샤랄라하고 너무 예쁘네요ㅎㅎㅎ',
#  '며칠을 한참 기다렸어요 사이즈때문에 ㅜㅜ 근데 보람있어요 생각했던 그대로고 너무 이뻐요ㅠㅠ',
#  '화이트엄청깔끔해요 안방에 설치했는데넘넘예쁘네요',
#  '이가격에 이렇게 고급스러운 커튼이 있다는게 너무 놀라워요ㅠㅠ 달고나서 집 분위기가 완전 바껴서 너무 감동이에요 넉넉하게 하려고 530으로 샀는데 하나로도 충분해서 하나는 다른 문에 달려고 합니다 너무 조아여',
#  '조금 더 준만큼 값어치 있게 좋네요 ㅎ',
#  '진작 살껄 ㅠㅠㅠ 넘 예뻐요 ㅠㅠㅠ 샤랄라',
#  '추가 주문 고민중일 정도로 정말 좋아요',
#  '너무너무너무만족해요진짜 생각한것보다 다 너무예뻐요 ㅠㅠㅠ 이제 안방이랑 작은방 다용도실것도 주문하려구요 완전대만족 추천합니다 이 가격에 이 커튼 못사요',
#  '넘무 예뻐요 진짜 가성비 짱인 것 같아용',
#  '이사가서 쓸거라 아직 못달아봤지만 기대됩니다',
#  '배송 설치 적당한 가격에 맘에 들어요',
#  '집이랑 침대랑 잘어울려요 예뻐요 추천',
#  'ㅜㅜ커튼3개째실패했는데 이번꺼는대박성공♡♡ 가성비진짜좋아요 뒤에확실히가려집니다 창이이쁜집이었음 얇은커튼만으로도이쁠텐데 옛날집이라그냥가려버려쓰여ㅋㅋㅋ 담달에하나더사려구요',
#  '배송도 빠르고 설치도 쉬워요 결정적으로 너무 예쁩니다',
#  '이중커튼이 너무 하고싶은데 커튼 레일이 아니라 고민하던중 찾은거예요 생각보다 더 예쁘고 흰색이지만 암막도 잘되요 살짝 길어서 밑에가 끌리지만 그것마저도 이뻐요 ㅎㅎ',
#  '아일렛인데 쉬폰 느낌 찾기가 힘들었어요 암막 뒤에 이쁘게 두겹으로 되어있어서 너무 예뻐요',
#  '너무예뻐요 큰방 커튼도 여기서 샀는데 레이스짱예쁘고 거실커튼도 사이즈나 디자인이나 만족입니다 흰색이라 완벽암막은 아니지만 거실이라 느낌이 딱 좋아요 4시쯤 찍은 사진입니다',
#  '거실이 ㄱ자로 창문이 있어서 큰거 작은거 구입해서 다 달았어요 샤랄라하니 이뻐요',
#  '커튼 정말 천도 좋고 예쁘고 200퍼센트 만족입니다 아빠도 커튼 잘 샀다고 칭찬해주셨어요',
#  '좋아요 안방하고 거실 다이커튼이에여 암막인데 회색빛안돌고 최고에요',
#  '예뻐요예뻐용예뻐요오오진짜예쁘요₩',
#  '정말 깨끗해요 단지 구겨짐이 있어 전 스팀다리미로 다렸더니 구김이 그나마 사라졌네요 깔끔해요',
#  '100프오 암막말구 빛이 은은하게 들어오는 커튼을 원했는데 딱 좋아요 정말 이뻐요',
#  '커텐 이거산게 신의한수에요넘나리 예쁨',
#  '퀄리티 아주좋아요♡ 집안 분위기가 화사해지고 겨울에 방한 효과도 있네용',
#  '존나이쁨요어어어어어아아아ㅏ아아어오오오ㅗ옹',
#  '안방 아침햇살입니다 너무 예뻐요',
#  '도어대신 파티션으로 사용하는데 은은한 크림색과 잘 어울려요',
#  '커튼 하나로 분위기 완전 바꼈어요 이뻐요',
#  '너무너무 예뻐서 난리입니다 암막커텐이 이렇게 예뻐도 되냐고 ㅎㅎ 대만족입니다',
#  '울 딸방 햇빛이 해질때까지 들어 오는 방이라 이 암막커튼이 딱인것 같아 주문 했는데 배송도 빠르고 설치 방법도 숴웠어 정말 맘 에 들고 울 딸이 드레스 같다고 좋아 하네요 방이 은은 하니 딱 좋아요 원하던 커튼 이에요',
#  '커튼봉 커튼 모두 가장 큰사이즈로 했어요  18평20평 정도의 거실이구요  커튼길이가 살짝 길어서 조금 아쉽지만 전체적으로 디자인이 넘 이뻐요  속커튼과 레이스커튼 모두 소재가 톡톡해서 고급져요 싼티안나요 ㅎㅎㅎㅎ 화이트하길 잘한거같아요 관리는 좀 빡씨겟지만 넘 맘에들어요오',
#  '정말 너무너무 예뻐요 너무 하얘서 병원 느낌 나면 어쩌나 했는데 조금 오바해서 호텔느낌나요 ㅠㅠ 방이 워낙 작고 어수선 했는데 커튼 하나로 화사해졌어요 암막에 레이스가 겹쳐있는 디자인이라 사랑스럽고 암막 특유의 탁한 느낌이 없어요 제방엔 360 사이즈가 딱인데 방이 큰 분들은 더 폭이 넓은걸로 추천드려요 새 냄새는 좀 나는데 시간이 해결해 줄거라 믿습니다 배송도 총알이에요 금요일 아침에 결제하고 토요일에 받았어요 bbb',
#  '말이필여없어요ㅡ너무이쁩니다♡빛차단도 잘되요',
#  '이전보다 집안이 환해진 느낌이예요 화이트커텐사고싶었는데 너무만족합니다 가격대비 완전굿이네요',
#  '커튼 크림베이지 색 예뻐요 안방에 하면 따뜻한 분위기가 살아나네요 빛 차단도 꽤 잘돼요',
#  '보는 그대로 너무 예뻐요 디자인 보자마자 이거다 싶어 바로 구매했습니다 쉬폰느낌으로 호텔 느낌도 나면서 단열과 암막도 필요해서 이중으로 커튼을 달아야하나 고민했는데 마침 딱 이 디자인 만나서 바로 달았어요 커튼 봉이랑도 너무 잘 어울리고 저희집 길이랑도 딱이라 진짜 맞춤으로 제작한 거 같아요 화이트라 때 안타게만 잘 관리하면 더할나위 없이 좋을 제품 같아요 프로방스한 느낌을 살리고 호텔 느낌도 원하시면 딱입니다 배송도 빨랐어요',
#  '오자마자 세탁하고 바로설치했어요 너무이쁘네요잘산거같아요',
#  '저는 뒤에 행거 옷 가리는 용도로 구입했는데 진짜 넘넘 마음에 쏙 들어요 정신 없던 방이 아주 조금은 정리됬습니당',
#  '전세집 브라운 색상에 칙칙한 블라인드를 떼버리니 속이 다 후련 덕분에 집에 화사해졌어요 몇몇 후기에 못이 짧아서 설치하는데 힘들다 해서 걱정했는데 저는 튼튼하게 쉽게 설치했어요 만족합니다D',
#  '화면보다 실물이 더 예뻐요 사길 잘했어요',
#  '집이화사해보이고이뻐요 암막도 확실하네요',
#  '생각했던것보다 더 예쁘고 샤랄라 웨딩드레스같아요 완전 암막도아니고 딱좋아요',
#  '이뻐요 아직 설치전인데요 넘 이쁠거 같아 기대되요',
#  '생각했던것보다 암막효과를 볼것 같아요 이중으로 된 레이스도 이뻐요',
#  '보시다시피 예쁩니다 레이스랑 같이있어서 공주풍스럽죠 인테리어 하기도 분위기있어 보이고 맘에들어요',
#  '커튼이뻐요 베이지라서암막이잘안될줄알았는데 암막도나름잘되고만족합니다',
#  '동생방에 있는거 너무 이뻐서 똑같은거 구매했어요 화이특컬러인데도 햇빛차단 잘되고 깔끔하고 이뻐요',
#  '배송 진짜 빨랐어요 시킨 다음 날 와서 놀랐어요 ㅋㅋ 그리고 커튼 너무 예쁩니다 레이스가 싸구려 같다고 많이 ㅎ ㅏ샤서 기대를 전혀 안 했는데 그래서 그런지 전 괜찮았어요 ㅎㅎ 묶으면 더 예쁠 것 같아서 설렙니다',
#  '너무너무 이뻐요 잘쓰겠습니다ㅎㅎㅎㅎ',
#  '예쁘고 차르르 하니 좋네요 커튼봉이어서 아일렛으료 선택했어요',
#  '화이트색상 깨끗하고 이중 레이스라 더 풍성해보이고 이뻐요',
#  '가격도 좋고 재질도 좋네요 배송도 엄청빨라요 덕분에 아늑하고 예쁜집이 되었네요',
#  '산것중에 젤로 맘에드는 커텐이여요 존예임',
#  '생각보다 더 크고 예뻐요 무엇보다 예뻐요 최고',
#  '차르르 떨어지는게 너무예뻐요 침실 분위기가 확삽니다 ',
#  '조아요강추',
#  '예뻐요 정말 예뻐서 만족합니다 그런데 저희 창에 아주 조금 짧아서 아쉬워요 ㅠㅠ',
#  '배송도 이틀만에 엄청 빨리왓구요 디자인도 샤랄라하니 이뻐요 ㅎㄹ 설치하는것도 별로 안어려웠습니당',
#  '사진 그대로구 예뻐요 😆 저희 집에 길이도 딱 맞아서 수선 없이 바로 설치했습니당',
#  '품절이라 오래기다렸지만 배송도 빠르고 너무 예뻐요',
#  '너무 예뻐요 침실 분위기도 좋고 아침에 일어났을때도 기분 좋아요',
#  '다 좋아요 딸들도 이쁘다고하고 우리커튼한거보고 맘에든다고 다른지인도 했어용',
#  '저희 거실 450x240이라 530사이즈 구매했어요 살짝 짧은데 끌리는것보단 나아요 ㅎㅎ 넘이뻐용',
#  '딱 예뻐요 구김만 없어지면 더 예쁘겠어요',
#  '또 재구매햇어요 너무 예뻐요',
#  '처음으로 커텐을 제가 골라서 사 봤는데 일단 사진 이랑 똑같아요 ㅎㅎ 지금은 밤이라서 잘 안보이는데 아침에 햇빛들어오면 어떨지 빨리 보고싶네용 디자인은 만족 합니당',
#  '정말 새하얗습니다 가격도 착하고 배송도 빨라요',
#  '커튼 생각했던 것 보다 더 이쁘고 걸어놓으니 인스타감성 그 자체네요ㅎㅎ 저는 빨리 사용하고 싶어서 따로 세탁을 안하고 바로 걸었는데 냄새가 많이나서 좀 힘들었어요 ㅠㅠ 그래도 한 3일 환기하니까 냄새는 잘 빠졌어요 그래도 속커튼과 겉커튼같이 있어서 편하고 분위기 있게 변해서 인테리어 변경하고 싶으신 분들은 추천드립니다',
#  '거실에 커튼이 없어서 허전해보여서 주문했어용 화이트라 깔끔하고 레이스까지 있으니 집 분위기가 확 달라지네요ㅋㅋ 화이트라엄청 어둑하게 암막이 되는건 아니지만 낮에도 아늑한 분위기라 너무 좋아요ㅋㅋ 거실엔 어두우면 안되니 화이트하길 잘한가같아여',
#  '거실에 설치했어요 적당히 분위기도 좋고 이중이라 너무 예뻐요',
#  '안방에 달아놨는데 색도 딱예쁘고 좋아요 포근한느낌이에요 길이가 약간 길까싶었는데 딱맞아서 다행이네요',
#  '너무예뻐요 제방을 따듯한느낌으로 보여주는 최고의역할즁 암막효과도 최고',
#  '너무너무너무예뻐용 화이트라 밝고 화사하니 예쁩니당 ㅎㅎ',
#  '공주같아여예뻐요생각보다 무거워여낑낑거렸어옄ㅋㅋ',
#  '레이스에 암막 달리거 까지 찾았었는데 두가지를 한번에 가질수 있어서 너무 좋았어요 ㅎㅎㅎ 이제 햇빛 걱정없는 하루를 살꺼같아요 고마워요 번창하세요 ㅎㅎ',
#  '샤랄라한 분위기 연출해주고 예뻐요 저는 치수를 더 큰것을 사야했는데 잘못맞춰서 아쉽지만요ㅠ 가격대비 이주 잘 산것 같아요',
#  '속커튼 암막커튼 둘다 구매하고싶을 때 짱이예요 정말 마음에듭니다',
#  '멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍멍',
#  '설치도 쉽고 이중이라 찬 냉기도 막아줘서 보온효과도 있으며 무엇보다 디자인 너무 예쁜거아님',
#  '커튼 드디어 방정리하고 달아요 너무 맘에 드네요 쪼끔 긴감이 있지만 그래도 죠아용',
#  '좋아요 완전화이트에 하늘하늘해서 너무 이뻐보이네요 기분전환을 집게핀 이쁜거 달아서 장식하려고요',
#  '커텐이랑 침구만 바꾸어도 방이 훨씬 환해지고 들어갈 때마다 기분이 좋네요 ㅎㅎ 탄력받아 작은방 것도 재구매하러 들어온김에 리뷰올립니다',
#  '전에 사용했던 제품 재구매했어요 흰색이라 암막커텐이어도 많이 답답하진않네요',
#  '다음에 이사가도 이 커튼 사려구요 너무 예뻐요 ㅠㅠ',
#  '커튼이 풍성해서 고급져보여요 생각보다 너무 괜찮앗어요',
#  '커튼봉을 같이 구매했어야했는데 따로 구매해서 겨우 설치했네요 ㅎㅎㅎ 빠른배송 감사합니다 설치하고나니 거실분위기 good ㅎㅎ 샤랄라분위기 좋아하시는분에게는 추천드려요',
#  '대만족입니다 남편도 너무 예뿌다고 칭찬해줬어유🤍',
#  '배송빠르고 이뻐요 암막도 잘될꺼같아요',
#  '50프로 정도 햇빛 막아주는 거 같고 예쁘고 좋아요 가성비 최고입니다',
#  '거실에 달고 고급스럽고이뻐서 안방에도 이제품으로 구매햇어요 봉나사가 짧아서 철물점 왓다갓다하긴했지만 제품은 모두 다만족합니다',
#  '깔끔해요 예쁘게 안묶여서 그냥 풀렀어요 화이트라 빛 있으면 조금은 비칠거 같긴 하지만 깔끔해서 좋습니다',
#  '집안 분위기가 달라졌어요 꼼꼼한 포장도 너무 감사드립니다',
#  '집안 분위기 엄청 바꼈어요 너무 이뻐요 이가격으로 이런 퀄리티라니 굳굳 암막도 엄청 잘되요',
#  '무난깔끔하니 예뻐요 재구매했어요 나비주름 핀형으로도 제작부탁드려요ㅠㅠㅠㅠㅠ',
#  '230높이에 좀 길긴하지만 너무 예뻐용',
#  '너무 이쁜 것 같아요 세일 중이라서 가성비 좋게 샀네요',
#  '행거 가렸는데 안에 옷 하나도 안비치고 너무 좋아요 단점이라면 커텐이 길어서 바닥에 질질 끄는게 단점이네요',
#  '흰색이라 넘나 이쁜것 존예로움',
#  '비치는건 싫고 커튼 두개달긴 복잡해서 선택한 제품인데 넘 만족하고 쓰고있습니다 ',
#  '커튼 넘 이쁘고 사이즈도 적당 맘에 쏙 드네요 약간 무게감이 있는것 빼고 최고임다',
#  '커텐하나 달았다고 집이 이렇게 화사해졌네요 가격대비 품질짱입니다 조립도 너무 쉽고 간편해서 금방 설치했어요',
#  '방은 암막이 되야해서 베이지로 구매했는데 맘에 들어서 작은방도 같은걸로 재구매했어요',
#  '재질도 좋고 디자인도 이뻐요 사진이랑 완전 동일합니다',
#  '밤에 이정도 암막이예요 사진보다 실물이 예쁘네요',
#  '화사합니다ㅎ 바닥에 커텐이 끌리는걸 안좋아해서 5센티정도만 짧으면 참 좋겠지만 어쩔수없네요ㅎ 처음에 한쪽만 걸었다가 냄새가 나서 건조기시트넣고 먼지 털고 했더니 냄새는 안나요 살짝 주름진 부분이 있어서 다림질하고 싶은데 흰색이라 혹시 잘못될까봐 그냥 걸었습니다ㅎㅎ 분무기로 물좀 뿌려주고 걸어두면 무게감이 있어 펴질것도 같아요 저녁에 설치해서 햇빛이 어느정도 들어오는지는 모르겠네요ㅎ 내일 기대합니다',
#  '커튼 정말 예뻐요 ㅎㅎ 하늘하늘한게 넘 이쁩니다',
#  '까탈쟁이 실시간후기에요 리뷰에 싼마이같다는 말이 많아서 걱정했어요 ㅠㅠ 가구 들어오기전에 커튼 며칠 알아보고 먼저 시켰는데 시키기전에 엄청 스트레스받다가 가격적인 면에서 괜찮은 듯 해서 결국 베이지루 시켰어여 결과물은 만족이에요 😄 언니랑 둘이 했는데 그렇게 고생하지두 않구 잘 된거 같애서 기분이 좋아요 아직 거실에 가구가 다 안 와서 텅텅이지만 가성비 면에서 본다면 이건 정말 괜찮은 거 같은데요 엄청 예민하시면 그냥 비싼커튼 알아보고 사심 될 거 같고 제일 큰 커튼 세트로 했는데도 이 가격에 묶는 방법에 따라 연출하기 나름이고 딱히 눈에 띄는 하자가 없는 제품이라서 저는 당당히 추천합니다 저 까다로운편인데 가성비 엄청 따지거든요 근데 진짜 이정도면 합격이에요👋🏻😃',
#  '커튼너무 예쁘고 가격도착해요 ㅎㅎ 덕분에 크리스마스때도 새해에도 예쁘게 꾸며서 사진찍었어요',
#  '조금 넓은 벽에 전체적으로 커튼을 넣을거라 적당한 커튼을 찾다가 구매했어요 커튼 하나만 달았는데 방이 화사하고 아늑한 느낌이 들어서 아주 만족스럽습니다 배송은 아주 빨랐고 커튼 자체의 품질도 가격대비 훌륭해요 밝은 색상을 구매했지만 암막효과도 아주 좋아요 한 낮에 커튼을 쳐두고 불을 모두 끄면 저녁이 된 느낌이에요 안쪽 커튼은 생각보다 어두운 편인데 레이스를 내리면 하얀색상으로 덮여서 색상이 좀더 연하고 밝아보입니다',
#  '햇빛 잘 가려져요 나눠서 묶으면 예뻐요',
#  '방이 정말 화사하고 분위기 있어요 햇살이 간접적으로 들어오는데 넘 기분이 좋아지는 그런 느낌이예요 강추요',
#  '커튼이 넘이뻐요 묶어도이쁘고 그냥두어도이쁘고 너무 암막아니라서 더좋드라구요',
#  '넘 이뻐용 사이즈 대충 보고 샀는데 딱 맞아서 넘 좋았어요',
#  '샬라라하지만 완전 암막차단되어 바람도 막아주고 좋으네요',
#  '어머님댁에 해드리려 주문했는데 사이즈가 너무길어 설치못하고 있네요ㅜㅜ 저령한가격에 잘산거 같아요',
#  '시어머니가 너무 예쁘시다고 또 구매햇네요',
#  '불량왔는데 하루만에 빠르게 배송해주셔서 금방 달았어요 감사해요 커튼 너무너무 이쁩니다 저희장 길이에도 맞춤처럼 딱 맞아서 기분좋네요',
#  '잘쓰고있어요 암막도 잘됨요 ㅎㅎㅎㅎ',
#  '너무 예쁘고 집이 훤해 보여서 좋아요',
#  '사이즈도 좋고 너무 이뻐요 레이스 묶을 끈이 없어서 밋밋해보이지만 이쁜 끈으로 묶으면 공주방 될거같아요',
#  '쉬폰같은걸 하고싶었는데 저희집이 추워서 이걸로 했는데 만족해요',
#  '넘넘예뻐요 딱제가원하던 느낌이예요',
#  '조금 길이는 길지만 맘에들어요암막도 잘되고 이쁘네요',
#  '아주좋아여 만족스러워요 길이나 두께도 적당스',
#  '샤랄라 하니 이뻐요 외풍도 잘막아주고 완전한 암막은 아니지만 그래도 조하요',
#  '여기 커튼만 세개째사서 쓰는즁이에여 속커튼 안커튼 2중으로 달기 너무 귀찮고 가격도 신경쓰이는데 이건 가격도 싸고 암막 기능도 좋고 분위기까지 나오니까 너무 조아여 넘 잘쓰구 있쯤더',
#  '이중 커튼 달고 싶었는데 안에 블라인드가 있어서 고민하다가 이걸 샀어요 ㅠㅠ 커튼다는 곳이 다 차있어서 레일형으로 사고 싶었는데 레일형이 없어서 아쉬워요 길이 선택도 할 수 있으면 좋을 것 같아요길어서 단이 많이 끌리긴 하네요 그래두 볼 때마다 넘 예뻐서 만족',
#  '하늘하늘하고 이뻐요 재질도 좋고 완전 좋아용',
#  '깨끗한 화이트컬러라 집에 정말 잘어울리고 암막이 완벽하게 되진않지만 은은하게 볕들어오는게 예쁩니다 완전 대만족이에요',
#  '예쁩니다 길이가 길까봐 걱정했는데 딱이에요',
#  '하얀색 커튼을 원했는데 잘 산 것 같아요 촤르르 떨어져서 너무 예쁘네요',
#  '아주 잘 사용하고 있습니다 너무 좋아요',
#  '커텐하나만으로도 분위기 바뀔수잇어요ㅠㅠ넘나 좋아용',
#  '분위기가 달라졌어요 너무 만족합니다',
#  '너무 맘에들어요 커튼만 했는데 집이 따뜻해보이는거있죠ㅎㅎ 색상도 너무 고급지고 넘 이뻐요',
#  '흐 커텐하나로 집분위기가 살아요 짱 ㅋㅋㅋ',
#  '커튼이 참 예쁘네요 촤르르 떨어지고 암막커튼에 밖에 레이스까지 너무 좋은가격에 잘 샀습니당 갑자기 공주님방 된것같아서 너무 맘에들어요🤍',
#  '이중인데 햇볕도̆̈ 잘 막아주고 여러모로 깨끗해보이고 기본에 충실하면서 예쁜 디자인입니당',
#  '깔끔하고 사이즈도 딱맞아요',
#  '길이는 넉넉한게 나을뻔했어요 암막은 많이안된다고해서 샀고 오히려 빛이 들어오니 좋습니다',
#  '설치도 쉽고 저렴하고 좋아요 화이트 이지만 암막도 되네요',
#  '우와아 너무 이뻐요 냄새가 좀 나서 밖에 며칠 널어두다가 걸었어요 길이도 다행히 딱 맞아야',
#  '커튼하나로분위기가 확 달라지네요 화사해지고 너무 예뻐요 창문이 큰집으로 이사가면서 제일하고 싶었던게 예쁜커튼 사는거였는데 소원을 이뤘어용 ㅂ다양하게 묶어서 연출도 가능해서 낮이나 밤이나 활용 다양하게 할수있을것같아요❤️',
#  '커튼달고 침실분위기가 아늑하게 바꼈어요이중이라 다양하게 분위기 낼수도있고 넘넘 맘에 듭니다',
#  '진짜 이뻐요 ㅠ 완전 레전드 이사하면서 산것 중에서 젤 맘에 들어용',
#  '방구조 바꾸면서 구매했어요 화사해서 너무 예뻐요 작은 창문인데 침대 옆이라 추울듯해서 긴걸로 달았어요 확실히 찬기운 막아주고 좋네요♡ 사진찍고보니 더 맘에 들어요',
#  '아들방이라 칙칙하지 말라고 하얀색으로 달았더니 넘 예쁘네요ㅎㅎ 핑크도 추가 구매했어요',
#  '배송도 빠르고 생각보다 싼티안나구 이뻐요',
#  '20평대 거실커튼으로 딱이에요ㅎㅎㅎ',
#  '왕 너무 예뻐요  집 분위기가 달라짐',
#  '정말 잘샀다고 생각해요 가격대비 고급스럽고요',
#  '배송도 빠르고 길이 사이즈 다 맞아요  커튼하나로 집 분위기가 이렇게 바뀌네요 ',
#  '커튼이 분위기 있게 예뻐요 ㅜㅜㅠㅝㅜ',
#  '예쁘고 따뜻해서 추가구매해서 아이방에 달아줬네요 포장박스가 너덜너덜 많이 찢어지고 벌어져서 왔지만내품엔 이상없고 배송도 빠르고 대만족합니다',
#  '암막 앤드 레이스 같으거랑 같이 있어서 더 예뻐요',
#  '리뷰가 좋아서 기대했는데 역시 기대한만큼 넘넘 이뻐용 맘에들어용',
#  '넘 예뻐요 암막도 잘 됩니다',
#  '좋아요 예뻐요 라이트는 따로 사서 달았어요',
#  '딸방에 설치했는데 길이도 폭도 색깔까지 너무 예쁘게 매치가 되어요 암막효과도 있어서 스탠드켜고 공부할때 집중력이 잘 된다고하네요',
#  '흰색이라 암막 안될까봐 걱정 했는데 엄청 잘 돼요 방도 환해지고 좋네요',
#  '집이 환해지고 깔끔해졌어요 ㅋㅋ 사길잘했어오',
#  '잘 사용하고 있습니다 길이는 진짜 두배정도 생각하고 구매하세요',
#  '이사한집에 구매해서 달았더니 예쁘네요 깔끔하면서도 따뜻해보여요',
#  '제일 잘산거 진짜 거실만 나가면 공주집 느낌나요',
#  '좋아요 길이가 길어서 수선을 필요할거 같아요',
#  '설치전인데 이중이라서 그런지 무게가 꽤 나가요',
#  '가격도 저렴한데 혹시나 예쁘지 않을까 걱정했는데 넘예쁘요',
#  '빨리오고 예뻐용 많이 파세여',
#  '금액대비 훌륭합니다고급스럽고 예뻐요',
#  '이쁘네요 사길 잘했다난 생각이 듭니다',
#  '아이보리 커튼 원했는데 진짜 기대이상이예요ㅎㅎㅎ 너무너무너무너무 예쁩니다 ㅎㅎㅎ',
#  '오자마자 세탁해서 걸었는데 차분하니 마음에들어요',
#  '이쁘고 설치하기 쉽습니다 샤랄라해서 거실 분위기가 달라졌어요ㅎ',
#  '방에다 설치했더니 엄마가 너무이뿌다하셔서 거실것도 주문했어요 ㅋ 진짜이뿌고 일단 사실 원자재자체는 그렇게 좋은것같아보이진않은데 앞에쉬폰이달려서 가격대비 고급스러워보이구요 커튼이 조금 길이가모자라도 앞에 쉬폰때매 풍성해보여요 대만족 가격디자인 다 합격합격',
#  '예뻐요 완전완전 가성비 갑이에요 조금 무게감은 있어요ㅠㅠ',
#  '수선집에서 길이 줄여서 사용하고 있어요',
#  '안방 분위기랑 찰떡쿵  넘 예뿌네요 👍',
#  '완전 마음에 들어요 집안 분위가 180도로 바뀜ㅋㅋ',
#  '커튼없이 지내다가 주문해서 설치했는데 크기도 색도 너무 마음에 들어요 레이스가 같이 있어서 그런지 더 아늑하고 따뜻한 느낌이에요 볼때마다 사길 잘했다는 생각이들정도로 너무 마음에 들어요',
#  '아직입주전이라 배송만 받아놓구 몇달째 미개봉상태에요ㅎ 기대됩니다',
#  '엄마도 사드렸는데 맘에들어하시네요',
#  '화사하고 이쁘네요 조잡스런 디자인이 아니라 깔끔합니다',
#  '이뻐요ㅎㅎㅎㅎ커텐 달기도 쉬운거같아용',
#  '이중으로 흰면  레이스가 달려있구요 전 흰봉이 아니고 집에 있던 원목봉으로 그냥 했는데도 괜찮습니다 웨딩드레스 차르르르 너무 좋습니다',
#  '배송도 빠르고 거실의 분위기가 달라지는 디자인입니다 넘 맘에들어요',
#  '화사하고 너무느므 예뻐요 무거운 암막커튼 했다가 이거로 바꿨어요 맘도몸도 가벼워 지는듯',
#  '방풍역할도 암막역할도 너무 좋아요 레이스덕에 심심하지않고 이쁘게 잘 사용하고 있습니다',
#  '생각보다 진짜이뻐요 저는 흰색이라서 백프로 암막은안되지만 만족하면서 사용하구있습니댜',
#  '화이트 품절이라 베이지류 삿는데 분위기 정말 예뻐오',
#  '화이트 선택 잘한것 같아욤 깔끔하고 가격대비 만족합니다',
#  '지난번 작은 사이즈 샀는데 완전 만족해서 사이즈 업 해서 구매했는데 만족해요 방풍기능ㆍ디자인ㆍ컬러 ㆍ가격 굿 입니다 1개더 구매예정입니다',
#  '방풍기능도 되면서 색깔 디자인 가격 모두 만족이예요',
#  '커텐 너무 맘에 듭니다 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '하애서 너무 이뻐요 ㄱ깔끔해보이고 공주풍 납니당',
#  '깔끔하고 배송도 빠르고 좋아요 확실히 커튼 설치하니까 찬바람을 막아줘서 집이 따뜻해지는 게 느껴져요',
#  '너무맘에들어요 색도 새하얗고 배송도 빨리왔어요 여자혼자 설치하기는 힘들것같네요 그치만 설치하는 방법자체가 어렵진않았어요 조금 커텐이 길게오기는 했는데 대만족입니다',
#  '길이살짝긴데 그래도 존예탱💕💕 너무이뻐여 ㅠㅠ 샤랄라 안방분위기 바꿨습니댜',
#  '넘넘이뻐여 환해보이구암막도 살짝있어서 분위기있네여',
#  '요아이 달았더니 우풍이 많이 없어지고 봉을 천장에 달수없어 몰딩에 달았어요 기장이 더 길어졌네요 ㅋㅋ 넘 이뻐요',
#  '너무 이쁘고요 두번사세요 ㅠㅠ아일렛형이라 넘 쉬워요',
#  '너무 마음에 들어요 기장도 딱 맞아떨어져서 만족합니다 암박은 뭐',
#  '너무예뻐요 햇빛은 좋은데 겨울이라 추워서 하얀암막으로 구매했어요 낮에는 적당히 밝아서 좋아요 그리고 쉬폰커튼 달려있어서 훨씬 고급지고 인테리어가 확 살아서 맘에들어요',
#  '마음에 들어요 좀 길어서 수선해서 쓰려구요 ㅎㅎ',
#  '요즘 유행하는 쉬폰커튼 사려다가 밖에서 보인다는 말이 있어 화이트 커튼 중 고민하다 구매했어요 도톰해서 요즘처럼 추울 때 한기도 잘 막아주면서 넘 포근해보이네요 공주풍 컨셉 딱 질색이라 혹 그럴까 걱정했는데 전혀 넘 자연스럽게 이쁘네요 여름 빼곤 사계절 애용할듯요 넘 만족합니다',
#  '고민한만큼 가심비가 좋습니다 브라켓 높이조절 가능해서 최대로 늘렸는데도 바닥이 살짝 들뜨는게 전체적인 우아함을 반감시키는게 아쉬울 따름이지만소재도 도톰하고 광택도 있고 무게감있으며웨딩드레스처럼 쨍한 화이트여서 집이 회사해보이지만 암막 기능은 충분히 해주어 역광으로 컴퓨터 쓰는데 넘 유용하게 잘쓰고있습니다 개인적으로 감사하게 쓰고있어요',
#  '저렴한 가격에 잘산거 같아요 우선 핑크색상 그닥 나쁘지않고 암막은 거이90 되는거같아요 딸방에 어울리고 단열도 된다는게 좋네요',
#  '디자인 내구성 모두 만족해요 커튼봉은 약하단 말 있어서 쿠x 에서 사이즈 초대형으로 못없이 달 수 있는 봉으로 썼어요 이전에 차콜 암막 커튼 사용할땐 거의 100프로 암막이 됐는데 이건 흰색이라 날 밝으면 밝아져요 방 암막은 기대하지 마세요 다른건 다 괜찮아요',
#  '예뻐용 ㅎㅎㅎㅎㅎ방분위기가 확살아났어요',
#  '집 거실 싸이즈보단 좀 작긴 하지만 너무 맘에 들어서 그냥 하기로 했어요분위기도 화사해지고 좋아요',
#  '창이 가로로 너무 넓어서 적당한 사이즈 찾다가 결국은 거실 큰 창용으로 주문했는데탁월한 선택이었네요',
#  '예쁘고 길이도 딱 맞아서 좋았어요 배송도 빨랐습니다',
#  '블라인드 달까 하다가 커튼 단 건데 화이트여도 은근 암막 기능해주고 분위기도 살려서 좋아요',
#  '가격대비 너무 맘에 들어 다른 색깔로 또 구매 했어요',
#  '너무이뻐요 다들어디서 구입했냐고 물어보네요ㅎ',
#  '화이트사고 마음에들어서 베이지도 주문했어용 저는 너무 어두운걸 안좋아하는데 베이지가 딱 적당한거 같아요 아침에 찍은 사진인데 빛차단은 충분하고요 예쁩니다 침실용으로 잘쓰고있습니다',
#  '화이트 이중커튼 예뻐요 깔끔하고 저렴해 더 좋습니다 암막커튼은 아닌듯해요',
#  '많이 고민하고 여기저기 알아보다가 리뷰보고 결정했는데 마음에 들고 후회없이 좋아요',
#  '최고예요색상재질 모두맘에 들어요 다른방도 재구매하려구요',
#  '화이트 살라했는데 베이지로ㅠ 잘못주문 했지만 그래도 예뻐용 암막커튼이라서 어두운게 더 좋을거같네요 때도 안탈거같구 밤에 조명켜놓으면 더 은은해서 예쁜거 같아요 여름용은 따로 사야겠어요 ㅎ',
#  '이뻐요 집 분위기 살려주네요 기대 이상입니다',
#  '정말이쁘고천도 좋구요 저희집에는 좀 길긴하지만괜찮습니다 가성비 최고입니다',
#  '거실길이에 딱맞아 좋아요 레이스가 한겹위에 있으니 훨씬 고급쓰러워 보여요 맘에 쏙듭니다',
#  '크림베이지 색 좋습니다 암막도 되고 고급스런분위기도 만들어주고 굿굿',
#  '저희 집엔 쫌 길지만 밝은 색인데 암막도 되고 좋았어요',
#  '레일설치에 애좀 먹었지만 ㅜ ㅜ 커튼은 너무 마음에 들어요 또 구매하러올게요',
#  '너무이쁩니다 분위기완전달라져요 진짜최고',
#  '화이트를 많이 사시던데 제가 감당이 안될듯하여 크림베이지로 샀는데 이것도 넘 분위기있고 좋아요 무게감이 좀 있긴한데 만족합니다',
#  '가격대비 만족합니다 디자인색상넘 이뻐요',
#  '안방거텐이라서 핑크로 했는데 이쁘네요',
#  '너무 이뻐요 가격도 너무 괜찮고 분위기도 미침 커튼에 약간 냄새가 나서 환기시키고 페리즈 뿌리니까 없어졌네용',
#  '좋아요 색상도 맘에 들어요 사이즈도 딱이에요',
#  '좋아요 잘쓰겠습니다',
#  '17평입니다 신혼집에 가볍게 쓰려고 샀는데 베이지는 너무 마음에 드는데 화이트는 너무 새하얗네요 그래도 가격대비 좋습니다 봉도 튼튼해요',
#  '집이 화사해지네요 레이스까지 달려있는데도 과하단 느낌없이 딱 좋습니다 가성비 말할것도 없구요 화이트라 암막이 덜되긴하는데 그래도 나쁘지않아요',
#  '와 진짜 무슨일이래요 너무 예뻐요 방이 은은한 분위기로 바뀌었어요 감사합니다 길이도 딱좋네요 ㅎㅎ',
#  '제일 작은 사이즈를 가로 2미터에 달았는데 딱조아여 바람 막아줘서 넘조아여',
#  '고민많이했는데 생각 보다 맘에들어요 대만족 강추합니다',
#  '색감도 이쁘고 길이도 딱 맞는게 좋아요 ㅎㅎㅎ 너무 예쁘고 분위기 있어요',
#  '속커튼 겉커튼을 묶었을때 느낌이 다르고 암막효과좋고 하얀색이라 집 분위기 자체가 아주 밝아졌어요 진작살걸 고민을 왜했었나 싶어요',
#  '가로 3미터 거실창에 달았습니다 집안공기도 따뜻해진거 같고 분위기도 아늑해져서 만족스럽네요 겉에 레이스 커텐이 하늘하늘 너무 이쁩니다',
#  '친구들이 다들 어디서 샀냐고 물어보내요ㅋㅋ 암막도되고 하늘히늘 하기도하고 예뻐요',
#  '완벽한 암막은 아니라서 아쉽습니다 ㅜㅜ',
#  '가성비 최고에요진짜  제 방이 창이 너무 넓어서 걱정했는데 사이즈 딱 적당하구 길이도 진짜 맞춘 것처럼 딱 맞아요ㅠ 진짜예쁘구 저 혼자 설치하기 너무 힘들 줄 알았는데 완전 뚝딱했어요 진짜 잘 구매한듯합니다',
#  '색상도 원단도 크기도 너무좋와요 죄송합니다 사진을 잘못 올렸어요ㅠㅠ',
#  '잘쓸게여 빨리 잘받아봤어요',
#  '너무 이뻐요 이가격에 너무 맘에들어요',
#  '사진보다 도 예뻐요 ㅠ 이런 커튼 원해서 사게됐어요 만족 100퍼센트❤️',
#  '후기보고 주문 했는데 좋아요 잘 산것 같아서 기분이가 좋습니다',
#  '분위기 좋아요 찬바람도 막아주고요 잘쓰겠습니다',
#  '가격에비해 고급진거 같아요 무지 깔끔해보이고 갠찮 습니다 앞으로 분위기 바꾸고싶을땐 여기서 교체꼭 하고싶어요',
#  '딸이베이지색을샀는데 예쁘더라구요 그래서 전흰색을샀는데정말예뻐요커튼위에레이스까지저말예쁘더군요강추',
#  '빠른 배송 너무 좋네용♡ 예쁘게 잘 쓰겠습니다',
#  '첫눈에 반해 구매한 커튼 이중이고 암막이라서 굉장히 좋아요 너무 암막은 아닌걸 원했는데 딱 좋아요 ㅎㅎ',
#  '배송진짜 빠르네요베이지 화이트 고민하다 화이트했는데 너무예뻐요 ㅠㅠㅠㅠㅠ빛차단 적당히 예쁘게잘되구바람도 잘막아줘요가격도 정말 착하구 다마음에 드는상품이예요아 봉은 너무 긴걸삿나봐요 하나빼구사용해도 조절도 되구 딱 좋습니다',
#  '완벽한 안막은 아니지만 너무 맘에들어요 빛들어와서 더 이쁜 느낌',
#  '베이지색상 구매했어요 너무이뻐요 화이트도구매하려고요 이가격에 이런커튼 못사요 정말 쵭오에요베이지암막도잘되네요♥♥♥♥',
#  '너무 예뻐요 앞에 레이스 쉬폰은 생각보다는 모기장 재질인데 그래도 두고보니 예쁘네요 배송 속도는 보통이었습니다',
#  '넘 예뻐요 ㅎㅎㅎㅎㅎ 고민할 필요가 없음  ',
#  '너무 이뻐용 다른 집에는 길이가 바닥에 딱 인뎅 저희 집 천장이 높아서 좀 짧은 거 같아용',
#  '실측이 3미터여서 넉넉히 530 사이즈 주문하였는데 샤랄라하니 예쁘네요',
#  '거실에 커튼을 연달아 달았는데 집전체가 화사해졌어요 커튼이 좀 많이 무겁지만 괜찮아요',
#  '암막기능은 있가고 하는데 디자인이 열일하는 커텐',
#  '실물이 더 예뻐요 실제로 다니까 더 좋네요ㅠㅠ 거실에 달거라 커튼을 쳐도 어느정도 밝은게 좋아서 화이트로 했는데 잘한것 같아요 집이 화사하고 고급스러워졌어요',
#  '커튼 여기서 무조건사세요 진짜 이뻐요',
#  '아직 안달아봤지만 살짝열어본결과 좋네용',
#  '화이트로 꾸미고 있어서 주문했어요  너무 예뻐요 계속 고민했는데 고민하지말고 얼른 사세요 배송도 엄청 빨라요 어제 결제했는데 오늘 도착했어요 이불도 빨리 바꿔야겠어요  ',
#  '댓글보고 조금 저렴해보이면 어쩌나 했는데 괜찮네요',
#  '배송 빠르게 와서 마음에 들어요  생각보다 엄청 무거움',
#  '너무 예뻐요 색은 약간 창백한 화이트  같아요  가격 대비 짱입니다 ',
#  '거실이 분위기 있어졌어요 화사하니 넘 이쁘고 암막이라 베란다 찬기운도 많이 커버되서 만족스러워요 낮에 해들때 샷도 올려봐요',
#  '아이방에 달아줬는데 화사하니 너무 예쁘네요 동생이랑 엄마집에도 추천했는데 맘에 꼭 드신다네요',
#  '리뷰보구 예쁘단얘기에 내 스퇄이기도하구 구매했는데 아주빨리 배송도해주시구 완죤 드레스같은게 너무 예쁘네요 애들이 일단 너무 좋아하구 두껍기도하구 너무 좋네요 근데 약간 냄새가 나긴하는데 이건 환기시키면 금방 빠질듯해요 이가격에 이정도면 대박인든싶어요 넘 감사합니다 마니파세요']

# %%
# 각 상품별 리뷰만 모아 리턴하는 함수
def gain_reviews_per_product(pname):
    return df[df['pname']==pname]['review'].tolist()

# %%
print(gain_reviews_per_product('애슐리 전신거울 3colors')[:10])
# Out:
# ['아빠가 ㅇ오만원은 줬겠다하셨어요 대만족', '클래식하고 분위기 있네요 재구매 의사 있습니다', '조립도 쉽고 너무 예뻐요 저렴한 가격에 배송도 괜찮았습니다 잘쓰겠습니다 많이 파세용', '이젠 너무 흔해진 거울이지만 그래도 엔틱한느낌이 너무 예쁘고 좋습니다 다만 남자들이 보기에는 거울이 조금 짧다고 그러네요', '친구에게 선물한건데 무척 만족스러워한다조립도 간단하고 여러모로 쓸모가 잇다', '너무예뻐용 근데 이거 받아보시면 알겠지만 끼워져있던 봉이 너무 꽉조여졌어서 온가족이 스패너들고 거울과 싸웠답미당호호 거울 자체는 예뻐욥', '고급스럽고 이뻐서 아주 맘에 듭니다 잘샀어요ㅎ', '거울 너무 이쁘네요 월넛색 빈티지하면서 절대 이가격으러 안보여요 ㅎㅎㅎ 다행히 스크래치 이런것도 없는거로 잘 왔네요 조립은 두명이서하는게 수월할듯', '예뻐요 근데 지지대가 조금 약한느낌 쨋든 전체적으로 예뻐요', '너무 좋아요 급하게 필요해서 그냥 베스트상품 샀는데 괜히 베스트가 아니네요 조립도 완전 쉬워요']

# %% [markdown]
# __정상적으로 상품별 리뷰가 추출된다__

# %% [markdown]
# ### df_rev에 각 상품별 리뷰 list 붙이기

# %%
# 상품명 리스트 따로 빼기
pname_list = df_rev.pname.tolist()
print(len(pname_list), pname_list[:3])
# Out:
# 3650 ['선데이 러그 7size 4colors', '순수원목 선반장 4colors (가로2단)', '오로라 단스탠드(전구 증정 이벤트)']

# %% [markdown]
# ## 각 상품별로 모든 리뷰 리스트에 모으는 쉬운 코드
# `d.groupby('A')['B'].apply(list)`

# %%
# 상품별로 리뷰 모으기
reviews = []
for pname in pname_list:
    reviews.append(gain_reviews_per_product(pname))

# %%
df_rev['review'] = reviews
df_rev.shape
# Out:
# (3650, 3)

# %%
df_rev.head()
# Out:
#                                        pname  count  \
# 0                       선데이 러그 7size 4colors  33619
# 1                    순수원목 선반장 4colors (가로2단)  29225
# 2                        오로라 단스탠드(전구 증정 이벤트)  20335
# 3                           애슐리 전신거울 3colors  14545
# 4  집순이 슬리브 옥스포드 삼각 등쿠션 (솜포함, 2size / 6color)  14491
#
#                                               review
# 0  [너무 좋네요 선배가 와서 양념치킨 먹다가 바로 흘림 상놈, 배송도 엄청 빨리 왔고...
# 1  [여기서 날파리가많이나왔어욥왤까여, 이 가격에 이렇게 예뿌다니 진짜 맘에 들어용 품...
# 2  [실제로 보니까 더 이쁘네용 ㅋㅋ특히 밤에 조명킬때가 넘 예뻐용💓배송도 엄청빨라서 ...
# 3  [ 🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬 이거 사는 사람 많은거 같은데 불량 나는 안오겠...
# 4  [등받이 길죽한베개로사용하다가 너무불편해서 길죽이베개버리고 고민끝에 주문햇어요 리뷰...

# %% [markdown]
# ### 각 상품별 keyword 추출하기

# %%
print(*df_rev.review.iloc[0])
# Out:
# 샤랄라한 분위기 연출해주고 예뻐요 저는 치수를 더 큰것을 사야했는데 잘못맞춰서 아쉽지만요ㅠ 가격대비 이주 잘 산것 같아요 십년만에 남이 준 커튼에서 새로 샀네요 하얀색이 너무 이쁘고 저희 거실 창이 아주 넓은데도 충분히 커버가 되네요 딸들이 너무 이쁘다고 앞에서 틱톡찍어요 가격 생각하면 너무 싸게 잘 샀다고 여겨지네요 넘무 예뻐요 진짜 가성비 짱인 것 같아용 사진이 어두워서그런데 색이쁘고 분홍색ㄷ샀는데 그것도이뻣어요근데 여름이라그런지 좀두꺼워서 아직은 커텐을 쳐놓고 살아욘 ㅎㅎㅎㅎ 완전대만족 남편몰래 서프라이즈해주려고 혼자서 했는데 남편이 넘 좋아해요 어디서 이가격에 커튼을 구입했냐며 너무예쁘다고 하네요 안방이랑 작은방은 작은사이즈로 또 주문하려구여 진짜 백만배강추🥰🥰🥰😍😍😍😍😍 예쁘네요 그런데 대가 좀 약한거 같아요 너무너무너무만족해요진짜 생각한것보다 다 너무예뻐요 ㅠㅠㅠ 이제 안방이랑 작은방 다용도실것도 주문하려구요 완전대만족 추천합니다 이 가격에 이 커튼 못사요 커튼 진짜 특가로 잘샀어요고급지고 집도 넓어보이고 너무 이뻐요 기존에 있던 커튼은 암막이 하나도 안되어서 사봤는데 너무 예쁘고 웨딩드레스처럼 샤랄라한게 대만족이에요 아쉬운건 세로길이가 치수로 재면 딱 맞아야 하는데 아일렛 부분이 높아서 그런지 딸랑하네요 ㅠㅠ 그래도 길어서 머리카락 엉켜붙는것보다는 낫겠거니 하고 그대로 달았어요 진작 살껄 ㅠㅠㅠ 넘 예뻐요 ㅠㅠㅠ 샤랄라 이중레이스 안방 침실용으로 달았습니다 이쁘네요 화사하고 기존 암막커튼은 한 낮에도 쳐놓으면 밤인지 낮인지 몰라서 낮잠자기 좋은 요요 커튼은 암막의 효과보단 인테리어용 으로 좋아요 밝고 화사한 샤랄라느낌으로 분위기 바꿔봤어요 침구랑 잘 어울립니다 이사오면서 주문한건데 사이즈 완전 찰떡 넘나 이뻐요 배송이 빠르긴했는데 상자는 여기저기 뜯어져서 왔더라구요 그래도 빠진것없이 다 잘왔어요 커튼은 예쁘구 설치도 어렵지 않았는데 봉이 엄청 내구성 있어보이진않네요 스팀다림질 한번 해주면 더 예쁠것같아요 사진은 약간 베이지빛나는 흰색인줄 알았는데 회색기가 도는 흰색이네여 그리고 사진 보기보다 하늘하늘한 느낌이 없어요ㅠㅠㅠㅠ 예뻐요 흰색이라 암막이 많이 되는건 아니지만 그래도 적당히 됩니다 ㅎㅎ  배송도 빨랐어요  솔직하게 사진보단 덜했어요 주문하려고 했는데 품절이라서 조금 기다렸는데 입고되자마자 바로 배송해주시긴 해서 좋았어요 가격대비 괜찮아요 조금 더 준만큼 값어치 있게 좋네요 ㅎ 이가격에 이렇게 고급스러운 커튼이 있다는게 너무 놀라워요ㅠㅠ 달고나서 집 분위기가 완전 바껴서 너무 감동이에요 넉넉하게 하려고 530으로 샀는데 하나로도 충분해서 하나는 다른 문에 달려고 합니다 너무 조아여 타블렛 아래쪽 제봉선 박음질 일부 부분이 터져있는데 교환하기 귀찮아서 그냥 사용합니다 암막효과는 좋네요 화이트엄청깔끔해요 안방에 설치했는데넘넘예쁘네요 너무 이뽀요 너무 하옇고 이뽀서 때탈까 조금 조심스럽긴 하지만 잘 쓰겠습니다 며칠을 한참 기다렸어요 사이즈때문에 ㅜㅜ 근데 보람있어요 생각했던 그대로고 너무 이뻐요ㅠㅠ 너무이뻐요 근데 연결하는게 좀 약해서 끼우다가 몇번 빠졌어요 그거빼고는 만족합니다 하얗고 샤랄라하고 너무 예쁘네요ㅎㅎㅎ 배송도 빠르고 가격도 저렴하고 달아보니 너무 예쁘기도 한데요 레이스 부분 박음질 불량이 좀 있어요 실이 잡아당겨지며 우글우글해진부분이 많아서 다른부분은 제가 살살 당기며 폈는데 천이 연결되는 부분은 오버록되어있는 부분이라 잡아당겨 펼수가 없네요 ㅠ 이미 커튼 설치한 다음에 발견해서 교환하기도 그렇고 또 주름이 있어서 자세히 안보면 크게 티가 안나서 그냥 쓰려구요 그래도 전반적으로 만족합니다 집이 화사해졌어요 가격도 착하고 디자인도 너무 예뻐요 암막커튼 질감도 너무 맘에 듭니다 커튼박스부터 달아서 그런지 커튼 아래가 약간 짧은데 그래도 괜찮아요 너무 예뻐요 안방에는 포근한느낌으로 베이지색상했는데 예뻐요  인디핑크랑 베이비핑크랑 고민했는데  베이비핑크도 괜찮네용 더 방이 화사해보여서요  ㅎㅎ 너무 튼튼하고 예뻐요 저렴하게 주문잘했어용 너무 튼튼하고 예뻐요 저렴하게 주문잘했어용 넘 예뻐요 흰색이라 때가 탈까 조심스럽지만 예뻐서 감안하고 사용하려구요 암막이 100프로 되진 않지만 살짝 비치는 정도인데 이정도면 만족해요 배송도 빠르게왔고 커튼 진짜 부드러워요 마감처리도 좋아요 조금 무거운데 레이스까지̆̎ 달린거 치면 정말 좋아요 동생이 구입한 커텐이랑 사이즈만 다르게 주문했습니당 워낙 예쁘고 적당한 암막이라 좋아서 저도 샀어요 동생은 같은 창문 사이즈에 더 큰 사이즈를 샀지만 저는 264사이즈로도 주름이 충분해서 샀습니다 실사이즈 두배정도면 충분하게 예쁜 주름인것 같아요 완전 어두운 암막 원하시는 분보다 어느정도 햇빛을 막아주고 여리한 느낌 원하는 분들한테는 완전 추천입니닫 그리고 조립 너무 쉬워요 예뻐요 암막도 잘되고 레이스 있어서 더 예쁨것 같네요 너무예뻐요 큰방 커튼도 여기서 샀는데 레이스짱예쁘고 거실커튼도 사이즈나 디자인이나 만족입니다 흰색이라 완벽암막은 아니지만 거실이라 느낌이 딱 좋아요 4시쯤 찍은 사진입니다 암막이 효과가 크네요 생각보다 좋아요 ㅎㅎ 멋스럽네요정리하느라 이제서안 달았어요 불키면 더 이쁜데 암막 어느정도 되는지 궁금하실 분들이 계실것같아서 흰색 너무 좋아요샤랄라하구 진짜 이뻐요 위에 고리형식이 아니라서 안이쁠까봐 걱정햇는데 샤방해가지구 눈도 잘 안가구 진짜 마음에 드는데 키가 딸려서 압축봉으로 역도함 아일렛인데 쉬폰 느낌 찾기가 힘들었어요 암막 뒤에 이쁘게 두겹으로 되어있어서 너무 예뻐요 이중커튼이 너무 하고싶은데 커튼 레일이 아니라 고민하던중 찾은거예요 생각보다 더 예쁘고 흰색이지만 암막도 잘되요 살짝 길어서 밑에가 끌리지만 그것마저도 이뻐요 ㅎㅎ 배송도 빠르고 설치도 쉬워요 결정적으로 너무 예쁩니다 쉬폰커튼을 사고싶었는데 쉬폰커튼은 암막이 너무 안될거같아서 찾아보다가 이 커튼을 보게되었는데 쉬폰커튼이랑 암막커튼 두개를 같이 달고싶었던 저에게 딱 안성맞춤인 커튼이였어요 그래서 품절이 풀리길 기다렸다가 샀는데 사이즈를 잘못알고 원래 시켜야되는 사이즈의 2배나 큰걸 시켰지만 그렇게 커보이지않고 예뻐서 다행이에요 화이트 완전 강추입니당 방 분위기가 엄청 밝아보이고 인스타갬성이 아주 뿜뿜해여 너무 예뻐요 다들 사세요 샤랄랄라해서 이뻐요 배송도 진짜 빠르구여 화이트라 그런지 완전히 빛을 차단해주지는 못하지만 이쁘니까 추천합니다 너무 하애서 걱정했는데 분위기 살고 좋아요 남편이 하얀색 싫다고 설치 전까지 입길이가 일메다 나왔었는데 설치하고 사진 보내주니 잡지에 나오는 집같다며 퇴근하고 와서는 발렌타인 한 잔 했어요 커튼봉 자체가 견고하진 않지만 커튼봉을 양쪽 균형맞춰 브라켓에 끼운 후에는 커튼달기로서 문제 없이 튼튼함 사진처럼 반나절 묶고 있다가 밤에 풀어 펼쳤는데 이렇게 해도 저렇게 해도 예쁨 커튼이 무게감이 있어 고급스러워 보임 포쉐린 타일 공사로 지면 높이가 높아져 커튼이 끌리는 건 세탁 시 수선집에 맡겨야겄음 커튼 하단에 신발에 밟힌 자국이 있어서 아쉽네요 검수나 포장때 신경써주시면 좋겠어요 암막 생각하고 사면 안됩니다 커튼이 없다면 눈부셔서 깨겠지만 커튼이 있어도 밝아서 깨요 디자인은 예쁘고 낮에 굳이 안걷어도 된다는 장점이 있네요 커튼봉 진짜 별로요 여기서 말고 다른곳에서 사세요 튼튼하긴 한데 천장에서 너무 떨어지게 걸 수밖에 없어서 지저분해보여요 크으 너무 예뻐서 만족스러워요ㅠㅠㅠ 방 분위기가 달라졌어요 깔끔하고 무난합니다 순백색이라 웨딩드레스분위기 음 이중인것도알고 암막인것도 알았는데 망사인줄은 또 신경을 못쓰고 붙어있다는것도 몰랐고ㅎㅎ 무조건 이쁘고 가격이 착해서 샀는데 하늘하늘 느낌이 없다는게 아쉬워요 그래서 나비커튼을 베란다에 해야하나봐요ㅎㅎ 530두개인데 작긴작아요 거실이 4000이 넘어서요 그것도 뭐 감수해야죠 그래도 웨딩드레스느낌은 진짜 나네요ㅎㅎ 가격대비 완전 만족입니다 뻣뻣하지 않고 부드럽고 구김도 잘 안가요 너무 맘에 들어요 암막커튼인데 레이스 달려있어서 신혼방 침실에 딱이네요 빛차단은 100프로는 안되지만 화이트라 감안하고 샀습니다 그렇다고 불편할 정도는 아니고 80프로 이상 되는것 같아요 배송도 빠르고 가성비 좋습니다 하얀색을 할까하다 베이지로 했는데 휠  ...

# %% [raw]
# @@@ okt 활용

# %%
# 0번상품 리뷰에 대한 morphs, nouns, phrases
okt.morphs(df_rev.review.iloc[0][1]) # 해당 n번째 제품의 리뷰 개수만큼 돌려야하는듯...그럼 굳이 review들을 reviews로 합친의의가...ㅠ
# Out:
# ['십년',
#  '만에',
#  '남',
#  '이',
#  '준',
#  '커튼',
#  '에서',
#  '새로',
#  '샀네요',
#  '하얀색',
#  '이',
#  '너무',
#  '이쁘고',
#  '저희',
#  '거실',
#  '창',
#  '이',
#  '아주',
#  '넓은데도',
#  '충분히',
#  '커버',
#  '가',
#  '되네요',
#  '딸',
#  '들',
#  '이',
#  '너무',
#  '이쁘다고',
#  '앞',
#  '에서',
#  '틱톡',
#  '찍어요',
#  '가격',
#  '생각',
#  '하면',
#  '너무',
#  '싸게',
#  '잘',
#  '샀다고',
#  '여겨지네요']

# %%
r01 = ""
for r in df_rev.review.iloc[0]:
    r01 += r+' '
r01
# Out:
# '샤랄라한 분위기 연출해주고 예뻐요 저는 치수를 더 큰것을 사야했는데 잘못맞춰서 아쉽지만요ㅠ 가격대비 이주 잘 산것 같아요 십년만에 남이 준 커튼에서 새로 샀네요 하얀색이 너무 이쁘고 저희 거실 창이 아주 넓은데도 충분히 커버가 되네요 딸들이 너무 이쁘다고 앞에서 틱톡찍어요 가격 생각하면 너무 싸게 잘 샀다고 여겨지네요 넘무 예뻐요 진짜 가성비 짱인 것 같아용 사진이 어두워서그런데 색이쁘고 분홍색ㄷ샀는데 그것도이뻣어요근데 여름이라그런지 좀두꺼워서 아직은 커텐을 쳐놓고 살아욘 ㅎㅎㅎㅎ 완전대만족 남편몰래 서프라이즈해주려고 혼자서 했는데 남편이 넘 좋아해요 어디서 이가격에 커튼을 구입했냐며 너무예쁘다고 하네요 안방이랑 작은방은 작은사이즈로 또 주문하려구여 진짜 백만배강추🥰🥰🥰😍😍😍😍😍 예쁘네요 그런데 대가 좀 약한거 같아요 너무너무너무만족해요진짜 생각한것보다 다 너무예뻐요 ㅠㅠㅠ 이제 안방이랑 작은방 다용도실것도 주문하려구요 완전대만족 추천합니다 이 가격에 이 커튼 못사요 커튼 진짜 특가로 잘샀어요고급지고 집도 넓어보이고 너무 이뻐요 기존에 있던 커튼은 암막이 하나도 안되어서 사봤는데 너무 예쁘고 웨딩드레스처럼 샤랄라한게 대만족이에요 아쉬운건 세로길이가 치수로 재면 딱 맞아야 하는데 아일렛 부분이 높아서 그런지 딸랑하네요 ㅠㅠ 그래도 길어서 머리카락 엉켜붙는것보다는 낫겠거니 하고 그대로 달았어요 진작 살껄 ㅠㅠㅠ 넘 예뻐요 ㅠㅠㅠ 샤랄라 이중레이스 안방 침실용으로 달았습니다 이쁘네요 화사하고 기존 암막커튼은 한 낮에도 쳐놓으면 밤인지 낮인지 몰라서 낮잠자기 좋은 요요 커튼은 암막의 효과보단 인테리어용 으로 좋아요 밝고 화사한 샤랄라느낌으로 분위기 바꿔봤어요 침구랑 잘 어울립니다 이사오면서 주문한건데 사이즈 완전 찰떡 넘나 이뻐요 배송이 빠르긴했는데 상자는 여기저기 뜯어져서 왔더라구요 그래도 빠진것없이 다 잘왔어요 커튼은 예쁘구 설치도 어렵지 않았는데 봉이 엄청 내구성 있어보이진않네요 스팀다림질 한번 해주면 더 예쁠것같아요 사진은 약간 베이지빛나는 흰색인줄 알았는데 회색기가 도는 흰색이네여 그리고 사진 보기보다 하늘하늘한 느낌이 없어요ㅠㅠㅠㅠ 예뻐요 흰색이라 암막이 많이 되는건 아니지만 그래도 적당히 됩니다 ㅎㅎ  배송도 빨랐어요  솔직하게 사진보단 덜했어요 주문하려고 했는데 품절이라서 조금 기다렸는데 입고되자마자 바로 배송해주시긴 해서 좋았어요 가격대비 괜찮아요 조금 더 준만큼 값어치 있게 좋네요 ㅎ 이가격에 이렇게 고급스러운 커튼이 있다는게 너무 놀라워요ㅠㅠ 달고나서 집 분위기가 완전 바껴서 너무 감동이에요 넉넉하게 하려고 530으로 샀는데 하나로도 충분해서 하나는 다른 문에 달려고 합니다 너무 조아여 타블렛 아래쪽 제봉선 박음질 일부 부분이 터져있는데 교환하기 귀찮아서 그냥 사용합니다 암막효과는 좋네요 화이트엄청깔끔해요 안방에 설치했는데넘넘예쁘네요 너무 이뽀요 너무 하옇고 이뽀서 때탈까 조금 조심스럽긴 하지만 잘 쓰겠습니다 며칠을 한참 기다렸어요 사이즈때문에 ㅜㅜ 근데 보람있어요 생각했던 그대로고 너무 이뻐요ㅠㅠ 너무이뻐요 근데 연결하는게 좀 약해서 끼우다가 몇번 빠졌어요 그거빼고는 만족합니다 하얗고 샤랄라하고 너무 예쁘네요ㅎㅎㅎ 배송도 빠르고 가격도 저렴하고 달아보니 너무 예쁘기도 한데요 레이스 부분 박음질 불량이 좀 있어요 실이 잡아당겨지며 우글우글해진부분이 많아서 다른부분은 제가 살살 당기며 폈는데 천이 연결되는 부분은 오버록되어있는 부분이라 잡아당겨 펼수가 없네요 ㅠ 이미 커튼 설치한 다음에 발견해서 교환하기도 그렇고 또 주름이 있어서 자세히 안보면 크게 티가 안나서 그냥 쓰려구요 그래도 전반적으로 만족합니다 집이 화사해졌어요 가격도 착하고 디자인도 너무 예뻐요 암막커튼 질감도 너무 맘에 듭니다 커튼박스부터 달아서 그런지 커튼 아래가 약간 짧은데 그래도 괜찮아요 너무 예뻐요 안방에는 포근한느낌으로 베이지색상했는데 예뻐요  인디핑크랑 베이비핑크랑 고민했는데  베이비핑크도 괜찮네용 더 방이 화사해보여서요  ㅎㅎ 너무 튼튼하고 예뻐요 저렴하게 주문잘했어용 너무 튼튼하고 예뻐요 저렴하게 주문잘했어용 넘 예뻐요 흰색이라 때가 탈까 조심스럽지만 예뻐서 감안하고 사용하려구요 암막이 100프로 되진 않지만 살짝 비치는 정도인데 이정도면 만족해요 배송도 빠르게왔고 커튼 진짜 부드러워요 마감처리도 좋아요 조금 무거운데 레이스까지̆̎ 달린거 치면 정말 좋아요 동생이 구입한 커텐이랑 사이즈만 다르게 주문했습니당 워낙 예쁘고 적당한 암막이라 좋아서 저도 샀어요 동생은 같은 창문 사이즈에 더 큰 사이즈를 샀지만 저는 264사이즈로도 주름이 충분해서 샀습니다 실사이즈 두배정도면 충분하게 예쁜 주름인것 같아요 완전 어두운 암막 원하시는 분보다 어느정도 햇빛을 막아주고 여리한 느낌 원하는 분들한테는 완전 추천입니닫 그리고 조립 너무 쉬워요 예뻐요 암막도 잘되고 레이스 있어서 더 예쁨것 같네요 너무예뻐요 큰방 커튼도 여기서 샀는데 레이스짱예쁘고 거실커튼도 사이즈나 디자인이나 만족입니다 흰색이라 완벽암막은 아니지만 거실이라 느낌이 딱 좋아요 4시쯤 찍은 사진입니다 암막이 효과가 크네요 생각보다 좋아요 ㅎㅎ 멋스럽네요정리하느라 이제서안 달았어요 불키면 더 이쁜데 암막 어느정도 되는지 궁금하실 분들이 계실것같아서 흰색 너무 좋아요샤랄라하구 진짜 이뻐요 위에 고리형식이 아니라서 안이쁠까봐 걱정햇는데 샤방해가지구 눈도 잘 안가구 진짜 마음에 드는데 키가 딸려서 압축봉으로 역도함 아일렛인데 쉬폰 느낌 찾기가 힘들었어요 암막 뒤에 이쁘게 두겹으로 되어있어서 너무 예뻐요 이중커튼이 너무 하고싶은데 커튼 레일이 아니라 고민하던중 찾은거예요 생각보다 더 예쁘고 흰색이지만 암막도 잘되요 살짝 길어서 밑에가 끌리지만 그것마저도 이뻐요 ㅎㅎ 배송도 빠르고 설치도 쉬워요 결정적으로 너무 예쁩니다 쉬폰커튼을 사고싶었는데 쉬폰커튼은 암막이 너무 안될거같아서 찾아보다가 이 커튼을 보게되었는데 쉬폰커튼이랑 암막커튼 두개를 같이 달고싶었던 저에게 딱 안성맞춤인 커튼이였어요 그래서 품절이 풀리길 기다렸다가 샀는데 사이즈를 잘못알고 원래 시켜야되는 사이즈의 2배나 큰걸 시켰지만 그렇게 커보이지않고 예뻐서 다행이에요 화이트 완전 강추입니당 방 분위기가 엄청 밝아보이고 인스타갬성이 아주 뿜뿜해여 너무 예뻐요 다들 사세요 샤랄랄라해서 이뻐요 배송도 진짜 빠르구여 화이트라 그런지 완전히 빛을 차단해주지는 못하지만 이쁘니까 추천합니다 너무 하애서 걱정했는데 분위기 살고 좋아요 남편이 하얀색 싫다고 설치 전까지 입길이가 일메다 나왔었는데 설치하고 사진 보내주니 잡지에 나오는 집같다며 퇴근하고 와서는 발렌타인 한 잔 했어요 커튼봉 자체가 견고하진 않지만 커튼봉을 양쪽 균형맞춰 브라켓에 끼운 후에는 커튼달기로서 문제 없이 튼튼함 사진처럼 반나절 묶고 있다가 밤에 풀어 펼쳤는데 이렇게 해도 저렇게 해도 예쁨 커튼이 무게감이 있어 고급스러워 보임 포쉐린 타일 공사로 지면 높이가 높아져 커튼이 끌리는 건 세탁 시 수선집에 맡겨야겄음 커튼 하단에 신발에 밟힌 자국이 있어서 아쉽네요 검수나 포장때 신경써주시면 좋겠어요 암막 생각하고 사면 안됩니다 커튼이 없다면 눈부셔서 깨겠지만 커튼이 있어도 밝아서 깨요 디자인은 예쁘고 낮에 굳이 안걷어도 된다는 장점이 있네요 커튼봉 진짜 별로요 여기서 말고 다른곳에서 사세요 튼튼하긴 한데 천장에서 너무 떨어지게 걸 수밖에 없어서 지저분해보여요 크으 너무 예뻐서 만족스러워요ㅠㅠㅠ 방 분위기가 달라졌어요 깔끔하고 무난합니다 순백색이라 웨딩드레스분위기 음 이중인것도알고 암막인것도 알았는데 망사인줄은 또 신경을 못쓰고 붙어있다는것도 몰랐고ㅎㅎ 무조건 이쁘고 가격이 착해서 샀는데 하늘하늘 느낌이 없다는게 아쉬워요 그래서 나비커튼을 베란다에 해야하나봐요ㅎㅎ 530두개인데 작긴작아요 거실이 4000이 넘어서요 그것도 뭐 감수해야죠 그래도 웨딩드레스느낌은 진짜 나네요ㅎㅎ 가격대비 완전 만족입니다 뻣뻣하지 않고 부드럽고 구김도 잘 안가요 너무 맘에 들어요 암막커튼인데 레이스 달려있어서 신혼방 침실에 딱이네요 빛차단은 100프로는 안되지만 화이트라 감안하고 샀습니다 그렇다고 불편할 정도는 아니고 80프로 이상 되는것 같아요 배송도 빠르고 가성비 좋습니다 하얀색을 할까하다 베이지로 했는데 휠 ...

# %%
print(okt.morphs(r01))
print()
print(okt.nouns(r01))
print()
print(okt.phrases(r01))
# Out:
# ['샤랄라', '한', '분위기', '연출', '해주고', '예뻐요', '저', '는', '치수', '를', '더', '큰것을', '사야', '했는데', '잘', '못', '맞춰서', '아쉽지만', '요', 'ㅠ', '가격', '대비', '이주', '잘', '산것', '같아요', '십년', '만에', '남', '이', '준', '커튼', '에서', '새로', '샀네요', '하얀색', '이', '너무', '이쁘고', '저희', '거실', '창', '이', '아주', '넓은데도', '충분히', '커버', '가', '되네요', '딸', '들', '이', '너무', '이쁘다고', '앞', '에서', '틱톡', '찍어요', '가격', '생각', '하면', '너무', '싸게', '잘', '샀다고', '여겨지네요', '넘', '무', '예뻐요', '진짜', '가성', '비', '짱', '인', '것', '같아용', '사진', '이', '어두워서', '그런데', '색', '이쁘고', '분홍색', 'ㄷ', '샀는데', '그것', '도', '이', '뻣', '어', '요', '근데', '여름', '이라', '그런지', '좀', '두꺼워서', '아직', '은', '커텐', '을', '쳐놓고', '살아욘', 'ㅎㅎㅎㅎ', '완전', '대', '만족', '남편', '몰래', '서프라이즈', '해주려고', '혼자', '서', '했는데', '남편', '이', '넘', '좋아해요', '어디서', '이', '가격', '에', '커튼', '을', '구입', '했냐', '며', '너무', '예쁘다고', '하네요', '안방', '이랑', '작은방', '은', '작은', '사이즈', '로', '또', '주문', '하려구여', '진짜', '백만배', '강추', '🥰🥰🥰😍😍😍😍😍', '예쁘네요', '그런데', '대가', '좀', '약한거', '같아요', '너무', '너무', '너무', '만족해요', '진짜', '생각', '한', '것', '보다', '다', '너무', '예뻐요', 'ㅠㅠㅠ', '이제', '안방', '이랑', '작은방', '다용도실', '것', '도', '주문', '하려구요', '완전', '대', '만족', '추천', '합니다', '이', '가격', '에', '이', '커튼', '못', '사요', '커튼', '진짜', '특가', '로', '잘', '샀어요', '고급', '지고', '집도', '넓어', '보이', '고', '너무', '이뻐요', '기존', '에', '있던', '커튼', '은', '암', '막', '이', '하나', '도', '안되어서', '사봤는데', '너무', '예쁘고', '웨딩드레스', '처럼', '샤랄라', '한', '게', '대', '만족', '이에요', '아쉬운건', '세로', '길이', '가', '치수', '로', '재면', '딱', '맞아야', '하는데', '아일렛', '부분', '이', '높아서', '그런지', '딸', '랑', '하네요', 'ㅠㅠ', '그래도', '길어서', '머리카락', '엉', '켜', '붙는것보다는', '낫겠거니', '하고', '그대로', '달았어요', '진작', '살껄', 'ㅠㅠㅠ', '넘', '예뻐요', 'ㅠㅠㅠ', '샤랄라', '이중', '레이스', '안방', '침실', '용', '으로', '달았습니다', '이쁘네요', '화사하고', '기존', '암', '막', '커튼', '은', '한', '낮', '에도', '쳐놓으면', '밤', '인지', '낮', '인지', '몰라서', '낮잠', '자기', '좋은', '요요', '커튼', '은', '암', '막', '의', '효과', '보단', '인테리어', '용', '으로', '좋아요', '밝고', '화사한', '샤랄라', '느낌', '으로', '분위기', '바꿔', '봤어요', '침구', '랑', '잘', '어울립니다', '이', '사오', '면서', '주', '문', '한', '건데', '사이즈', '완전', '찰떡', '넘나', '이뻐요', '배송', '이', '빠르긴', '했는데', '상자', '는', '여기저기', '뜯어져서', '왔더라구요', '그래도', '빠진것', '없이', '다', '잘', '왔어요', '커튼', '은', '예쁘구', '설치', '도', '어렵지', '않았는데', '봉', '이', '엄청', '내', '구성', '있어', '보이진', '않네요', '스팀', '다림질', '한번', '해주면', '더', '예쁠것', '같아요', '사진', '은', '약간', '베이지', '빛나는', '흰색', '인', '줄', '알았는데', '회색', '기', '가', '도', '는', '흰색', '이네', '여', '그리고', '사진', '보기', '보다', '하늘하늘한', '느낌', '이', '없어요', 'ㅠㅠㅠㅠ', '예뻐요', '흰색', '이라', '암', '막', '이', '많이', '되는건', '아니지만', '그래도', '적당히', '됩니다', 'ㅎㅎ', '배송', '도', '빨랐어요', '솔직하게', '사진', '보단', '덜했어요', '주문', '하려고', '했는데', '품절', '이라서', '조금', '기다렸는데', '입고되', '자마자', '바로', '배송', '해주시긴', '해서', '좋았어요', '가격', '대비', '괜찮아요', '조금', '더', '준', '만큼', '값어치', '있게', '좋네요', 'ㅎ', '이', '가격', '에', '이렇게', '고급스러운', '커튼', '이', '있다는게', '너무', '놀라워요', 'ㅠㅠ', '달고나', '서', '집', '분위기', '가', '완전', '바', '껴서', '너무', '감동', '이에요', '넉넉하게', '하려고', '530', '으로', '샀는데', '하나로', '도', '충분해서', '하나', '는', '다른', '문', '에', '달려고', '합니다', '너무', '조아여', '타블렛', '아래쪽', '제', '봉선', '박음질', '일부', '부분', '이', '터져있는데', '교환', '하기', '귀찮아서', '그냥', '사용', '합니다', '암', '막', '효과', '는', '좋네요', '화이트', '엄청', '깔끔해요', '안방', '에', '설치', '했는', '데넘', '넘', '예쁘네요', '너무', '이뽀', '요', '너무', '하옇', '고', '이뽀', '서', '때', '탈까', '조금', '조심스럽긴', '하지만', '잘', '쓰겠습니다', '며칠', '을', '한참', '기다렸어요', '사이', '즈', '때문', '에', 'ㅜㅜ', '근데', '보람', '있어요', '생각', '했던', '그대', '로고', '너무', '이뻐요', 'ㅠㅠ', '너무', '이뻐요', '근데', '연결하는게', '좀', '약해서', '끼우다가', '몇번', '빠졌어요', '그거', '빼고는', '만족합니다', '하얗고', '샤랄라', '하고', '너무', '예쁘네요', 'ㅎㅎㅎ', '배송', '도', '빠르고', '가격', '도', '저렴하고', '달', '아보', '니', '너무', '예쁘', '기도', '한데요', '레이스', '부분', '박음질', '불량', '이', '좀', '있어요', '실', '이', '잡아당겨지며', '우글우글', '해진', '부분', '이', '많아서', '다른', '부분', '은', '제', '가', '살살', '당기며', '폈는데', '천이', '연결', '되는', '부분', '은', '오버', '록', '되어있는', '부분', '이라', '잡아당겨', '펼수가', '없네요', 'ㅠ', '이미', '커튼', '설치', '한', '다음', '에', '발견', '해서', '교환', '하기도', '그렇고', '또', '주름', '이', '있어서', '자세히', '안보', '면', '크게', '티', '가', '안나', '서', '그냥', '쓰려구요', '그래도', '전반', '적', '으로', '만족합니다', '집', '이', '화사해졌어요', '가격', '도', '착하고', '디자인', '도', '너무', '예뻐요', '암', '막', '커튼', '질감', '도', '너무', '맘', '에', '듭니', '다',  ...
#
# ['분위기', '연출', '저', '치수', '더', '요', '가격', '대비', '이주', '십년', '남', '준', '커튼', '하얀색', '저희', '거실', '창', '아주', '커버', '딸', '앞', '틱톡', '가격', '생각', '무', '진짜', '가성', '비', '짱', '것', '사진', '색', '분홍색', '그것', '뻣', '여름', '좀', '은', '커텐', '살아욘', '완전', '만족', '남편', '몰래', '서프라이즈', '혼자', '남편', '가격', '커튼', '구입', '며', '안방', '작은방', '사이즈', '또', '주문', '진짜', '백만배', '강추', '대가', '좀', '진짜', '생각', '것', '이제', '안방', '작은방', '다용도실', '것', '주문', '완전', '만족', '추천', '이', '가격', '이', '커튼', '커튼', '진짜', '특가', '고급', '지고', '집도', '보이', '기존', '커튼', '막', '하나', '웨딩드레스', '게', '만족', '세로', '길이', '치수', '아일렛', '부분', '딸', '머리카락', '켜', '그대로', '진작', '살껄', '이중', '레이스', '안방', '침실', '용', '기존', '막', '커튼', '낮', '밤', '낮', '낮잠', '자기', '요요', '커튼', '막', '효과', '인테리어', '용', '느낌', '분위기', '침구', '면서', '건데', '사이즈', '완전', '찰떡', '배송', '상자', '여기저기', '커튼', '설치', '봉', '구성', '스팀', '다림질', '한번', '더', '사진', '약간', '베이지', '흰색', '줄', '회색', '기', '도', '흰색', '여', '사진', '보기', '느낌', '흰색', '막', '배송', '사진', '주문', '품절', '조금', '자마자', '바로', '배송', '가격', '대비', '조금', '더', '준', '값어치', '가격', '커튼', '달고나', '집', '분위기', '완전', '바', '감동', '하나로', '하나', '다른', '문', '타블렛', '아래쪽', '봉선', '박음질', '일부', '부분', '교환', '그냥', '사용', '막', '효과', '화이트', '안방', '설치', '데넘', '이뽀', '하옇', '이뽀', '때', '조금', '며칠', '한참', '때문', '보람', '생각', '그대', '좀', '몇번', '그거', '배송', '가격', '달', '아보', '기도', '레이스', '부분', '박음질', '불량', '좀', '실', '해진', '부분', '부분', '제', '살살', '천이', '연결', '부분', '오버', '록', '부분', '커튼', '설치', '다음', '발견', '교환', '또', '주름', '안보', '크게', '티', '안나', '그냥', '전반', '집', '가격', '디자인', '막', '커튼', '질감', '맘', '듭니', '커튼', '박스', '커튼', '아래', '약간', '안방', '느낌', '베이지색', '핑크', '베이비', '핑크', '고민', '베이비', '핑크', '용', '더', '방이', '주문', '주문', '흰색', '때', '감안', '사용', '막', '프로', '살짝', '정도', '정도', '배송', '커튼', '진짜', '마감', '처리', '조금', '레이스', '치면', '정말', '동생', '구입', '커텐', '사이즈', '주문', '습', '워낙', '막', '저', '동생', '창문', '사이즈', '더', '사이즈', '저', '로', '주름', '실사', '이즈', '배정', '도면', '주름', '것', '완전', '어', '두운', '막', '분', '정도', '햇빛', '느낌', '분', '완전', '추천', '조립', '막도', '레이스', '더', '방', '커튼', '여기', '레이스', '거실', '커튼', '사이즈', '디자인', '만족', '흰색', '완벽', '막', '거실', '느낌', '사진', '막', '효과', '생각', '멋', '정리', '서안', '불키', '더', '막', '정도', '분', '흰색', '진짜', '위', '고리', '식이', '걱정', '햇', '샤', '방해', '지구', '눈', '진짜', '마음', '키', '압축', '봉', '역도', '함', '아일렛', '쉬폰', '느낌', '찾기', '막', '뒤', '겹', '이중', '커튼', '커튼', '레일', '고민', '중', '생각', '더', '흰색', '막도', '살짝', '밑', '그것', '배송', '설치', '결정', '쉬폰', '커튼', '쉬폰', '커튼', '막', '이', '커튼', '쉬폰', '커튼', '막', '커튼', '개', '저', '안성맞춤', '커튼', '품절', '사이즈', '원래', '사이즈', '배', '걸', '보이지', '다행', '화이트', '완전', '강추', '방', '분위기', '보이', '인스타', '성', '아주', '뿜뿜해', '샤', '배송', '진짜', '화이트', '빛', '차단', '추천', '걱정', '분위기', '살', '남편', '하얀색', '설치', '전', '메', '설치', '사진', '잡지', '집', '퇴근', '발렌타인', '잔', '커튼', '봉', '자체', '커튼', '봉', '양쪽', '균형', '브라켓', '후', '커튼', '문제', '사진', '반나절', '밤', '해도', '해도', '커튼', '무게', '감', '보임', '포쉐린', '타일', '공사', '지면', '높이', '커튼', '건', '세탁', '시', '선집', '겄음', '커튼', '하단', '신발', '밟힌', '자국', '검수', '포장', '때', '신경', '막', '생각', '사면', '커튼', '커튼', '깨', '디자인', '낮', '굳이', '장점', '커튼', '봉', '진짜', '별로', '여기', '곳', '천장', '걸', '수', '방', '분위기', '무난', '순백색', '웨딩드레스', '분위기', '음', '중인', '것', '알', '막', '것', '망사', '줄', '또', '신경', '무조건', '가격', '느낌', '나비', '커튼', '베란다', '개', '거실', '이', '그것', '뭐', '감수', '웨딩드레스', '느낌', '진짜', '가격', '대비', '완전', '만족', '구김', '맘', '막', '커튼', '레이스', '혼방', '침실', '빛', '차단', '프로', '화이트', '감안', '정도', '프로', '이상', '배송', '가성', '비', '하얀색', '베이지', '휠', '집', '가구', '산', '것', '빛', '차단', '구매', '배송', '색상', '질감', '진짜', '스탈', '촤르르르르', '강추', '레이스', '분리', '계속', '막', '판단', '미스', '온', '나사', '한번', '집', '공구', '다시', '작업', '컬러', '막', '햇살', '집', '거실', '세로', '막상', '보', '뼘', '정도', '기존', '커튼', '거', '식', '기장', '커튼', '자체', '커튼', '고리', '구멍', '살짝', '쫌', '한가지', '점', '망사', '원단', '커튼', '끝', '중간', '이음', '선끝', '밖', '음질', '망사', '밖', '음질', '그', '분분', '쫌', '참고', '층', '밤', '집안', '보이', '하나', '안보', '전체', '분위기', '변화', '성공', '기분', '커튼', '개', '이번', '대박', '성공', '가성', '비', '진짜', '뒤', '창', '커튼', '옛날', '집', '그냥', '담달', '하나', '더', '사려', '구', '집', '침대', '추천', '겉', '망사', '조금', '저렴', '차라리', '베이지', '화이트', '실제', '사진', '좀', '더', '것', '레이스', '부분', '약간' ...
#
# ['한 분위기', '한 분위기 연출', '치수', '잘못', '가격대비', '가격대비 이주', '십년', '준 커튼', '하얀색', '저희', '저희 거실', '저희 거실 창', '아주', '커버', '딸들', '틱톡', '가격', '가격 생각', '진짜', '진짜 가성비', '진짜 가성비 짱', '사진', '분홍색', '그것', '이뻣어', '여름', '은 커텐', '살아욘', '완전대만족', '완전대만족 남편몰래', '완전대만족 남편몰래 서프라이즈', '혼자', '남편', '이가격', '커튼', '구입', '안방', '작은방', '작은사이즈', '또 주문', '진짜 백만배강추', '대가', '대가 좀', '진짜 생각한것', '이제', '이제 안방', '작은방 다용도실것', '주문', '완전대만족 추천', '이 가격', '이 커튼', '이 커튼 못', '커튼 진짜', '커튼 진짜 특가', '고급지고', '고급지고 집도', '보이', '기존', '있던 커튼', '암막', '하나', '웨딩드레스', '한게', '한게 대만족', '아쉬운건 세로길이', '아일렛', '아일렛 부분', '머리카락', '그대로', '진작', '진작 살껄', '이중레이스', '이중레이스 안방', '이중레이스 안방 침실용', '기존 암막커튼', '낮잠자기', '낮잠자기 좋은 요요', '낮잠자기 좋은 요요 커튼', '암막의 효과', '인테리어용', '느낌', '분위기', '침구', '이사오면서', '이사오면서 주문한건데', '이사오면서 주문한건데 사이즈', '이사오면서 주문한건데 사이즈 완전', '이사오면서 주문한건데 사이즈 완전 찰떡', '배송', '상자', '여기저기', '설치', '내구성', '스팀다림질', '스팀다림질 한번', '스팀다림질 한번 해주면 더', '약간', '약간 베이지', '약간 베이지빛나는 흰색', '회색기', '흰색', '사진 보기', '하늘하늘한 느낌', '품절', '조금', '자마자', '자마자 바로', '자마자 바로 배송', '조금 더', '조금 더 준', '값어치', '고급스러운 커튼', '달고나', '집 분위기', '완전', '완전 바', '감동', '530', '하나로', '다른', '다른 문', '타블렛', '타블렛 아래쪽', '타블렛 아래쪽 제봉선', '타블렛 아래쪽 제봉선 박음질', '타블렛 아래쪽 제봉선 박음질 일부', '타블렛 아래쪽 제봉선 박음질 일부 부분', '교환', '그냥', '그냥 사용', '암막효과', '화이트', '설치했는데넘', '이뽀', '하옇', '며칠', '한참', '사이즈때문', '보람', '생각', '생각했던 그대', '몇번', '그거', '달아보', '기도', '레이스', '레이스 부분', '레이스 부분 박음질', '레이스 부분 박음질 불량', '해진부분', '다른부분', '살살', '천이', '천이 연결', '천이 연결되는 부분', '오버록', '오버록되어있는 부분', '커튼 설치', '다음', '발견', '또 주름', '안보', '크게', '크게 티', '안나', '디자인', '암막커튼', '암막커튼 질감', '듭니', '커튼박스', '커튼 아래', '포근한느낌', '베이지색상', '핑크', '베이비핑크', '고민', '네용', '네용 더', '네용 더 방이', '주문잘', '감안', '사용', '100프로', '살짝', '살짝 비치는 정도', '이정도', '마감처리', '치면', '치면 정말', '동생', '커텐', '사이즈', '워낙', '적당한 암막', '같은 창문', '같은 창문 사이즈', '더 큰 사이즈', '264사이즈로', '주름', '실사이즈', '실사이즈 두배정도면', '예쁜 주름', '완전 어두운', '완전 어두운 암막', '완전 어두운 암막 원하시는 분', '어느정도', '어느정도 햇빛', '여리한 느낌', '여리한 느낌 원하는 분들', '완전 추천', '조립', '암막도', '암막도 잘', '방 커튼', '여기', '거실커튼', '만족', '완벽암막', '거실', '4시', '효과', '정리', '이제서안', '불키', '암막 어느정도', '궁금하실 분들', '고리형식이', '걱정햇', '샤방해', '지구', '지구 눈', '진짜 마음', '압축봉', '역도함', '역도함 아일렛', '쉬폰', '쉬폰 느낌', '쉬폰 느낌 찾기', '암막 뒤', '두겹', '이중커튼', '커튼 레일', '고민하던중', '쉬폰커튼', '암막커튼 두개', '안성맞춤', '원래', '사이즈의 2배', '보이지', '다행', '화이트 완전', '화이트 완전 강추', '방 분위기', '인스타', '아주 뿜뿜해', '차단', '차단해주지는 못', '추천', '걱정', '분위기 살', '설치 전', '일메', '잡지', '퇴근', '발렌타인', '발렌타인 한 잔', '커튼봉', '커튼봉 자체', '양쪽', '양쪽 균형', '브라켓', '문제', '반나절', '해도', '무게감', '보임', '보임 포쉐린', '보임 포쉐린 타일', '보임 포쉐린 타일 공사', '지면', '지면 높이', '건 세탁', '건 세탁 시', '건 세탁 시 수선집', '겄음', '겄음 커튼', '겄음 커튼 하단', '신발', '밟힌', '밟힌 자국', '검수', '포장때', '포장때 신경', '암막 생각', '사면', '굳이', '굳이 안', '장점', '커튼봉 진짜', '커튼봉 진짜 별로', '다른곳', '천장', '무난', '순백색', '웨딩드레스분위기', '웨딩드레스분위기 음', '웨딩드레스분위기 음 이중인것', '망사', '또 신경', '무조건', '나비커튼', '베란다', '530두개', '4000이', '뭐 감수', '웨딩드레스느낌', '가격대비 완전', '가격대비 완전 만족', '구김', '신혼방', '신혼방 침실', '빛차단', '불편할 정도', '80프로', '80프로 이상', '가성비', '베이지', '있는 가구', '구매', '색상', '질감', '원하던 스탈', '촤르르르르', '촤르르르르 강추', '분리', '계속', '계속 암막', '판단미스', '온 나사', '한번', '있는 공구', '다시', '다시 작업', '컬러', '햇살', '저희집', '저희집 거실', '저희집 거실 세로', '230', '막상', '막상와서보', '반뼘정도', '기존 커튼', '기존 커튼 거', '기장', '커튼자체', '커튼자체 커튼고리', '커튼자체 커튼고리 구멍', '한가지', '한가지 아쉬운점', '있다면 망사원단', '있다면 망사원단 커튼끝', '있다면 망사원단 커튼끝과 중간', '있다면 망사원단 커튼끝과 중간 이음선끝', '있다면 망사원단 커튼끝과 중간 이음선끝 밖음질', '밖음질', '그 분분', '참고', '1층', '집안', '분위기 변화', '기분', '커튼3개째', '이번꺼', '대박성공', '가성비진짜', '얇은커튼', '옛날집', '담달', '하나더사려구', '침대', '추천 겉', '조금 저렴', '차라리', '차라리 베이지', '실제', '좀 더 예쁜 것', '레이스부분', '약간 모기장', '약간 모기장같은 느낌', '실밥', '실밥 정리', '실밥 정리 안', '실밥 정리 안 된 부분', '배송 설치', '배송 설치 적당한 가격', '사이즈미스', '교환 요청', '중이', '노란빛', '노란빛없는 흰색', '구입한건디', '신혼집', '신혼집 커텐', '아주 맘', '드네', '집도', '많이지지', '이건', '이건 다른', '이건 다른 커텐', '잘되길바래서', '잘되길바래서 흰색', '베이지색', '베이지색 암막', '베이지색 암막 더', '선택', '완전 꿀잠', '두께감', '디자인 가격', '디자인 가격 모두', '디자인 가격 모두 만족', '봉타입하나', '이중', '사용할 수', '정말', '정말 좋은 아이디어', '가격대비 재질', '완전 암막', '구매 할때', '때문', '아주 마음', '베이지 선택', '베이지 선택 집', '찰떡', '바람막이겸', '바람막이겸 암막겸', '바람', '솔솔', '실물', '아늑한 느낌', '질도', '암막 잘', '방이', '전 사실', '전 사실 좀', '전 사실 좀 얼렁뚱땅', '하자', '별로', '별로 신경', '흘깃', ...

# %% [raw]
# @@@ CountVectorizer 사용

# %%
type(ko_stopwords)
# Out:
# list

# %%
# vec = CountVectorizer(stop_words=ko_stopwords).fit(df_rev.review.iloc[0])
vec = CountVectorizer(ngram_range=(2,2), stop_words=ko_stopwords).fit(df_rev.review.iloc[0])
bag_of_words = vec.transform(df_rev.review.iloc[0])
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x:x[1], reverse=True)
words_freq[:20]
# Out:
# C:\Users\newel\anaconda3\envs\han\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['가서', '그런', '그럼에도', '그렇게', '그에', '그치지', '김에', '까닭에', '낫다', '년도', '논하지', '누가', '다시', '대해', '되어', '들면', '들자면', '듯하다', '따르는', '따지지', '때가', '만은', '만이', '만큼', '말하면', '말할것도', '몰라도', '몰랏다', '못하다', '바꾸어서', '바꿔', '밖에', '방면으로', '보아', '비길수', '비추어', '뿐만', '생각이다', '서술한바와같이', '쓰여', '아니다', '아니라', '안다', '안된다', '않고', '않기', '않는다면', '않다', '않도록', '알겠는가', '어찌됏든', '없고', '없다', '예를', '외에', '위에서', '이와', '이유는', '임에', '있다', '점에서', '주저하지', '줄은', '틀림없다', '편이', '하기', '하는', '하는것만', '하는것이', '하지', '함으로써', '해도', '해서는', '형식으로', '힘이'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# [('너무 좋아요', 1000),
#  ('배송도 빠르고', 845),
#  ('맘에 들어요', 634),
#  ('마음에 들어요', 619),
#  ('저렴한 가격에', 354),
#  ('너무 마음에', 262),
#  ('부드럽고 좋아요', 260),
#  ('마음에 듭니다', 256),
#  ('크기도 적당하고', 231),
#  ('가격도 저렴하고', 227),
#  ('너무 맘에', 217),
#  ('맘에 듭니다', 213),
#  ('너무 좋네요', 210),
#  ('가격대비 너무', 192),
#  ('촉감도 좋고', 187),
#  ('좋아요 ㅎㅎ', 183),
#  ('너무 예뻐요', 171),
#  ('가성비 좋아요', 158),
#  ('가격대비 좋아요', 146),
#  ('너무 이뻐요', 141)]

# %%
for i, v in enumerate(words_freq):
    if i == 20:
        break
    print(v[0], end=', ')
print()
# Out:
# 너무 좋아요, 배송도 빠르고, 맘에 들어요, 마음에 들어요, 저렴한 가격에, 너무 마음에, 부드럽고 좋아요, 마음에 듭니다, 크기도 적당하고, 가격도 저렴하고, 너무 맘에, 맘에 듭니다, 너무 좋네요, 가격대비 너무, 촉감도 좋고, 좋아요 ㅎㅎ, 너무 예뻐요, 가성비 좋아요, 가격대비 좋아요, 너무 이뻐요,

# %%
vec = CountVectorizer(ngram_range=(1,1), stop_words=ko_stopwords).fit(df_rev.review.iloc[3019])
bag_of_words = vec.transform(df_rev.review.iloc[3019])
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x:x[1], reverse=True)
words_freq[:20]
# Out:
# [('이뻐요', 2),
#  ('분위기', 1),
#  ('있네요', 1),
#  ('라탄', 1),
#  ('흔들의자랑', 1),
#  ('잘어울려요', 1),
#  ('러그', 1),
#  ('덕분에', 1),
#  ('방이', 1),
#  ('완벽해졌습니다', 1),
#  ('너무', 1),
#  ('예뻐요', 1),
#  ('부드럽고', 1),
#  ('색상', 1),
#  ('화면보다', 1),
#  ('푸른빛인데', 1),
#  ('빈티지하고', 1),
#  ('로맨틱하네요', 1),
#  ('진짜', 1),
#  ('촉감', 1)]

# %%
# df_rev shape:
df_rev.shape
# Out:
# (3650, 3)

# %% [markdown]
# ### 3650개 상품에 대한 각각 top 10 review bigram

# %%
# most_review drop하기
df_rev = df_rev.drop(columns='most_review')

# %%
df_rev.head(1)
# Out:
#                     상품명                                             review
# 0  선데이 러그 7size 4colors  [너무 좋네요 선배가 와서 양념치킨 먹다가 바로 흘림 상놈, 배송도 엄청 빨리 왔고...

# %%
df_rev.insert(2, "most_review", "nothing")
df_rev.head(2)
# Out:
#                        상품명                                             review  \
# 0     선데이 러그 7size 4colors  [너무 좋네요 선배가 와서 양념치킨 먹다가 바로 흘림 상놈, 배송도 엄청 빨리 왔고...
# 1  순수원목 선반장 4colors (가로2단)  [여기서 날파리가많이나왔어욥왤까여, 이 가격에 이렇게 예뿌다니 진짜 맘에 들어용 품...
#
#   most_review
# 0     nothing
# 1     nothing

# %%
for i in range(df_rev.shape[0]):
    try:
        vec = CountVectorizer(ngram_range=(2,2), stop_words=ko_stopwords).fit(df_rev.review.iloc[i])
        bag_of_words = vec.transform(df_rev.review.iloc[i])
        sum_words = bag_of_words.sum(axis=0)
        words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
        words_freq = sorted(words_freq, key = lambda x:x[1], reverse=True)[:10]
        df_rev.at[i, 'most_review'] = [row[0] for row in words_freq][:5] # ValueError: empty vocabulary; perhaps the documents only contain stop words
        if len(df.iloc[i]['review']) < 11:
            # 리뷰개수가 적어 겹칠경우 방지를 위해 홀수번째만
            df_rev.at[i, 'most_review'] = [row[0] for row in words_freq][::2]
    except:
        df_rev.at[i, 'most_review'] = [""] # ValueError: empty vocabulary; perhaps the documents only contain stop words
# Out:
# C:\Users\newel\anaconda3\envs\han\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['가서', '그런', '그럼에도', '그렇게', '그에', '그치지', '김에', '까닭에', '낫다', '년도', '논하지', '누가', '다시', '대해', '되어', '들면', '들자면', '듯하다', '따르는', '따지지', '때가', '만은', '만이', '만큼', '말하면', '말할것도', '몰라도', '몰랏다', '못하다', '바꾸어서', '바꿔', '밖에', '방면으로', '보아', '비길수', '비추어', '뿐만', '생각이다', '서술한바와같이', '쓰여', '아니다', '아니라', '안다', '안된다', '않고', '않기', '않는다면', '않다', '않도록', '알겠는가', '어찌됏든', '없고', '없다', '예를', '외에', '위에서', '이와', '이유는', '임에', '있다', '점에서', '주저하지', '줄은', '틀림없다', '편이', '하기', '하는', '하는것만', '하는것이', '하지', '함으로써', '해도', '해서는', '형식으로', '힘이'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
df_most = df_rev[['pname', 'most_review']]
df_most.to_excel("각 상품별 상위5개 bigram 키워드.xlsx")
df_most.sample(10)
# Out:
#                                     pname  \
# 850                  KURBY 의자 A타입 3colors
# 1435             하멜 리본타이 린넨쿠션(솜포함)(50x50)
# 248                       PP 라탄 바스켓 수납바스켓
# 2442           크리스마스트리 샬롯레드 1.3M 전구장식 풀세트
# 1880                  원목 라탄 나트랑체어 2colors
# 1586      HUGGY BEAR FABRIC POSTER_2sizes
# 1001         [할인쿠폰] 버니 방수 패브릭 3.5인 카우치 소파
# 3033               [쿠폰할인] 뉴플로렌스 골드 스탠딩 거울
# 3601  [해외] Setago JH27 테이블 램프 nude-forest
# 506                    노르딕 육각 테이블 5colors
#
#                                             most_review
# 850          [배송도 빠르고, 마음에 들어요, 너무 예뻐요, 맘에 들어요, 맘에 듭니다]
# 1435         [너무 예뻐요, 배송도 빠르고, 마음에 들어요, 너무 맘에, 너무 빵빵해서]
# 248          [너무 좋아요, 뚜껑이 있어서, 너무 예뻐요, 마음에 들어요, 맘에 들어요]
# 2442       [너무 예뻐요, 생각했던거 보다, 보다 퀄리티가, 퀄리티가 너무, 너무 좋아서]
# 1880     [너무 편하고, 너무 예뻐요, 마음에 듭니다, 처음에 불량제품이, 불량제품이 와서]
# 1586       [너무 귀여워요, 너무 귀엽고, 가격은 비싸지만, 너무 귀여워서, 맘에 들어요]
# 1001           [맘에 들어요, 기다린 보람이, 너무 이뻐요, 맘에 듭니다, 너무 맘에]
# 3033   [생각햇던 금색은, 금색은 아니지만, 아니지만 무광황색, 무광황색 이게, 이게 이쁜것]
# 3601  [디자인 마음에, 마음에 듭니다, 듭니다 무선이라서, 무선이라서 휴대성이, 휴대성이...
# 506           [조립도 쉽고, 너무 좋아요, 맘에 들어요, 배송도 빠르고, 너무 예뻐요]

# %%
df_rev.iloc[2222]['review']
# Out:
# ['생각보다 작지만 군더더기 없이 귀엽네요 잘 쓸게요',
#  '보온도 잘 되고 디자인도 아담하니 예쁩니다',
#  '사이즈 딱 좋고 죽통으로 괜찮을 것 같아요  색감도 파스텔 톤이라 예쁘고 배송도 하루만에 도착 했어요 ',
#  '예쁘고 사용하기 편하네요 밀폐력도 좋은거 같아요',
#  '텀블러만 주는줄 알았는데 사은품으로 커버랑 수저도 포함되어 있었네요이럴줄알았으면 커버는 따로 사지 말껄 그랬니봐요ㅠㅠ다행히 색상은 다르게와서 기분전환할때마다 다르게 껴야겠어요 ㅋㅋ 쨌든 사은품 감사드리고 잘쓰겠습니다',
#  '좋아요좋아요좋아요좋아요좋아요좋아요',
#  '모슈 텀블러 사용 했는데 보온 보냉이 잘 돼서 죽통도 주문 했어요 아직 사용을 안 해봐서 성능은 모르겠지만 디자인은 너무 귀여워요',
#  '예뻐서 샀어요 보온ㅇ력은 평범한거같아요',
#  '귀엽고 이뻐요 색감도 이쁘네요 맘에듭니다',
#  '너무 귀엽네요 생각보다 많이 들어갈것같아서 더욱 좋아요',
#  '디자인도 귀엽고 같이 동봉되어 온 숟가락도 너무 귀엽습니다 귀여운걸 떠나서 보온이 정말 잘되네요 아침에 만든 수프를 넣어서 점심에 먹는데도 뜨겁습니다 만족해요',
#  '디자인 너무 심플하고 색상도 이뻐요',
#  '제가 생각한 민트하고는 완전다르네요디자인은 예뻐요보온력은 그냥 그래요',
#  '배송이 빨라서 좋았구요 크기도 딱 원하는 사이즈예요 스푼이랑 커버도 너무 귀엽네요 모슈제품 많이 가지고 있는데 디자인이 참 이뻐요ㅋ',
#  '모양도 이쁘고 양이 적절해요 비비고 미역국 한 봉이 그대로 다 들어갑니다 제법 온기도 오래가서 도시락용으로 좋아요',
#  '빠른배송 감사합니다 이뻐요 420L이 혹시 클까봐 걱정했는데 큰거하기를 잘한것같아요',
#  '색상 너무 마음에 들어요 교정하고 먹는게 불편해서 죽 먹는데 딱 좋아요',
#  '요즘 도시락 싸서 출근하는데 보온도시락이 필요하겠더라그용 다른 거랑 고민하다가 이게 이뻐서 걍 주문했어요 ㅜㅜ 이뻐요 잘 쓸게요',
#  '아기이유식용으로산건데 넘나이쁘고 보온잘되요',
#  '넘넘 예뻐요 깨물어주고 싶엉 머스터드 컬러는 뚜껑까지 머스터드인데 얘네 둘은 흰색처리 따라오는 스푼도 있어서 쎄뚜쎄뚜']

# %% [raw]
# - cbf: 컨텐츠 더
# - cf:  사용자 행동
#     - 아이템: 행렬을 바꾸고 유사성
#     - 사용자:
# - 단순하게 매칭보단 cos similarity 계산해서 도출했다 이정도가 더 임팩트 있어보였다
# - 유클리디안: 비율 상관 x, 코사인: 각도기반이므로 비율 ㅇ, 50:50 이면 cos sim이면 scale을 중시하지 않는다

# %%
df_rev.most_review
# Out:
# 0       [너무 좋아요, 배송도 빠르고, 맘에 들어요, 마음에 들어요, 저렴한 가격에, 너무...
# 1       [조립도 쉽고, 배송도 빠르고, 마음에 들어요, 너무 좋아요, 맘에 들어요, 침대 ...
# 2       [너무 예뻐요, 배송도 빠르고, 맘에 들어요, 너무 이뻐요, 너무 좋아요, 마음에 ...
# 3       [조립도 쉽고, 너무 예뻐요, 배송도 빠르고, 맘에 들어요, 마음에 들어요, 너무 ...
# 4       [너무 좋아요, 편하고 좋아요, 너무 편하고, 너무 편해요, 배송도 빠르고, 생각보...
#                               ...
# 3645                    [토퍼가좀딱따해요 부드러운토퍼, 부드러운토퍼 다시사야겧어요]
# 3646                                [깔끔하고 디자인, 좋네요 만족합니다]
# 3647             [가격대비 만족해요, 만족해요 배송도괜찮고, 배송도괜찮고 사용하기좋네요]
# 3648            [배송도 빨리오고, 빨리오고 가격도, 가격도 저렴해서, 저렴해서 좋습니다]
# 3649    [일단 디자인, 디자인 적으로, 적으로 심플해서, 심플해서 마음에, 마음에 들었고요...
# Name: most_review, Length: 3650, dtype: object

# %%
df_rev.sample(20)
# Out:
#                                            상품명  \
# 2831              [리퍼] 공기청정기 Le-510 원룸 H13헤파필터
# 2557                               라탄등나무피크닉바구니
# 1463          원목 협탁 사이드 테이블 논슬립 스펀지 증정 (2type)
# 3097                        가드너스와이프 유약분 -- 화이트
# 1204                     그리너리 가리개 커튼 (창문형/긴창형)
# 1956                       allday LIM 브런치 플레이트
# 2250                   보르미올리 비스트로 저그 유리물병 1.0L
# 2689                    [해외] 전기포트 KLF03 8color
# 2592  행잉 레더스트랩 (L) - HANGING LEATHER STRAP (L)
# 74                           [쿠폰할인] 피카 사이드 테이블
# 882               보아르 클린에어 3중 헤파필터 H13등급 공기청정기
# 1638                        카페 스윙 인테리어 휴지통(5L)
# 2392            오마주 실리콘 플레이트 테이블매트 프렌치35 7종 택1
# 2184                          앵두전구 30구 50구 80구
# 519          비산 파손방지 강화 안전 대형 전신거울 400/600/700
# 298                                플레르 레이스 식탁보
# 2128                      600ml 스텐 우유 스팀피쳐/눈금형
# 1076          샌드베이지 색상 출시! 4E 테이블 단스탠드_5colors
# 2943    회전목마캔들 메리고라운드 오브제캔들 디자인 향초 필라왁스 인테리어소품
# 2556                             냄새제거 향초_2type
#
#                                                  review most_review
# 2831  [행사로 저렴하게 잘 샀습니다 자취하면서 작은 청정기 알아보고 있었는데 uv기능보고...     nothing
# 2557  [예뻐요 저는 참숯을 담아놨는뎅 너무 예뻐요, 원하던색상에 디자인까지, 예뻐요 잘 ...     nothing
# 1463  [선물용으러 구입한건대 볼트랑 꺽쇠랑 사이즈도 안맞고 이건 조립을 어떻게 하라는건지...     nothing
# 3097  [작은 사이즈는 기본 화원포트 분갈이용으로 적합해요 너무 이뻐요❣️, 깔끔하고 흠잡...     nothing
# 1204  [생각보다 훨씬 장화홍련느낌이라 첨에 약당황했으나 소재가 너무 좋고 고급져보여요 책...     nothing
# 1956  [너무 귀여워요 밀크티베이지인가 이색은 귀여워서 있는 것 거의 다 샀네요, 기대이상...     nothing
# 2250  [작은것 하나1L 두개 구매했어요 너무 이쁘게 잘 쓰고있습니다 유리 단단하고 깨지지...     nothing
# 2689  [배송도 완전 빠르고 좋네요 강추합니다, 꺄 넘이뽀요 착각해서 도착도 하기전에 구매...     nothing
# 2592  [아주 아주 아주 맘에 들어요 행잉 레더스트랩 이것저것 많이 보고 비교해봤는데 정말...     nothing
# 74    [조립 직접하시는분들 꼭 보셨으면 여자혼자사는집이라 기사님께 비밀번호 알려드리긴 좀...     nothing
# 882   [제가 맘에드는 물건이 있으면 세심한 리뷰를 적는게 좋아하는 편인데 이게 얼마만인지...     nothing
# 1638  [크기가 고양이만하고 적당한 사이즈라 좋구요 그레이 색깔과 디자인이 너무 마음에듭니...     nothing
# 2392  [완젼 이뻐이뻐 이뻐요  혼자먹어도 근사하게대접받은 느낌입니다, 오마주 실리콘 테이...     nothing
# 2184  [넘 길어서 엉키고 걸기힘들었어요 짧은거 살껄그랬어요 그래도 진챠이뻐요, 깔끔하고 ...     nothing
# 519   [거울 뒷편으로 곰팡이가 잔뜩 끼여서 왔네요ㅜ 반품시킬까하다가 닦여져서 여러번 닦아...     nothing
# 298   [완전 완전 가격에 비해 퀄리티며 디자인이며 짜임마무리며 입 댈 거 없다며 혼자 감...     nothing
# 2128  [무난 깔끔한게 딱 좋아요ㅎㅎㅎ 가격두 착하구 이걸루 열심히 연습할게요, 크기도 적...     nothing
# 1076  [부모님 방에 둘 무드등으로 선물해드렸는데 엄빠 모두 좋아하시네요 넘 예쁜거 캐치해...     nothing
# 2943  [정말 마음에 들어요 향도 맘에 들고 포인트 주기 좋아요, 블랙체리 향 달콤한 소주...     nothing
# 2556  [기대보다는 향이 덜하지만 분위기 내고 싶을때 켜요 따로 받침 없이 윗부분 비닐만 ...     nothing

# %%
# vec = CountVectorizer(stop_words=ko_stopwords).fit(df_rev.review.iloc[1])
vec = CountVectorizer(ngram_range=(2,2), stop_words=ko_stopwords).fit(df_rev.review.iloc[1])
bag_of_words = vec.transform(df_rev.review.iloc[0])
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items() if ]
words_freq = sorted(words_freq, key = lambda x:x[1], reverse=True)
words_freq[:20]

# %% [raw]
# @@@ TF-IDF 와 토큰화 -> 실패

# %% [markdown]
# # KRWordRank 시도
# - [https://github.com/lovit/KR-WordRank](https://github.com/lovit/KR-WordRank) 코드 그대로 사용

# %%
from krwordrank.word import KRWordRank

# %%
min_count = 5
max_length = 300
wordrank_extractor = KRWordRank(min_count=min_count, max_length=max_length)

# %%
beta = 0.85
max_iter = 100
texts = df_rev["review"][3019]
keywords, rank, graph = wordrank_extractor.extract(texts, beta, max_iter)

# %%
# 불용어 정의(리뷰에서 너무 많이 보여거 뺄 것)
custom_stopwords = {'너무', 'ㅎㅎ', 'ㅋㅋ', '좋아요', '예뻐요', '이뻐요', '진짜', '정말', '예쁘고', 
                    '이쁘고', '맘에','들어요', '완전', '좋고', '생각보다', '같아요', '마음에',
                    '조금', '엄청', '아주', '좋습니다', '좋네요', '생각', '예쁘'}
passwords = {word:score for word, score in 
             sorted(keywords.items(), key=lambda x:-x[1])[:20] if not (word in custom_stopwords)}
passwords
# Out:
# {}

# %%
df_rev.shape
# Out:
# (3650, 4)

# %%
df_rev[df_rev['상품명'] == "빈티지그린 로즈부케 드로잉 원형러그"]['review']
# Out:
# 3019    [분위기 있네요 라탄 흔들의자랑 잘어울려요, 러그 덕분에 제 방이 완벽해졌습니다 너...
# Name: review, dtype: object

# %%
df_rev["review"][3019]
# Out:
# ['분위기 있네요 라탄 흔들의자랑 잘어울려요',
#  '러그 덕분에 제 방이 완벽해졌습니다 너무 예뻐요 ',
#  '부드럽고 색상 넘 이뻐요 화면보다 좀 더 푸른빛인데 빈티지하고 로맨틱하네요',
#  '진짜 촉감 너어어어무 좋아요  거실카펫도 여기꺼로 바꾸려구요 거기다가 세탁기돌려도 된다니 대만족입니다 ㅋㅋ 실물이 훨 이뻐요']

# %%
# without stopwords
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:30]:
    print('%8s:\t%.4f' % (word, r))
# Out:
#       너무:	2.3830

# %%
# summarize_with_keywords 함수
from krwordrank.word import summarize_with_keywords

keywords = summarize_with_keywords(df_rev["review"][3019], min_count=3, max_length=10,
           beta=0.85, max_iter=10, stopwords=custom_stopwords, verbose=True)
# Out:
# scan vocabs ...
# num vocabs = 3
# done = 1 Early stopped.

# %%
# print([kwrd for kwrd in keywords][:5])

# for i in range(len(keywords)):
#     print(keywords[i])

print(df_rev["상품명"][77][7:])
keywords
# Out:
# 크리미 세미워싱 차렵이불 (S/Q) 2colors
# {'이불': 14.644398451993231,
#  '가볍고': 12.997023166649319,
#  '부드럽고': 7.685038654354408,
#  '느낌': 6.251748765404665,
#  '색도': 5.484756456718726,
#  '포근': 5.17273446982149,
#  '배송': 4.654156369794625,
#  '약간': 4.638713407702633,
#  '세탁': 4.3998864927492605,
#  '만족': 4.383897975177778,
#  '촉감': 4.069411973984497,
#  '베이지': 3.9640799566493943,
#  '색상도': 3.854979853034597,
#  '그래도': 3.753163479791768,
#  '폭신': 3.7266687842778823,
#  '가격': 3.706242314847995,
#  '따뜻': 3.537542457177348,
#  'ㅠㅠ': 3.34983129129913,
#  '구매': 3.3497817387426396,
#  '근데': 3.3460161689032053,
#  '제가': 3.275347530812946,
#  '많이': 3.2628453350366025,
#  '색깔도': 3.1369929913288233,
#  '가성비': 3.0247877446579294,
#  '부들': 2.95640023620295,
#  '그냥': 2.944697751342009,
#  '보들': 2.8929053051123153,
#  '사용': 2.7824838512566137,
#  '바로': 2.7701940486195022,
#  '아직': 2.758731219274284,
#  '좋은': 2.7231358936021763,
#  '색감': 2.674966054899416,
#  '푹신': 2.5309616139586923,
#  '다른': 2.47217981811262,
#  '색은': 2.468087812369636,
#  '잠이': 2.416919581603841,
#  '빠르고': 2.3887785622676203,
#  '패드': 2.2446377433289237,
#  '가벼': 2.243387008435504,
#  '사진': 2.1016354781511857,
#  '보풀이': 2.074737510132795,
#  '살짝': 2.0553531029687186,
#  '다만': 2.029491678626485,
#  '샀는데': 2.014963974819673,
#  '처음': 1.9616442041155842,
#  '색이': 1.9455221622352386,
#  '한번': 1.9251471526373996,
#  '그리고': 1.852939705842683,
#  '듭니다': 1.8506715590340854,
#  '그레이': 1.7851619721510366,
#  '재질': 1.721510270119781,
#  '있어': 1.70912037615662,
#  '오자마자': 1.585669821774078,
#  '지금': 1.551659044420382,
#  '아니': 1.5212055549327665,
#  '저는': 1.5044271241578024,
#  '괜찮': 1.5038705012364133,
#  '저렴': 1.5003052980390814,
#  '베개': 1.4722994419558169,
#  '재구매': 1.4583286507068052,
#  '하지만': 1.4097551246283424,
#  'ㅜㅜ': 1.4069437835292464,
#  '여름에도': 1.3665238024053061,
#  '하나': 1.347376539696639,
#  '사이': 1.3400104344617878,
#  '일단': 1.2765867005307894,
#  '이쁩니다': 1.2695141768997567,
#  '디자인': 1.251246992875633,
#  '해요': 1.2442979947460602,
#  '솜이': 1.231105627614839,
#  '있는': 1.2260009872015925,
#  '같은': 1.2243380987799188,
#  '되게': 1.2194591267400465,
#  '사계절': 1.2143264695713483,
#  '전체적으로': 1.1992510109984575,
#  '빨리': 1.1947423158674448,
#  '얇고': 1.1938085802522846,
#  '섞인': 1.1670900781974063,
#  '받자마자': 1.1640718510496515,
#  '잠도': 1.1521715800875132,
#  '합니다': 1.144701137621161,
#  '보고': 1.1365564235823808,
#  '주름이': 1.128072755812369,
#  '침대': 1.1158823648446552,
#  '고민': 1.1150332088038521,
#  '쓰고': 1.1122848211193115,
#  '굉장히': 1.1007972500289833,
#  '그대로': 1.096571272545471,
#  '제품': 1.090010964626154,
#  '계속': 1.0700754271859296,
#  '했는데': 1.0683528258555302,
#  '같이': 1.0634317297614686,
#  '매트': 1.0628734645243934,
#  '않고': 1.0576366775862542,
#  '제일': 1.0493862987667415,
#  '컬러': 1.026061842740945,
#  '주문': 1.0235064176775353,
#  '먼지': 1.019776707275943,
#  '커버': 1.0182015161387532,
#  '감사': 1.0152941256898278}

# %% [markdown]
# # 찐 키워드 추출
# - KRWordRank
# - 아래 두 셀이 다임

# %%
stopwords = {'너무', 'ㅎㅎ', 'ㅎㅎㅎ', 'ㅋㅋ', '좋아요', '예뻐요', '이뻐요', '진짜', '정말', '예쁘고', 
                    '이쁘고', '맘에','들어요', '완전', '좋고', '생각보다', '같아요', '마음에', 'ㅜㅜ', 'ㅜㅜㅜ'
                    '조금', '엄청', '아주', '좋습니다', '좋네요', '생각', '예쁘', 'ㅠㅠ', 'ㅠㅠㅠ', 'ㅋㅋㅋ'}

# %%
from krwordrank.word import KRWordRank
from krwordrank.word import summarize_with_keywords

# 모든 상품 각각에 대한 top5 키워드 추출
for i in range(df_rev.shape[0]):
    keywords = summarize_with_keywords(df_rev["review"][i], 
                                       min_count=1, max_length=10, 
                                       beta=0.85, max_iter=10, 
                                       stopwords=stopwords, verbose=True)
    # 각 상품명 row별 most reviewed 항목 value값 변경
    df_rev.at[i, 'most_review'] = [kwrd for kwrd in keywords][:5] # 상위 5개만
# Out:
# scan vocabs ...
# num vocabs = 315
# done = 10
# scan vocabs ...
# num vocabs = 429
# done = 10
# scan vocabs ...
# num vocabs = 589
# done = 10
# scan vocabs ...
# num vocabs = 1072
# done = 10
# scan vocabs ...
# num vocabs = 495
# done = 10
# scan vocabs ...
# num vocabs = 911
# done = 10
# scan vocabs ...
# num vocabs = 370
# done = 10
# scan vocabs ...
# num vocabs = 380
# done = 10
# scan vocabs ...
# num vocabs = 258
# done = 10
# scan vocabs ...
# num vocabs = 249
# done = 10
# scan vocabs ...
# num vocabs = 480
# done = 10
# scan vocabs ...
# num vocabs = 350
# done = 10
# scan vocabs ...
# num vocabs = 377
# done = 10
# scan vocabs ...
# num vocabs = 323
# done = 10
# scan vocabs ...
# num vocabs = 500
# done = 10
# scan vocabs ...
# num vocabs = 330
# done = 10
# scan vocabs ...
# num vocabs = 281
# done = 10
# scan vocabs ...
# num vocabs = 608
# done = 10
# scan vocabs ...
# num vocabs = 469
# done = 10
# scan vocabs ...
# num vocabs = 411
# done = 10
# scan vocabs ...
# num vocabs = 308
# done = 10
# scan vocabs ...
# num vocabs = 410
# done = 10
# scan vocabs ...
# num vocabs = 245
# done = 10
# scan vocabs ...
# num vocabs = 372
# done = 10
# scan vocabs ...
# num vocabs = 340
# done = 10
# scan vocabs ...
# num vocabs = 269
# done = 10
# scan vocabs ...
# num vocabs = 330
# done = 10
# scan vocabs ...
# num vocabs = 385
# done = 10
# scan vocabs ...
# num vocabs = 443
# done = 10
# scan vocabs ...
# num vocabs = 437
# done = 10
# scan vocabs ...
# num vocabs = 365
# done = 10
# scan vocabs ...
# num vocabs = 367
# done = 10
# scan vocabs ...
# num vocabs = 326
# done = 10
# scan vocabs ...
# num vocabs = 483
# done = 10
# scan vocabs ...
# num vocabs = 380
# done = 10
# scan vocabs ...
# num vocabs = 378
# done = 10
# scan vocabs ...
# num vocabs = 323
# done = 10
# scan vocabs ...
# num vocabs = 554
# done = 10
# scan vocabs ...
# num vocabs = 301
# done = 10
# scan vocabs ...
# num vocabs = 232
# done = 10
# scan vocabs ...
# num vocabs = 474
# done = 10
# scan vocabs ...
# num vocabs = 446
# done = 10
# scan vocabs ...
# num vocabs = 310
# done = 10
# scan vocabs ...
# num vocabs = 391
# done = 10
# scan vocabs ...
# num vocabs = 223
# done = 10
# scan vocabs ...
# num vocabs = 319
# done = 10
# scan vocabs ...
# num vocabs = 214
# done = 10
# scan vocabs ...
# num vocabs = 280
# done = 10
# scan vocabs ...
# num vocabs = 396
# done = 10
# scan vocabs ...
# num vocabs = 531
# done = 10
# scan vocabs ...
# num vocabs = 296
# done = 10
# scan vocabs ...
# num vocabs = 258
# done = 10
# scan vocabs ...
# num vocabs = 239
# done = 10
# scan vocabs ...
# num vocabs = 255
# done = 10
# scan vocabs ...
# num vocabs = 677
# done = 10
# scan vocabs ...
# num vocabs = 245
# done = 10
# scan vocabs ...
# num vocabs = 401
# done = 10
# scan vocabs ...
# num vocabs = 359
# done = 10
# scan vocabs ...
# num vocabs = 485
# done = 10
# scan vocabs ...
# num vocabs = 203
# done = 10
# scan vocabs ...
# num vocabs = 275
# done = 10
# scan vocabs ...
# num vocabs = 508
# done = 10
# scan vocabs ...
# num vocabs = 285
# done = 10
# scan vocabs ...
# num vocabs = 318
# done = 10
# scan vocabs ...
# num vocabs = 262
# done = 10
# scan vocabs ...
# num vocabs = 496
# done = 10
# scan vocabs ...
# num vocabs = 273
# done = 10
# scan vocabs ...
# num vocabs = 466
# done = 10
# scan vocabs ...
# num vocabs = 320
# done = 10
# scan vocabs ...
# num vocabs = 272
# done = 10
# scan vocabs ...
# num vocabs = 258
# done = 10
# scan vocabs ...
# num vocabs = 249
# done = 10
# scan vocabs ...
# num vocabs = 278
# done = 10
# scan vocabs ...
# num vocabs = 373
# done = 10
# scan vocabs ...
# num vocabs = 353
# done = 10
# scan vocabs ...
# num vocabs = 253
# done = 10
# scan vocabs ...
# num vocabs = 331
# done = 10
# scan vocabs ...
# num vocabs = 224
# done = 10
# scan vocabs ...
# num vocabs = 309
# done = 10
# scan vocabs ...
# num vocabs = 197
# done = 10
# scan vocabs ...
# num vocabs = 250
# done = 10
# scan vocabs ...
# num vocabs = 158
# done = 10
# scan vocabs ...
# num vocabs = 181
# done = 10
# scan vocabs ...
# num vocabs = 97
# done = 10
# scan vocabs ...
# num vocabs = 235
# done = 10
# scan vocabs ...
# num vocabs = 480
# done = 10
# scan vocabs ...
# num vocabs = 390
# done = 10
# scan vocabs ...
# num vocabs = 189
# done = 10
# scan vocabs ...
# num vocabs = 251
# done = 10
# scan vocabs ...
# num vocabs = 392
# done = 10
# scan vocabs ...
# num vocabs = 279
# done = 10
# scan vocabs ...
# num vocabs = 326
# done = 10
# scan vocabs ...
# num vocabs = 231
# done = 10
# scan vocabs ...
# num vocabs = 187
# done = 10
# scan vocabs ...
# num vocabs = 476
# done = 10
# scan vocabs ...
# num vocabs = 175
# done = 10
# scan vocabs ...
# num vocabs = 267
# done = 10
# scan vocabs ...
# num vocabs = 308
# done = 10
# scan vocabs ...
# num vocabs = 658
# done = 10
# scan vocabs ...
# num vocabs = 772
# done = 10
# scan vocabs ...
# num vocabs = 219
# done = 10
# scan vocabs ...
# num vocabs = 458
# done = 10
# scan vocabs ...
# num vocabs = 331
# done = 10
# scan vocabs ...
# num vocabs = 315
# done = 10
# scan vocabs ...
# num vocabs = 404
# done = 10
# scan vocabs ...
# num vocabs = 302
# done = 10
# scan vocabs ...
# num vocabs = 195
# done = 10
# scan vocabs ...
# num vocabs = 248
# done = 10
# scan vocabs ...
# num vocabs = 196
# done = 10
# scan vocabs ...
# num vocabs = 449
# done = 10
# scan vocabs ...
# num vocabs = 394
# done = 10
# scan vocabs ...
# num vocabs = 251
# done = 10
# scan vocabs ...
# num vocabs = 290
# done = 10
# scan vocabs ...
# num vocabs = 245
# done = 10
# scan vocabs ...
# num vocabs = 275
# done = 10
# scan vocabs ...
# num vocabs = 448
# done = 10
# scan vocabs ...
# num vocabs = 628
# done = 10
# scan vocabs ...
# num vocabs = 315
# done = 10
# scan vocabs ...
# num vocabs = 216
# done = 10
# scan vocabs ...
# num vocabs = 243
# done = 10
# scan vocabs ...
# num vocabs = 254
# done = 10
# scan vocabs ...
# num vocabs = 350
# done = 10
# scan vocabs ...
# num vocabs = 366
# done = 10
# scan vocabs ...
# num vocabs = 460
# done = 10
# scan vocabs ...
# num vocabs = 307
# done = 10
# scan vocabs ...
# num vocabs = 186
# done = 10
# scan vocabs ...
# num vocabs = 239
# done = 10
# scan vocabs ...
# num vocabs = 230
# done = 10
# scan vocabs ...
# num vocabs = 436
# done = 10
# scan vocabs ...
# num vocabs = 420
# done = 10
# scan vocabs ...
# num vocabs = 294
# done = 10
# scan vocabs ...
# num vocabs = 592
# done = 10
# scan vocabs ...
# num vocabs = 294
# done = 10
# scan vocabs ...
# num vocabs = 351
# done = 10
# scan vocabs ...
# num vocabs = 359
# done = 10
# scan vocabs ...
# num vocabs = 246
# done = 10
# scan vocabs ...
# num vocabs = 296
# done = 10
# scan vocabs ...
# num vocabs = 224
# done = 10
# scan vocabs ...
# num vocabs = 200
# done = 10
# scan vocabs ...
# num vocabs = 196
# done = 10
# scan vocabs ...
# num vocabs = 261
# done = 10
# scan vocabs ...
# num vocabs = 294
# done = 10
# scan vocabs ...
# num vocabs = 163
# done = 10
# scan vocabs ...
# num vocabs = 173
# done = 10
# scan vocabs ...
# num vocabs = 260
# done = 10
# scan vocabs ...
# num vocabs = 180
# done = 10
# scan vocabs ...
# num vocabs = 257
# done = 10
# scan vocabs ...
# num vocabs = 814
# done = 10
# scan vocabs ...
# num vocabs = 343
# done = 10
# scan vocabs ...
# num vocabs = 279
# done = 10
# scan vocabs ...
# num vocabs = 364
# done = 10
# scan vocabs ...
# num vocabs = 167
# done = 10
# scan vocabs ...
# num vocabs = 252
# done = 10
# scan vocabs ...
# num vocabs = 215
# done = 10
# scan vocabs ...
# num vocabs = 161
# done = 10
# scan vocabs ...
# num vocabs = 150
# done = 10
# scan vocabs ...
# num vocabs = 241
# done = 10
# scan vocabs ...
# num vocabs = 217
# done = 10
# scan vocabs ...
# num vocabs = 253
# done = 10
# scan vocabs ...
# num vocabs = 124
# done = 10
# scan vocabs ...
# num vocabs = 252
# done = 10
# scan vocabs ...
# num vocabs = 426
# done = 10
# scan vocabs ...
# num vocabs = 199
# done = 10
# scan vocabs ...
# num vocabs = 363
# done = 10
# scan vocabs ...
# num vocabs = 214
# done = 10
# scan vocabs ...
# num vocabs = 233
# done = 10
# scan vocabs ...
# num vocabs = 471
# done = 10
# scan vocabs ...
# num vocabs = 332
# done = 10
# scan vocabs ...
# num vocabs = 212
# done = 10
# scan vocabs ...
# num vocabs = 258
# done = 10
# scan vocabs ...
# num vocabs = 306
# done = 10
# scan vocabs ...
# num vocabs = 166
# done = 10
# scan vocabs ...
# num vocabs = 348
# done = 10
# scan vocabs ...
# num vocabs = 179
# done = 10
# scan vocabs ...
# num vocabs = 562
# done = 10
# scan vocabs ...
# num vocabs = 288
# done = 10
# scan vocabs ...
# num vocabs = 153
# done = 10
# scan vocabs ...
# num vocabs = 455
# done = 10
# scan vocabs ...
# num vocabs = 399
# done = 10
# scan vocabs ...
# num vocabs = 421
# done = 10
# scan vocabs ...
# num vocabs = 321
# done = 10
# scan vocabs ...
# num vocabs = 207
# done = 10
# scan vocabs ...
# num vocabs = 181
# done = 10
# scan vocabs ...
# num vocabs = 151
# done = 10
# scan vocabs ...
# num vocabs = 303
# done = 10
# scan vocabs ...
# num vocabs = 402
# done = 10
# scan vocabs ...
# num vocabs = 264
# done = 10
# scan vocabs ...
# num vocabs = 146
# done = 10
# scan vocabs ...
# num vocabs = 214
# done = 10
# scan vocabs ...
# num vocabs = 168
# done = 10
# scan vocabs ...
# num vocabs = 436
# done = 10
# scan vocabs ...
# num vocabs = 331
# done = 10
# scan vocabs ...
# num vocabs = 258
# done = 10
# scan vocabs ...
# num vocabs = 183
# done = 10
# scan vocabs ...
# num vocabs = 266
# done = 10
# scan vocabs ...
# num vocabs = 218
# done = 10
# scan vocabs ...
# num vocabs = 349
# done = 10
# scan vocabs ...
# num vocabs = 368
# done = 10
# scan vocabs ...
# num vocabs = 357
# done = 10
# scan vocabs ...
# num vocabs = 127
# done = 10
# scan vocabs ...
# num vocabs = 426
# done = 10
# scan vocabs ...
# num vocabs = 163
# done = 10
# scan vocabs ...
# num vocabs = 217
# done = 10
# scan vocabs ...
# num vocabs = 199
# done = 10
# scan vocabs ...
# num vocabs = 285
# done = 10
# scan vocabs ...
# num vocabs = 308
# done = 10
# scan vocabs ...
# num vocabs = 205
# done = 10
# scan vocabs ...
# num vocabs = 193
# done = 10
# scan vocabs ...
# num vocabs = 301
# done = 10
# scan vocabs ...
# num vocabs = 395
# done = 10
# scan vocabs ...
# num vocabs = 325
# done = 10
# scan vocabs ...
# num vocabs = 244
# done = 10
# scan vocabs ...
# num vocabs = 465
# done = 10
# scan vocabs ...
# num vocabs = 192
# done = 10
# scan vocabs ...
# num vocabs = 224
# done = 10
# scan vocabs ...
# num vocabs = 219
# done = 10
# scan vocabs ...
# num vocabs = 245
# done = 10
# scan vocabs ...
# num vocabs = 260
# done = 10
# scan vocabs ...
# num vocabs = 158
# done = 10
# scan vocabs ...
# num vocabs = 370
# done = 10
# scan vocabs ...
# num vocabs = 257
# done = 10
# scan vocabs ...
# num vocabs = 331
# done = 10
# scan vocabs ...
# num vocabs = 315
# done = 10
# scan vocabs ...
# num vocabs = 195
# done = 10
# scan vocabs ...
# num vocabs = 115
# done = 10
# scan vocabs ...
# num vocabs = 147
# done = 10
# scan vocabs ...
# num vocabs = 235
# done = 10
# scan vocabs ...
# num vocabs = 142
# done = 10
# scan vocabs ...
# num vocabs = 167
# done = 10
# scan vocabs ...
# num vocabs = 145
# done = 10
# scan vocabs ...
# num vocabs = 134
# done = 10
# scan vocabs ...
# num vocabs = 120
# done = 10
# scan vocabs ...
# num vocabs = 322
# done = 10
# scan vocabs ...
# num vocabs = 101
# done = 10
# scan vocabs ...
# num vocabs = 201
# done = 10
# scan vocabs ...
# num vocabs = 120
# done = 10
# scan vocabs ...
# num vocabs = 280
# done = 10
# scan vocabs ...
# num vocabs = 223
# done = 10
# scan vocabs ...
# num vocabs = 278
# done = 10
# scan vocabs ...
# num vocabs = 274
# done = 10
# scan vocabs ...
# num vocabs = 275
# done = 10
# scan vocabs ...
# num vocabs = 136
# done = 10
# scan vocabs ...
# num vocabs = 146
# done = 10
# scan vocabs ...
# num vocabs = 180
# done = 10
# scan vocabs ...
# num vocabs = 431
# done = 10
# scan vocabs ...
# num vocabs = 128
# done = 10
# scan vocabs ...
# num vocabs = 144
# done = 10
# scan vocabs ...
# num vocabs = 180
# done = 10
# scan vocabs ...
# num vocabs = 145
# done = 10
# scan vocabs ...
# num vocabs = 149
# done = 10
# scan vocabs ...
# num vocabs = 186
# done = 10
# scan vocabs ...
# num vocabs = 327
# done = 10
# scan vocabs ...
# num vocabs = 274
# done = 10
# scan vocabs ...
# num vocabs = 178
# done = 10
# scan vocabs ...
# num vocabs = 626
# done = 10
# scan vocabs ...
# num vocabs = 248
# done = 10
# scan vocabs ...
# num vocabs = 848
# done = 10
# scan vocabs ...
# num vocabs = 338
# done = 10
# scan vocabs ...
# num vocabs = 114
# done = 10
# scan vocabs ...
# num vocabs = 346
# done = 10
# scan vocabs ...
# num vocabs = 191
# done = 10
# scan vocabs ...
# num vocabs = 321
# done = 10
# scan vocabs ...
# num vocabs = 208
# done = 10
# scan vocabs ...
# num vocabs = 279
# done = 10
# scan vocabs ...
# num vocabs = 251
# done = 10
# scan vocabs ...
# num vocabs = 281
# done = 10
# scan vocabs ...
# num vocabs = 196
# done = 10
# scan vocabs ...
# num vocabs = 121
# done = 10
# scan vocabs ...
# num vocabs = 642
# done = 10
# scan vocabs ...
# num vocabs = 164
# done = 10
# scan vocabs ...
# num vocabs = 228
# done = 10
# scan vocabs ...
# num vocabs = 227
# done = 10
# scan vocabs ...
# num vocabs = 243
# done = 10
# scan vocabs ...
# num vocabs = 209
# done = 10
# scan vocabs ...
# num vocabs = 214
# done = 10
# scan vocabs ...
# num vocabs = 278
# done = 10
# scan vocabs ...
# num vocabs = 164
# done = 10
# scan vocabs ...
# num vocabs = 208
# done = 10
# scan vocabs ...
# num vocabs = 102
# done = 10
# scan vocabs ...
# num vocabs = 313
# done = 10
# scan vocabs ...
# num vocabs = 264
# done = 10
# scan vocabs ...
# num vocabs = 205
# done = 10
# scan vocabs ...
# num vocabs = 348
# done = 10
# scan vocabs ...
# num vocabs = 274
# done = 10
# scan vocabs ...
# num vocabs = 262
# done = 10
# scan vocabs ...
# num vocabs = 181
# done = 10
# scan vocabs ...
# num vocabs = 148
# done = 10
# scan vocabs ...
# num vocabs = 148
# done = 10
# scan vocabs ...
# num vocabs = 433
# done = 10
# scan vocabs ...
# num vocabs = 346
# done = 10
# scan vocabs ...
# num vocabs = 281
# done = 10
# scan vocabs ...
# num vocabs = 122
# done = 10
# scan vocabs ...
# num vocabs = 271
# done = 10
# scan vocabs ...
# num vocabs = 279
# done = 10
# scan vocabs ...
# num vocabs = 134
# done = 10
# scan vocabs ...
# num vocabs = 207
# done = 10
# scan vocabs ...
# num vocabs = 227
# done = 10
# scan vocabs ...
# num vocabs = 198
# done = 10
# scan vocabs ...
# num vocabs = 181
# done = 10
# scan vocabs ...
# num vocabs = 322
# done = 10
# scan vocabs ...
# num vocabs = 196
# done = 10
# scan vocabs ...
# num vocabs = 272
# done = 10
# scan vocabs ...
# num vocabs = 98
# done = 10
# scan vocabs ...
# num vocabs = 291
# done = 10
# scan vocabs ...
# num vocabs = 269
# done = 10
# scan vocabs ...
# num vocabs = 199
# done = 10
# scan vocabs ...
# num vocabs = 161
# done = 10
# scan vocabs ...
# num vocabs = 117
# done = 10
# scan vocabs ...
# num vocabs = 452
# done = 10
# scan vocabs ...
# num vocabs = 243
# done = 10
# scan vocabs ...
# num vocabs = 184
# done = 10
# scan vocabs ...
# num vocabs = 145
# done = 10
# scan vocabs ...
# num vocabs = 271
# done = 10
# scan vocabs ...
# num vocabs = 277
# done = 10
# scan vocabs ...
# num vocabs = 245
# done = 10
# scan vocabs ...
# num vocabs = 488
# done = 10
# scan vocabs ...
# num vocabs = 156
# done = 10
# scan vocabs ...
# num vocabs = 389
# done = 10
# scan vocabs ...
# num vocabs = 177
# done = 10
# scan vocabs ...
# num vocabs = 189
# done = 10
# scan vocabs ...
# num vocabs = 272
# done = 10
# scan vocabs ...
# num vocabs = 192
# done = 10
# scan vocabs ...
# num vocabs = 242
# done = 10
# scan vocabs ...
# num vocabs = 286
# done = 10
# scan vocabs ...
# num vocabs = 162
# done = 10
# scan vocabs ...
# num vocabs = 77
# done = 10
# scan vocabs ...
# num vocabs = 322
# done = 10
# scan vocabs ...
# num vocabs = 284
# done = 10
# scan vocabs ...
# num vocabs = 284
# done = 10
# scan vocabs ...
# num vocabs = 153
# done = 10
# scan vocabs ...
# num vocabs = 124
# done = 10
# scan vocabs ...
# num vocabs = 177
# done = 10
# scan vocabs ...
# num vocabs = 299
# done = 10
# scan vocabs ...
# num vocabs = 425
# done = 10
# scan vocabs ...
# num vocabs = 175
# done = 10
# scan vocabs ...
# num vocabs = 201
# done = 10
# scan vocabs ...
# num vocabs = 179
# done = 10
# scan vocabs ...
# num vocabs = 242
# done = 10
# scan vocabs ...
# num vocabs = 138
# done = 10
# scan vocabs ...
# num vocabs = 119
# done = 10
# scan vocabs ...
# num vocabs = 193
# done = 10
# scan vocabs ...
# num vocabs = 237
# done = 10
# scan vocabs ...
# num vocabs = 144
# done = 10
# scan vocabs ...
# num vocabs = 104
# done = 10
# scan vocabs ...
# num vocabs = 139
# done = 10
# scan vocabs ...
# num vocabs = 523
# done = 10
# scan vocabs ...
# num vocabs = 501
# done = 10
# scan vocabs ...
# num vocabs = 90
# done = 10
# scan vocabs ...
# num vocabs = 246
# done = 10
# scan vocabs ...
# num vocabs = 145
# done = 10
# scan vocabs ...
# num vocabs = 237
# done = 10
# scan vocabs ...
# num vocabs = 101
# done = 10
# scan vocabs ...
# num vocabs = 159
# done = 10
# scan vocabs ...
# num vocabs = 150
# done = 10
# scan vocabs ...
# num vocabs = 105
# done = 10
# scan vocabs ...
# num vocabs = 166
# done = 10
# scan vocabs ...
# num vocabs = 138
# done = 10
# scan vocabs ...
# num vocabs = 251
# done = 10
# scan vocabs ...
# num vocabs = 129
# done = 10
# scan vocabs ...
# num vocabs = 109
# done = 10
# scan vocabs ...
# num vocabs = 99
# done = 10
# scan vocabs ...
# num vocabs = 224
# done = 10
# scan vocabs ...
# num vocabs = 139
# done = 10
# scan vocabs ...
# num vocabs = 100
# done = 10
# scan vocabs ...
# num vocabs = 116
# done = 10
# scan vocabs ...
# num vocabs = 233
# done = 10
# scan vocabs ...
# num vocabs = 294
# done = 10
# scan vocabs ...
# num vocabs = 143
# done = 10
# scan vocabs ...
# num vocabs = 104
# done = 10
# scan vocabs ...
# num vocabs = 191
# done = 10
# scan vocabs ...
# num vocabs = 283
# done = 10
# scan vocabs ...
# num vocabs = 162
# done = 10
# scan vocabs ...
# num vocabs = 237
# done = 10
# scan vocabs ...
# num vocabs = 138
# done = 10
# scan vocabs ...
# num vocabs = 211
# done = 10
# scan vocabs ...
# num vocabs = 101
# done = 10
# scan vocabs ...
# num vocabs = 281
# done = 10
# scan vocabs ...
# num vocabs = 174
# done = 10
# scan vocabs ...
# num vocabs = 147
# done = 10
# scan vocabs ...
# num vocabs = 116
# done = 10
# scan vocabs ...
# num vocabs = 227
# done = 10
# scan vocabs ...
# num vocabs = 137
# done = 10
# scan vocabs ...
# num vocabs = 182
# done = 10
# scan vocabs ...
# num vocabs = 111
# done = 10
# scan vocabs ...
# num vocabs = 107
# done = 10
# scan vocabs ...
# num vocabs = 152
# done = 10
# scan vocabs ...
# num vocabs = 268
# done = 10
# scan vocabs ...
# num vocabs = 80
# done = 10
# scan vocabs ...
# num vocabs = 219
# done = 10
# scan vocabs ...
# num vocabs = 141
# done = 10
# scan vocabs ...
# num vocabs = 102
# done = 10
# scan vocabs ...
# num vocabs = 106
# done = 10
# scan vocabs ...
# num vocabs = 293
# done = 10
# scan vocabs ...
# num vocabs = 122
# done = 10
# scan vocabs ...
# num vocabs = 348
# done = 10
# scan vocabs ...
# num vocabs = 283
# done = 10
# scan vocabs ...
# num vocabs = 295
# done = 10
# scan vocabs ...
# num vocabs = 369
# done = 10
# scan vocabs ...
# num vocabs = 296
# done = 10
# scan vocabs ...
# num vocabs = 150
# done = 10
# scan vocabs ...
# num vocabs = 199
# done = 10
# scan vocabs ...
# num vocabs = 152
# done = 10
# scan vocabs ...
# num vocabs = 90
# done = 10
# scan vocabs ...
# num vocabs = 185
# done = 10
# scan vocabs ...
# num vocabs = 126
# done = 10
# scan vocabs ...
# num vocabs = 135
# done = 10
# scan vocabs ...
# num vocabs = 131
# done = 10
# scan vocabs ...
# num vocabs = 189
# done = 10
# scan vocabs ...
# num vocabs = 178
# done = 10
# scan vocabs ...
# num vocabs = 268
# done = 10
# scan vocabs ...
# num vocabs = 134
# done = 10
# scan vocabs ...
# num vocabs = 133
# done = 10
# scan vocabs ...
# num vocabs = 277
# done = 10
# scan vocabs ...
# num vocabs = 443
# done = 10
# scan vocabs ...
# num vocabs = 134
# done = 10
# scan vocabs ...
# num vocabs = 96
# done = 10
# scan vocabs ...
# num vocabs = 349
# done = 10
# scan vocabs ...
# num vocabs = 527
# done = 10
# scan vocabs ...
# num vocabs = 225
# done = 10
# scan vocabs ...
# num vocabs = 112
# done = 10
# scan vocabs ...
# num vocabs = 192
# done = 10
# scan vocabs ...
# num vocabs = 209
# done = 10
# scan vocabs ...
# num vocabs = 182
# done = 10
# scan vocabs ...
# num vocabs = 151
# done = 10
# scan vocabs ...
# num vocabs = 126
# done = 10
# scan vocabs ...
# num vocabs = 137
# done = 10
# scan vocabs ...
# num vocabs = 168
# done = 10
# scan vocabs ...
# num vocabs = 150
# done = 10
# scan vocabs ...
# num vocabs = 258
# done = 10
# scan vocabs ...
# num vocabs = 227
# done = 10
# scan vocabs ...
# num vocabs = 117
# done = 10
# scan vocabs ...
# num vocabs = 112
# done = 10
# scan vocabs ...
# num vocabs = 196
# done = 10
# scan vocabs ...
# num vocabs = 92
# done = 10
# scan vocabs ...
# num vocabs = 226
# done = 10
# scan vocabs ...
# num vocabs = 101
# done = 10
# scan vocabs ...
# num vocabs = 120
# done = 10
# scan vocabs ...
# num vocabs = 90
# done = 10
# scan vocabs ...
# num vocabs = 650
# done = 10
# scan vocabs ...
# num vocabs = 172
# done = 10
# scan vocabs ...
# num vocabs = 175
# done = 10
# scan vocabs ...
# num vocabs = 212
# done = 10
# scan vocabs ...
# num vocabs = 267
# done = 10
# scan vocabs ...
# num vocabs = 239
# done = 10
# scan vocabs ...
# num vocabs = 157
# done = 10
# scan vocabs ...
# num vocabs = 76
# done = 10
# scan vocabs ...
# num vocabs = 139
# done = 10
# scan vocabs ...
# num vocabs = 102
# done = 10
# scan vocabs ...
# num vocabs = 156
# done = 10
# scan vocabs ...
# num vocabs = 160
# done = 10
# scan vocabs ...
# num vocabs = 419
# done = 10
# scan vocabs ...
# num vocabs = 198
# done = 10
# scan vocabs ...
# num vocabs = 151
# done = 10
# scan vocabs ...
# num vocabs = 147
# done = 10
# scan vocabs ...
# num vocabs = 259
# done = 10
# scan vocabs ...
# num vocabs = 163
# done = 10
# scan vocabs ...
# num vocabs = 202
# done = 10
# scan vocabs ...
# num vocabs = 534
# done = 10
# scan vocabs ...
# num vocabs = 87
# done = 10
# scan vocabs ...
# num vocabs = 153
# done = 10
# scan vocabs ...
# num vocabs = 102
# done = 10
# scan vocabs ...
# num vocabs = 189
# done = 10
# scan vocabs ...
# num vocabs = 169
# done = 10
# scan vocabs ...
# num vocabs = 123
# done = 10
# scan vocabs ...
# num vocabs = 188
# done = 10
# scan vocabs ...
# num vocabs = 143
# done = 10
# scan vocabs ...
# num vocabs = 135
# done = 10
# scan vocabs ...
# num vocabs = 137
# done = 10
# scan vocabs ...
# num vocabs = 251
# done = 10
# scan vocabs ...
# num vocabs = 107
# done = 10
# scan vocabs ...
# num vocabs = 193
# done = 10
# scan vocabs ...
# num vocabs = 134
# done = 10
# scan vocabs ...
# num vocabs = 156
# done = 10
# scan vocabs ...
# num vocabs = 65
# done = 10
# scan vocabs ...
# num vocabs = 56
# done = 10
# scan vocabs ...
# num vocabs = 82
# done = 10
# scan vocabs ...
# num vocabs = 118
# done = 10
# scan vocabs ...
# num vocabs = 56
# done = 10
# scan vocabs ...
# num vocabs = 57
# done = 10
# scan vocabs ...
# num vocabs = 82
# done = 10
# scan vocabs ...
# num vocabs = 53
# done = 10
# scan vocabs ...
# num vocabs = 116
# done = 10
# scan vocabs ...
# num vocabs = 162
# done = 10
# scan vocabs ...
# num vocabs = 109
# done = 10
# scan vocabs ...
# num vocabs = 697
# done = 10
# scan vocabs ...
# num vocabs = 266
# done = 10
# scan vocabs ...
# num vocabs = 167
# done = 10
# scan vocabs ...
# num vocabs = 88
# done = 10
# scan vocabs ...
# num vocabs = 356
# done = 10
# scan vocabs ...
# num vocabs = 153
# done = 10
# scan vocabs ...
# num vocabs = 170
# done = 10
# scan vocabs ...
# num vocabs = 170
# done = 10
# scan vocabs ...
# num vocabs = 113
# done = 10
# scan vocabs ...
# num vocabs = 338
# done = 10
# scan vocabs ...
# num vocabs = 55
# done = 10
# scan vocabs ...
# num vocabs = 145
# done = 10
# scan vocabs ...
# num vocabs = 46
# done = 10
# scan vocabs ...
# num vocabs = 156
# done = 10
# scan vocabs ...
# num vocabs = 268
# done = 10
# scan vocabs ...
# num vocabs = 206
# done = 10
# scan vocabs ...
# num vocabs = 210
# done = 10
# scan vocabs ...
# num vocabs = 155
# done = 10
# scan vocabs ...
# num vocabs = 210
# done = 10
# scan vocabs ...
# num vocabs = 102
# done = 10
# scan vocabs ...
# num vocabs = 82
# done = 10
# scan vocabs ...
# num vocabs = 119
# done = 10
# scan vocabs ...
# num vocabs = 210
# done = 10
# scan vocabs ...
# num vocabs = 59
# done = 10
# scan vocabs ...
# num vocabs = 881
# done = 10
# scan vocabs ...
# num vocabs = 117
# done = 10
# scan vocabs ...
# num vocabs = 87
# done = 10
# scan vocabs ...
# num vocabs = 100
# done = 10
# scan vocabs ...
# num vocabs = 219
# done = 10
# scan vocabs ...
# num vocabs = 74
# done = 10
# scan vocabs ...
# num vocabs = 126
# done = 10
# scan vocabs ...
# num vocabs = 60
# done = 10
# scan vocabs ...
# num vocabs = 207
# done = 10
# scan vocabs ...
# num vocabs = 192
# done = 10
# scan vocabs ...
# num vocabs = 77
# done = 10
# scan vocabs ...
# num vocabs = 110
# done = 10
# scan vocabs ...
# num vocabs = 426
# done = 10
# scan vocabs ...
# num vocabs = 69
# done = 10
# scan vocabs ...
# num vocabs = 112
# done = 10
# scan vocabs ...
# num vocabs = 68
# done = 10
# scan vocabs ...
# num vocabs = 56
# done = 10
# scan vocabs ...
# num vocabs = 59
# done = 10
# scan vocabs ...
# num vocabs = 214
# done = 10
# scan vocabs ...
# num vocabs = 86
# done = 10
# scan vocabs ...
# num vocabs = 106
# done = 10
# scan vocabs ...
# num vocabs = 162
# done = 10
# scan vocabs ...
# num vocabs = 104
# done = 10
# scan vocabs ...
# num vocabs = 71
# done = 10
# scan vocabs ...
# num vocabs = 100
# done = 10
# scan vocabs ...
# num vocabs = 72
# done = 10
# scan vocabs ...
# num vocabs = 89
# done = 10
# scan vocabs ...
# num vocabs = 113
# done = 10
# scan vocabs ...
# num vocabs = 226
# done = 10
# scan vocabs ...
# num vocabs = 63
# done = 10
# scan vocabs ...
# num vocabs = 163
# done = 10
# scan vocabs ...
# num vocabs = 269
# done = 10
# scan vocabs ...
# num vocabs = 83
# done = 10
# scan vocabs ...
# num vocabs = 38
# done = 10
# scan vocabs ...
# num vocabs = 138
# done = 10
# scan vocabs ...
# num vocabs = 55
# done = 10
# scan vocabs ...
# num vocabs = 58
# done = 10
# scan vocabs ...
# num vocabs = 238
# done = 10
# scan vocabs ...
# num vocabs = 92
# done = 10
# scan vocabs ...
# num vocabs = 655
# done = 10
# scan vocabs ...
# num vocabs = 180
# done = 10
# scan vocabs ...
# num vocabs = 134
# done = 10
# scan vocabs ...
# num vocabs = 62
# done = 10
# scan vocabs ...
# num vocabs = 65
# done = 10
# scan vocabs ...
# num vocabs = 203
# done = 10
# scan vocabs ...
# num vocabs = 127
# done = 10
# scan vocabs ...
# num vocabs = 82
# done = 10
# scan vocabs ...
# num vocabs = 84
# done = 10
# scan vocabs ...
# num vocabs = 196
# done = 10
# scan vocabs ...
# num vocabs = 159
# done = 10
# scan vocabs ...
# num vocabs = 103
# done = 10
# scan vocabs ...
# num vocabs = 49
# done = 10
# scan vocabs ...
# num vocabs = 184
# done = 10
# scan vocabs ...
# num vocabs = 58
# done = 10
# scan vocabs ...
# num vocabs = 89
# done = 10
# scan vocabs ...
# num vocabs = 72
# done = 10 Early stopped.
# scan vocabs ...
# num vocabs = 122
# done = 10
# scan vocabs ...
# num vocabs = 170
# done = 10
# scan vocabs ...
# num vocabs = 110
# done = 10
# scan vocabs ...
# num vocabs = 92
# done = 10
# scan vocabs ...
# num vocabs = 225
# done = 10
# scan vocabs ...
# num vocabs = 120
# done = 10
# scan vocabs ...
# num vocabs = 64
# done = 10
# scan vocabs ...
# num vocabs = 141
# done = 10
# scan vocabs ...
# num vocabs = 86
# done = 10
# scan vocabs ...
# num vocabs = 108
# done = 10
# scan vocabs ...
# num vocabs = 170
# done = 10
# scan vocabs ...
# num vocabs = 54
# done = 10
# scan vocabs ...
# num vocabs = 69
# done = 10
# scan vocabs ...
# num vocabs = 153
# done = 10
# scan vocabs ...
# num vocabs = 169
# done = 10
# scan vocabs ...
# num vocabs = 147
# done = 10
# scan vocabs ...
# num vocabs = 138
# done = 10
# scan vocabs ...
# num vocabs = 54
# done = 10
# scan vocabs ...
# num vocabs = 164
# done = 10
# scan vocabs ...
# num vocabs = 112
# done = 10
# scan vocabs ...
# num vocabs = 122
# done = 10
# scan vocabs ...
# num vocabs = 63
# done = 10
# scan vocabs ...
# num vocabs = 106
# done = 10
# scan vocabs ...
# num vocabs = 223
# done = 10
# scan vocabs ...
# num vocabs = 217
# done = 10
# scan vocabs ...
# num vocabs = 57
# done = 10
# scan vocabs ...
# num vocabs = 89
# done = 10
# scan vocabs ...
# num vocabs = 82
# done = 10
# scan vocabs ...
# num vocabs = 194
# done = 10
# scan vocabs ...
# num vocabs = 64
# done = 10
# scan vocabs ...
# num vocabs = 79
# done = 10
# scan vocabs ...
# num vocabs = 78
# done = 10
# scan vocabs ...
# num vocabs = 62
# done = 10
# scan vocabs ...
# num vocabs = 62
# done = 10
# scan vocabs ...
# num vocabs = 402
# done = 10
# scan vocabs ...
# num vocabs = 166
# done = 10
# scan vocabs ...
# num vocabs = 59
# done = 10
# scan vocabs ...
# num vocabs = 61
# done = 10
# scan vocabs ...
# num vocabs = 175
# done = 10
# scan vocabs ...
# num vocabs = 139
# done = 10
# scan vocabs ...
# num vocabs = 125
# done = 10
# scan vocabs ...
# num vocabs = 212
# done = 10
# scan vocabs ...
# num vocabs = 60
# done = 10
# scan vocabs ...
# num vocabs = 333
# done = 10
# scan vocabs ...
# num vocabs = 85
# done = 10
# scan vocabs ...
# num vocabs = 63
# done = 10
# scan vocabs ...
# num vocabs = 198
# done = 10
# scan vocabs ...
# num vocabs = 60
# done = 10
# scan vocabs ...
# num vocabs = 87
# done = 10
# scan vocabs ...
# num vocabs = 209
# done = 10
# scan vocabs ...
# num vocabs = 54
# done = 10
# scan vocabs ...
# num vocabs = 130
# done = 10
# scan vocabs ...
# num vocabs = 90
# done = 10
# scan vocabs ...
# num vocabs = 181
# done = 10
# scan vocabs ...
# num vocabs = 121
# done = 10
# scan vocabs ...
# num vocabs = 241
# done = 10
# scan vocabs ...
# num vocabs = 222
# done = 10
# scan vocabs ...
# num vocabs = 73
# done = 10
# scan vocabs ...
# num vocabs = 34
# done = 10
# scan vocabs ...
# num vocabs = 68
# done = 10
# scan vocabs ...
# num vocabs = 211
# done = 10
# scan vocabs ...
# num vocabs = 105
# done = 10
# scan vocabs ...
# num vocabs = 36
# done = 10
# scan vocabs ...
# num vocabs = 98
# done = 10
# scan vocabs ...
# num vocabs = 58
# done = 10
# scan vocabs ...
# num vocabs = 120
# done = 10
# scan vocabs ...
# num vocabs = 123
# done = 10
# scan vocabs ...
# num vocabs = 206
# done = 10
# scan vocabs ...
# num vocabs = 128
# done = 10
# scan vocabs ...
# num vocabs = 136
# done = 10
# scan vocabs ...
# num vocabs = 76
# done = 10
# scan vocabs ...
# num vocabs = 109
# done = 10
# scan vocabs ...
# num vocabs = 186
# done = 10
# scan vocabs ...
# num vocabs = 151
# done = 10
# scan vocabs ...
# num vocabs = 161
# done = 10
# scan vocabs ...
# num vocabs = 86
# done = 10
# scan vocabs ...
# num vocabs = 52
# done = 10
# scan vocabs ...
# num vocabs = 128
# done = 10
# scan vocabs ...
# num vocabs = 40
# done = 10
# scan vocabs ...
# num vocabs = 164
# done = 10
# scan vocabs ...
# num vocabs = 216
# done = 10
# scan vocabs ...
# num vocabs = 89
# done = 10
# scan vocabs ...
# num vocabs = 90
# done = 10
# scan vocabs ...
# num vocabs = 179
# done = 10
# scan vocabs ...
# num vocabs = 46
# done = 10
# scan vocabs ...
# num vocabs = 73
# done = 10
# scan vocabs ...
# num vocabs = 133
# done = 10
# scan vocabs ...
# num vocabs = 62
# done = 10
# scan vocabs ...
# num vocabs = 114
# done = 10
# scan vocabs ...
# num vocabs = 150
# done = 10
# scan vocabs ...
# num vocabs = 135
# done = 10
# scan vocabs ...
# num vocabs = 133
# done = 10
# scan vocabs ...
# num vocabs = 246
# done = 10
# scan vocabs ...
# num vocabs = 67
# done = 10
# scan vocabs ...
# num vocabs = 98
# done = 10
# scan vocabs ...
# num vocabs = 193
# done = 10
# scan vocabs ...
# num vocabs = 57
# done = 10
# scan vocabs ...
# num vocabs = 105
# done = 10
# scan vocabs ...
# num vocabs = 479
# done = 10
# scan vocabs ...
# num vocabs = 71
# done = 10
# scan vocabs ...
# num vocabs = 132
# done = 10
# scan vocabs ...
# num vocabs = 215
# done = 10
# scan vocabs ...
# num vocabs = 129
# done = 10
# scan vocabs ...
# num vocabs = 85
# done = 10
# scan vocabs ...
# num vocabs = 82
# done = 10
# scan vocabs ...
# num vocabs = 175
# done = 10
# scan vocabs ...
# num vocabs = 192
# done = 10
# scan vocabs ...
# num vocabs = 153
# done = 10
# scan vocabs ...
# num vocabs = 171
# done = 10
# scan vocabs ...
# num vocabs = 214
# done = 10
# scan vocabs ...
# num vocabs = 101
# done = 10
# scan vocabs ...
# num vocabs = 111
# done = 10
# scan vocabs ...
# num vocabs = 91
# done = 10
# scan vocabs ...
# num vocabs = 77
# done = 10
# scan vocabs ...
# num vocabs = 94
# done = 10
# scan vocabs ...
# num vocabs = 23
# done = 10
# scan vocabs ...
# num vocabs = 43
# done = 10
# scan vocabs ...
# num vocabs = 104
# done = 10
# scan vocabs ...
# num vocabs = 24
# done = 10
# scan vocabs ...
# num vocabs = 33
# done = 10
# scan vocabs ...
# num vocabs = 100
# done = 10
# scan vocabs ...
# num vocabs = 120
# done = 10
# scan vocabs ...
# num vocabs = 48
# done = 10
# scan vocabs ...
# num vocabs = 67
# done = 10
# scan vocabs ...
# num vocabs = 18
# done = 8 Early stopped.
# scan vocabs ...
# num vocabs = 140
# done = 10
# scan vocabs ...
# num vocabs = 117
# done = 10
# scan vocabs ...
# num vocabs = 66
# done = 10
# scan vocabs ...
# num vocabs = 128
# done = 10
# scan vocabs ...
# num vocabs = 31
# done = 10
# scan vocabs ...
# num vocabs = 3
# done = 1 Early stopped.
# scan vocabs ...
# num vocabs = 80
# done = 10
# scan vocabs ...
# num vocabs = 85
# done = 10
# scan vocabs ...
# num vocabs = 45
# done = 10
# scan vocabs ...
# num vocabs = 92
# done = 10
# scan vocabs ...
# num vocabs = 279
# done = 10
# scan vocabs ...
# num vocabs = 30
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 55
# done = 10
# scan vocabs ...
# num vocabs = 47
# done = 10
# scan vocabs ...
# num vocabs = 28
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 29
# done = 10
# scan vocabs ...
# num vocabs = 81
# done = 10
# scan vocabs ...
# num vocabs = 81
# done = 10
# scan vocabs ...
# num vocabs = 173
# done = 10
# scan vocabs ...
# num vocabs = 144
# done = 10
# scan vocabs ...
# num vocabs = 73
# done = 10
# scan vocabs ...
# num vocabs = 90
# done = 10
# scan vocabs ...
# num vocabs = 95
# done = 10
# scan vocabs ...
# num vocabs = 51
# done = 10
# scan vocabs ...
# num vocabs = 33
# done = 10
# scan vocabs ...
# num vocabs = 79
# done = 10
# scan vocabs ...
# num vocabs = 26
# done = 10
# scan vocabs ...
# num vocabs = 31
# done = 10
# scan vocabs ...
# num vocabs = 32
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 32
# done = 10
# scan vocabs ...
# num vocabs = 49
# done = 10
# scan vocabs ...
# num vocabs = 187
# done = 10
# scan vocabs ...
# num vocabs = 39
# done = 10
# scan vocabs ...
# num vocabs = 65
# done = 10
# scan vocabs ...
# num vocabs = 33
# done = 10
# scan vocabs ...
# num vocabs = 56
# done = 10
# scan vocabs ...
# num vocabs = 153
# done = 10
# scan vocabs ...
# num vocabs = 76
# done = 10
# scan vocabs ...
# num vocabs = 69
# done = 10
# scan vocabs ...
# num vocabs = 51
# done = 10
# scan vocabs ...
# num vocabs = 108
# done = 10
# scan vocabs ...
# num vocabs = 84
# done = 10
# scan vocabs ...
# num vocabs = 28
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 33
# done = 10
# scan vocabs ...
# num vocabs = 250
# done = 10
# scan vocabs ...
# num vocabs = 54
# done = 10
# scan vocabs ...
# num vocabs = 138
# done = 10
# scan vocabs ...
# num vocabs = 70
# done = 10
# scan vocabs ...
# num vocabs = 103
# done = 10
# scan vocabs ...
# num vocabs = 58
# done = 10
# scan vocabs ...
# num vocabs = 34
# done = 10
# scan vocabs ...
# num vocabs = 25
# done = 10
# scan vocabs ...
# num vocabs = 79
# done = 10
# scan vocabs ...
# num vocabs = 48
# done = 10
# scan vocabs ...
# num vocabs = 53
# done = 10
# scan vocabs ...
# num vocabs = 74
# done = 10
# scan vocabs ...
# num vocabs = 33
# done = 10
# scan vocabs ...
# num vocabs = 73
# done = 10
# scan vocabs ...
# num vocabs = 88
# done = 10
# scan vocabs ...
# num vocabs = 43
# done = 10
# scan vocabs ...
# num vocabs = 160
# done = 10
# scan vocabs ...
# num vocabs = 53
# done = 10
# scan vocabs ...
# num vocabs = 41
# done = 10
# scan vocabs ...
# num vocabs = 27
# done = 10
# scan vocabs ...
# num vocabs = 38
# done = 10
# scan vocabs ...
# num vocabs = 27
# done = 10
# scan vocabs ...
# num vocabs = 89
# done = 10
# scan vocabs ...
# num vocabs = 48
# done = 10
# scan vocabs ...
# num vocabs = 28
# done = 10
# scan vocabs ...
# num vocabs = 56
# done = 10
# scan vocabs ...
# num vocabs = 52
# done = 10
# scan vocabs ...
# num vocabs = 64
# done = 10
# scan vocabs ...
# num vocabs = 129
# done = 10
# scan vocabs ...
# num vocabs = 29
# done = 10
# scan vocabs ...
# num vocabs = 61
# done = 10
# scan vocabs ...
# num vocabs = 35
# done = 10
# scan vocabs ...
# num vocabs = 173
# done = 10
# scan vocabs ...
# num vocabs = 101
# done = 10
# scan vocabs ...
# num vocabs = 30
# done = 10
# scan vocabs ...
# num vocabs = 55
# done = 10
# scan vocabs ...
# num vocabs = 52
# done = 10
# scan vocabs ...
# num vocabs = 63
# done = 10
# scan vocabs ...
# num vocabs = 73
# done = 10
# scan vocabs ...
# num vocabs = 35
# done = 10
# scan vocabs ...
# num vocabs = 102
# done = 10
# scan vocabs ...
# num vocabs = 33
# done = 10
# scan vocabs ...
# num vocabs = 50
# done = 10
# scan vocabs ...
# num vocabs = 54
# done = 10
# scan vocabs ...
# num vocabs = 46
# done = 10
# scan vocabs ...
# num vocabs = 52
# done = 10
# scan vocabs ...
# num vocabs = 22
# done = 10
# scan vocabs ...
# num vocabs = 53
# done = 10
# scan vocabs ...
# num vocabs = 75
# done = 10
# scan vocabs ...
# num vocabs = 22
# done = 10
# scan vocabs ...
# num vocabs = 99
# done = 10
# scan vocabs ...
# num vocabs = 61
# done = 10
# scan vocabs ...
# num vocabs = 167
# done = 10
# scan vocabs ...
# num vocabs = 96
# done = 10
# scan vocabs ...
# num vocabs = 198
# done = 10
# scan vocabs ...
# num vocabs = 20
# done = 8 Early stopped.
# scan vocabs ...
# num vocabs = 96
# done = 10
# scan vocabs ...
# num vocabs = 39
# done = 10
# scan vocabs ...
# num vocabs = 32
# done = 10
# scan vocabs ...
# num vocabs = 51
# done = 10
# scan vocabs ...
# num vocabs = 26
# done = 10
# scan vocabs ...
# num vocabs = 79
# done = 10
# scan vocabs ...
# num vocabs = 45
# done = 10
# scan vocabs ...
# num vocabs = 69
# done = 10
# scan vocabs ...
# num vocabs = 74
# done = 10
# scan vocabs ...
# num vocabs = 99
# done = 10
# scan vocabs ...
# num vocabs = 166
# done = 10
# scan vocabs ...
# num vocabs = 60
# done = 10
# scan vocabs ...
# num vocabs = 113
# done = 10
# scan vocabs ...
# num vocabs = 30
# done = 10
# scan vocabs ...
# num vocabs = 43
# done = 10
# scan vocabs ...
# num vocabs = 20
# done = 10
# scan vocabs ...
# num vocabs = 237
# done = 10
# scan vocabs ...
# num vocabs = 63
# done = 10
# scan vocabs ...
# num vocabs = 43
# done = 10
# scan vocabs ...
# num vocabs = 74
# done = 10
# scan vocabs ...
# num vocabs = 43
# done = 10
# scan vocabs ...
# num vocabs = 56
# done = 10
# scan vocabs ...
# num vocabs = 27
# done = 10
# scan vocabs ...
# num vocabs = 68
# done = 10
# scan vocabs ...
# num vocabs = 40
# done = 10
# scan vocabs ...
# num vocabs = 51
# done = 10
# scan vocabs ...
# num vocabs = 93
# done = 10
# scan vocabs ...
# num vocabs = 70
# done = 10
# scan vocabs ...
# num vocabs = 36
# done = 10
# scan vocabs ...
# num vocabs = 123
# done = 10
# scan vocabs ...
# num vocabs = 149
# done = 10
# scan vocabs ...
# num vocabs = 30
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 26
# done = 10
# scan vocabs ...
# num vocabs = 65
# done = 10
# scan vocabs ...
# num vocabs = 67
# done = 10
# scan vocabs ...
# num vocabs = 31
# done = 10
# scan vocabs ...
# num vocabs = 24
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 63
# done = 10
# scan vocabs ...
# num vocabs = 74
# done = 10
# scan vocabs ...
# num vocabs = 74
# done = 10
# scan vocabs ...
# num vocabs = 47
# done = 10
# scan vocabs ...
# num vocabs = 88
# done = 10
# scan vocabs ...
# num vocabs = 52
# done = 10
# scan vocabs ...
# num vocabs = 28
# done = 10
# scan vocabs ...
# num vocabs = 77
# done = 10
# scan vocabs ...
# num vocabs = 67
# done = 10
# scan vocabs ...
# num vocabs = 34
# done = 10
# scan vocabs ...
# num vocabs = 52
# done = 10
# scan vocabs ...
# num vocabs = 45
# done = 10
# scan vocabs ...
# num vocabs = 29
# done = 10
# scan vocabs ...
# num vocabs = 31
# done = 10
# scan vocabs ...
# num vocabs = 218
# done = 10
# scan vocabs ...
# num vocabs = 26
# done = 10
# scan vocabs ...
# num vocabs = 32
# done = 10
# scan vocabs ...
# num vocabs = 43
# done = 10
# scan vocabs ...
# num vocabs = 35
# done = 10
# scan vocabs ...
# num vocabs = 141
# done = 10
# scan vocabs ...
# num vocabs = 350
# done = 10
# scan vocabs ...
# num vocabs = 75
# done = 10
# scan vocabs ...
# num vocabs = 34
# done = 10
# scan vocabs ...
# num vocabs = 104
# done = 10
# scan vocabs ...
# num vocabs = 60
# done = 10
# scan vocabs ...
# num vocabs = 106
# done = 10
# scan vocabs ...
# num vocabs = 47
# done = 10
# scan vocabs ...
# num vocabs = 162
# done = 10
# scan vocabs ...
# num vocabs = 71
# done = 10
# scan vocabs ...
# num vocabs = 41
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 27
# done = 10
# scan vocabs ...
# num vocabs = 83
# done = 10
# scan vocabs ...
# num vocabs = 211
# done = 10
# scan vocabs ...
# num vocabs = 109
# done = 10
# scan vocabs ...
# num vocabs = 44
# done = 10
# scan vocabs ...
# num vocabs = 85
# done = 10
# scan vocabs ...
# num vocabs = 60
# done = 10
# scan vocabs ...
# num vocabs = 30
# done = 10
# scan vocabs ...
# num vocabs = 40
# done = 10
# scan vocabs ...
# num vocabs = 62
# done = 10
# scan vocabs ...
# num vocabs = 30
# done = 10
# scan vocabs ...
# num vocabs = 35
# done = 10
# scan vocabs ...
# num vocabs = 106
# done = 10
# scan vocabs ...
# num vocabs = 41
# done = 10
# scan vocabs ...
# num vocabs = 74
# done = 10
# scan vocabs ...
# num vocabs = 79
# done = 10
# scan vocabs ...
# num vocabs = 47
# done = 10
# scan vocabs ...
# num vocabs = 126
# done = 10
# scan vocabs ...
# num vocabs = 71
# done = 10
# scan vocabs ...
# num vocabs = 72
# done = 10
# scan vocabs ...
# num vocabs = 46
# done = 10
# scan vocabs ...
# num vocabs = 21
# done = 10 Early stopped.
# scan vocabs ...
# num vocabs = 39
# done = 10
# scan vocabs ...
# num vocabs = 42
# done = 10
# scan vocabs ...
# num vocabs = 74
# done = 10
# scan vocabs ...
# num vocabs = 25
# done = 10
# scan vocabs ...
# num vocabs = 62
# done = 10
# scan vocabs ...
# num vocabs = 125
# done = 10
# scan vocabs ...
# num vocabs = 114
# done = 10
# scan vocabs ...
# num vocabs = 106
# done = 10
# scan vocabs ...
# num vocabs = 34
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 139
# done = 10
# scan vocabs ...
# num vocabs = 26
# done = 10
# scan vocabs ...
# num vocabs = 112
# done = 10
# scan vocabs ...
# num vocabs = 149
# done = 10
# scan vocabs ...
# num vocabs = 76
# done = 10
# scan vocabs ...
# num vocabs = 80
# done = 10
# scan vocabs ...
# num vocabs = 40
# done = 10
# scan vocabs ...
# num vocabs = 55
# done = 10
# scan vocabs ...
# num vocabs = 157
# done = 10
# scan vocabs ...
# num vocabs = 135
# done = 10
# scan vocabs ...
# num vocabs = 64
# done = 10
# scan vocabs ...
# num vocabs = 113
# done = 10
# scan vocabs ...
# num vocabs = 49
# done = 10
# scan vocabs ...
# num vocabs = 41
# done = 10
# scan vocabs ...
# num vocabs = 75
# done = 10
# scan vocabs ...
# num vocabs = 50
# done = 10
# scan vocabs ...
# num vocabs = 158
# done = 10
# scan vocabs ...
# num vocabs = 67
# done = 10
# scan vocabs ...
# num vocabs = 86
# done = 10
# scan vocabs ...
# num vocabs = 63
# done = 10
# scan vocabs ...
# num vocabs = 27
# done = 10
# scan vocabs ...
# num vocabs = 166
# done = 10
# scan vocabs ...
# num vocabs = 33
# done = 10
# scan vocabs ...
# num vocabs = 28
# done = 10
# scan vocabs ...
# num vocabs = 78
# done = 10
# scan vocabs ...
# num vocabs = 28
# done = 10
# scan vocabs ...
# num vocabs = 43
# done = 10
# scan vocabs ...
# num vocabs = 48
# done = 10
# scan vocabs ...
# num vocabs = 112
# done = 10
# scan vocabs ...
# num vocabs = 336
# done = 10
# scan vocabs ...
# num vocabs = 30
# done = 10
# scan vocabs ...
# num vocabs = 47
# done = 10
# scan vocabs ...
# num vocabs = 112
# done = 10
# scan vocabs ...
# num vocabs = 227
# done = 10
# scan vocabs ...
# num vocabs = 193
# done = 10
# scan vocabs ...
# num vocabs = 50
# done = 10
# scan vocabs ...
# num vocabs = 54
# done = 10
# scan vocabs ...
# num vocabs = 31
# done = 10
# scan vocabs ...
# num vocabs = 24
# done = 10
# scan vocabs ...
# num vocabs = 76
# done = 10
# scan vocabs ...
# num vocabs = 27
# done = 10
# scan vocabs ...
# num vocabs = 43
# done = 10
# scan vocabs ...
# num vocabs = 7
# done = 1 Early stopped.
# scan vocabs ...
# num vocabs = 139
# done = 10
# scan vocabs ...
# num vocabs = 38
# done = 10
# scan vocabs ...
# num vocabs = 95
# done = 10
# scan vocabs ...
# num vocabs = 37
# done = 10
# scan vocabs ...
# num vocabs = 46
# done = 10 Early stopped.
# scan vocabs ...
# num vocabs = 24
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 34
# done = 10
# scan vocabs ...
# num vocabs = 32
# done = 10
# scan vocabs ...
# num vocabs = 30
# done = 10
# scan vocabs ...
# num vocabs = 83
# done = 10
# scan vocabs ...
# num vocabs = 93
# done = 10
# scan vocabs ...
# num vocabs = 54
# done = 10
# scan vocabs ...
# num vocabs = 6
# done = 1 Early stopped.
# scan vocabs ...
# num vocabs = 39
# done = 10
# scan vocabs ...
# num vocabs = 78
# done = 10
# scan vocabs ...
# num vocabs = 38
# done = 10
# scan vocabs ...
# num vocabs = 26
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 37
# done = 9 Early stopped.
# scan vocabs ...
# num vocabs = 30
# done = 10
# scan vocabs ...
# num vocabs = 174
# done = 10

# %%
kr_rev[kr_rev[]'상품명']

# %%
df_rev.at[3642, 'most_review'] = ["좋아요"]

# %%
# column 두개만 뽑아보기
df_22 = df_rev[['상품명', 'most_review']]
df_22.to_excel("keyword_per_product.xlsx")

# %%
print(df_22.iloc[407]['most_review'])
# Out:
# ['배송', '가성비', '소파', '만족', '스툴']

# %%
df_prod = pd.read_excel("product_data_full.xlsx")
print(df_prod.shape)
df_prod.head(3)
# Out:
# (3596, 21)
#   product_ID                                     상품명  product_price  \
# 0  Product_0            디퓨저 리필액 200ml 1+1+1+1 + 캔들증정          14900
# 1  Product_1                       줄무늬 글라스 유리병 2size           2890
# 2  Product_2  회전목마캔들 메리고라운드 오브제캔들 디자인 향초 필라왁스 인테리어소품          15800
#
#                                   Product_Url  대분류 대분류_1  중분류 중분류_1 중분류_2  \
# 0  https://ohou.se/productions/423747/selling  홈데코    조명  디퓨져   디퓨져   NaN
# 1   https://ohou.se/productions/81677/selling  홈데코    조명  플라워    식물   NaN
# 2  https://ohou.se/productions/571494/selling  홈데코    조명   캔들   디퓨져   NaN
#
#    소분류  ... 소분류_2     brand                  Thema_G  리뷰수   총점      별점평균  \
# 0  디퓨져  ...   NaN      코코도르             ['Romantic']  496  4.7  4.686895
# 1   화병  ...   NaN       코제트  ['Romantic', 'Antique']  982  4.7  4.868432
# 2   캔들  ...   NaN  F5NATURE             ['Romantic']    4  5.0  5.000000
#
#         내구성        가격       디자인        배송
# 0  4.725806  4.649194  4.661290  4.677419
# 1  4.831976  4.891039  4.874745  4.861507
# 2  5.000000  5.000000  5.000000  5.000000
#
# [3 rows x 21 columns]

# %%
df_rev.columns = ['상품명', 'count', 'review']
df_rev = df_rev[['상품명', 'review']]
df_rev.head(2)
# Out:
#                        상품명                                             review
# 0     선데이 러그 7size 4colors  [너무 좋네요 선배가 와서 양념치킨 먹다가 바로 흘림 상놈, 배송도 엄청 빨리 왔고...
# 1  순수원목 선반장 4colors (가로2단)  [여기서 날파리가많이나왔어욥왤까여, 이 가격에 이렇게 예뿌다니 진짜 맘에 들어용 품...

# %% [markdown]
# ### 기존 35nn개 상품 dataframe과 top5 리뷰데이터 dataframe 합치기

# %%
df_prod = df_prod.merge(df_rev, on='상품명')
print(df_prod.shape)
df_prod.sample(5)
# Out:
# (3596, 22)
#         product_ID                                     상품명  product_price  \
# 2204  Product_2204                          퍼블릭 원목 접시꽂이 6칸           5700
# 393    Product_393                             트리 오너먼트 19종           2900
# 82      Product_82       원프레드화이트 쇼파커버 (거실러그, 블랭킷, 다용도 패브릭)          34900
# 2298  Product_2298         뮤즈 고밀도 바이오워싱 순면 호텔식 차렵이불 세트 S/Q         117000
# 587    Product_587  [쿠폰할인][단독] 아만다 시크릿수납 원목 화장대 1000(스툴포함)         149000
#
#                                      Product_Url  대분류 대분류_1    중분류 중분류_1  \
# 2204  https://ohou.se/productions/381625/selling   주방   NaN   주방수납    정리
# 393   https://ohou.se/productions/175443/selling  홈데코    조명  크리스마스   NaN
# 82    https://ohou.se/productions/106089/selling  패브릭   NaN   홈패브릭   NaN
# 2298  https://ohou.se/productions/346431/selling  패브릭   NaN     침구   NaN
# 587   https://ohou.se/productions/315517/selling   가구   NaN   침실가구   NaN
#
#      중분류_2   소분류  ...    brand                            Thema_G   리뷰수   총점  \
# 2204   NaN  주방선반  ...     키친몰링                         ['Modern']    34  4.5
# 393    NaN    트리  ...      아웃팅                       ['Romantic']     3  3.3
# 82     NaN  소파커버  ...  레인보우하우스  ['Romantic', 'Natural', 'Modern']  1043  4.6
# 2298   NaN  차렵이불  ...     에이트룸              ['Antique', 'Modern']   492  4.6
# 587    NaN   화장대  ...     잉글랜더                       ['Romantic']   199  4.5
#
#           별점평균       내구성        가격       디자인        배송  \
# 2204  4.497059  4.382353  4.382353  4.529412  4.647059
# 393   2.600000  3.000000  2.333333  3.000000  2.000000
# 82    4.574497  4.256951  4.549377  4.725791  4.710451
# 2298  4.602236  4.485772  4.532520  4.752033  4.599593
# 587   4.421608  4.537688  4.457286  4.753769  3.879397
#
#                                                  review
# 2204  [원하는 디자인이구요 타 사이트보다 저렴하게 구입했어요, 도마받침대로 쓰고있어요 튼...
# 393   [일단 구성에서 솔방울 빠져서 안왔구요 저는 원래 있는 구성에다가 약 삼천 원어치 ...
# 82    [쇼파가 금방 지저분해질거 같아서 깔았는데 너무 잘어울리고 사이즈도 딱이네요, 쇼파...
# 2298  [다른 이불들하고 엄청 비교해보다가 구매했는데 받아보니까 너무 좋아요 겉은 바스락거...
# 587   [고급스러운 원목 화장대가 집안 분위기를 따뜻하게해줘요ㅎㅎ 수납공간도 많고 만족합니...
#
# [5 rows x 22 columns]
